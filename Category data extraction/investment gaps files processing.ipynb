# %%
import pandas as pd

# %% [markdown]
# # wheat

# %%
df=pd.DataFrame()
df_abs=pd.read_csv('abstract/PRJABS_2000.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2000.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bwheat\b') | temp['PROJECT_TERMS'].str.contains(r'\bwheat\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bwheat\b') |temp['ABSTRACT'].str.contains(r'\bWheat\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bWheat\b')| temp['PROJECT_TITLE'].str.contains(r'\bWheat\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2001.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2001.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bwheat\b') | temp['PROJECT_TERMS'].str.contains(r'\bwheat\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bwheat\b') |temp['ABSTRACT'].str.contains(r'\bWheat\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bWheat\b')| temp['PROJECT_TITLE'].str.contains(r'\bWheat\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)


df_abs=pd.read_csv('abstract/PRJABS_2002.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2002.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bwheat\b') | temp['PROJECT_TERMS'].str.contains(r'\bwheat\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bwheat\b') |temp['ABSTRACT'].str.contains(r'\bWheat\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bWheat\b')| temp['PROJECT_TITLE'].str.contains(r'\bWheat\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)


df_abs=pd.read_csv('abstract/PRJABS_2003.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2003.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bwheat\b') | temp['PROJECT_TERMS'].str.contains(r'\bwheat\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bwheat\b') |temp['ABSTRACT'].str.contains(r'\bWheat\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bWheat\b')| temp['PROJECT_TITLE'].str.contains(r'\bWheat\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2004.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2004.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bwheat\b') | temp['PROJECT_TERMS'].str.contains(r'\bwheat\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bwheat\b') |temp['ABSTRACT'].str.contains(r'\bWheat\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bWheat\b')| temp['PROJECT_TITLE'].str.contains(r'\bWheat\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)


df_abs=pd.read_csv('abstract/PRJABS_2005.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2005.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bwheat\b') | temp['PROJECT_TERMS'].str.contains(r'\bwheat\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bwheat\b') |temp['ABSTRACT'].str.contains(r'\bWheat\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bWheat\b')| temp['PROJECT_TITLE'].str.contains(r'\bWheat\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2006.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2006.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bwheat\b') | temp['PROJECT_TERMS'].str.contains(r'\bwheat\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bwheat\b') |temp['ABSTRACT'].str.contains(r'\bWheat\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bWheat\b')| temp['PROJECT_TITLE'].str.contains(r'\bWheat\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2007.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2007.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bwheat\b') | temp['PROJECT_TERMS'].str.contains(r'\bwheat\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bwheat\b') |temp['ABSTRACT'].str.contains(r'\bWheat\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bWheat\b')| temp['PROJECT_TITLE'].str.contains(r'\bWheat\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2008.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2008.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bwheat\b') | temp['PROJECT_TERMS'].str.contains(r'\bwheat\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bwheat\b') |temp['ABSTRACT'].str.contains(r'\bWheat\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bWheat\b')| temp['PROJECT_TITLE'].str.contains(r'\bWheat\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2009.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2009.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bwheat\b') | temp['PROJECT_TERMS'].str.contains(r'\bwheat\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bwheat\b') |temp['ABSTRACT'].str.contains(r'\bWheat\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bWheat\b')| temp['PROJECT_TITLE'].str.contains(r'\bWheat\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2010.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2010.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bwheat\b') | temp['PROJECT_TERMS'].str.contains(r'\bwheat\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bwheat\b') |temp['ABSTRACT'].str.contains(r'\bWheat\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bWheat\b')| temp['PROJECT_TITLE'].str.contains(r'\bWheat\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2011.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2011.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bwheat\b') | temp['PROJECT_TERMS'].str.contains(r'\bwheat\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bwheat\b') |temp['ABSTRACT'].str.contains(r'\bWheat\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bWheat\b')| temp['PROJECT_TITLE'].str.contains(r'\bWheat\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2012.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2012.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bwheat\b') | temp['PROJECT_TERMS'].str.contains(r'\bwheat\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bwheat\b') |temp['ABSTRACT'].str.contains(r'\bWheat\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bWheat\b')| temp['PROJECT_TITLE'].str.contains(r'\bWheat\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2013.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2013.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bwheat\b') | temp['PROJECT_TERMS'].str.contains(r'\bwheat\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bwheat\b') |temp['ABSTRACT'].str.contains(r'\bWheat\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bWheat\b')| temp['PROJECT_TITLE'].str.contains(r'\bWheat\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2014.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2014.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bwheat\b') | temp['PROJECT_TERMS'].str.contains(r'\bwheat\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bwheat\b') |temp['ABSTRACT'].str.contains(r'\bWheat\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bWheat\b')| temp['PROJECT_TITLE'].str.contains(r'\bWheat\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2015.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2015.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bwheat\b') | temp['PROJECT_TERMS'].str.contains(r'\bwheat\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bwheat\b') |temp['ABSTRACT'].str.contains(r'\bWheat\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bWheat\b')| temp['PROJECT_TITLE'].str.contains(r'\bWheat\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2016.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2016.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bwheat\b') | temp['PROJECT_TERMS'].str.contains(r'\bwheat\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bwheat\b') |temp['ABSTRACT'].str.contains(r'\bWheat\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bWheat\b')| temp['PROJECT_TITLE'].str.contains(r'\bWheat\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2017.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2017.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bwheat\b') | temp['PROJECT_TERMS'].str.contains(r'\bwheat\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bwheat\b') |temp['ABSTRACT'].str.contains(r'\bWheat\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bWheat\b')| temp['PROJECT_TITLE'].str.contains(r'\bWheat\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2018.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2018.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bwheat\b') | temp['PROJECT_TERMS'].str.contains(r'\bwheat\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bwheat\b') |temp['ABSTRACT'].str.contains(r'\bWheat\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bWheat\b')| temp['PROJECT_TITLE'].str.contains(r'\bWheat\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2019.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2019.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bwheat\b') | temp['PROJECT_TERMS'].str.contains(r'\bwheat\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bwheat\b') |temp['ABSTRACT'].str.contains(r'\bWheat\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bWheat\b')| temp['PROJECT_TITLE'].str.contains(r'\bWheat\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)
# Out:
# (668, 24) (0, 25)
# (340, 24) (0, 25)
# (351, 24) (0, 25)
# (310, 24) (0, 25)
# (641, 24) (6, 25)
# (618, 24) (22, 25)
# (640, 24) (36, 25)
# (598, 24) (56, 25)
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3071: DtypeWarning: Columns (12,20) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# (104076, 24) (251, 25)
# (118557, 24) (468, 25)
# (111400, 24) (677, 25)
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3071: DtypeWarning: Columns (12) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# (98064, 24) (856, 25)
# (93367, 24) (997, 25)
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3071: DtypeWarning: Columns (20) have mixed types.Specify dtype option on import or set low_memory=False.
# ...

# %%
df = df[df.AGENCY != 'NASA']
df = df[df.AGENCY != 'NIH']
df.shape
# Out:
# (1392, 25)

# %%
df.to_csv('wheat.csv',index=False)

# %% [markdown]
# # corn or maize

# %%
df=pd.DataFrame()
df_abs=pd.read_csv('abstract/PRJABS_2000.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2000.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bcorn\b') | temp['PROJECT_TERMS'].str.contains(r'\bcorn\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bcorn\b') |temp['ABSTRACT'].str.contains(r'\bCorn\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bCorn\b')| temp['PROJECT_TITLE'].str.contains(r'\bCorn\b')|
           temp['ABSTRACT'].str.contains(r'\bmaize\b') | temp['PROJECT_TERMS'].str.contains(r'\bmaize\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bmaize\b') |temp['ABSTRACT'].str.contains(r'\bMaize\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bMaize\b')| temp['PROJECT_TITLE'].str.contains(r'\bMaize\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2001.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2001.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bcorn\b') | temp['PROJECT_TERMS'].str.contains(r'\bcorn\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bcorn\b') |temp['ABSTRACT'].str.contains(r'\bCorn\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bCorn\b')| temp['PROJECT_TITLE'].str.contains(r'\bCorn\b')|
           temp['ABSTRACT'].str.contains(r'\bmaize\b') | temp['PROJECT_TERMS'].str.contains(r'\bmaize\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bmaize\b') |temp['ABSTRACT'].str.contains(r'\bMaize\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bMaize\b')| temp['PROJECT_TITLE'].str.contains(r'\bMaize\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)


df_abs=pd.read_csv('abstract/PRJABS_2002.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2002.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bcorn\b') | temp['PROJECT_TERMS'].str.contains(r'\bcorn\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bcorn\b') |temp['ABSTRACT'].str.contains(r'\bCorn\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bCorn\b')| temp['PROJECT_TITLE'].str.contains(r'\bCorn\b')|
           temp['ABSTRACT'].str.contains(r'\bmaize\b') | temp['PROJECT_TERMS'].str.contains(r'\bmaize\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bmaize\b') |temp['ABSTRACT'].str.contains(r'\bMaize\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bMaize\b')| temp['PROJECT_TITLE'].str.contains(r'\bMaize\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)


df_abs=pd.read_csv('abstract/PRJABS_2003.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2003.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bcorn\b') | temp['PROJECT_TERMS'].str.contains(r'\bcorn\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bcorn\b') |temp['ABSTRACT'].str.contains(r'\bCorn\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bCorn\b')| temp['PROJECT_TITLE'].str.contains(r'\bCorn\b')|
           temp['ABSTRACT'].str.contains(r'\bmaize\b') | temp['PROJECT_TERMS'].str.contains(r'\bmaize\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bmaize\b') |temp['ABSTRACT'].str.contains(r'\bMaize\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bMaize\b')| temp['PROJECT_TITLE'].str.contains(r'\bMaize\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2004.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2004.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bcorn\b') | temp['PROJECT_TERMS'].str.contains(r'\bcorn\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bcorn\b') |temp['ABSTRACT'].str.contains(r'\bCorn\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bCorn\b')| temp['PROJECT_TITLE'].str.contains(r'\bCorn\b')|
           temp['ABSTRACT'].str.contains(r'\bmaize\b') | temp['PROJECT_TERMS'].str.contains(r'\bmaize\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bmaize\b') |temp['ABSTRACT'].str.contains(r'\bMaize\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bMaize\b')| temp['PROJECT_TITLE'].str.contains(r'\bMaize\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2005.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2005.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bcorn\b') | temp['PROJECT_TERMS'].str.contains(r'\bcorn\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bcorn\b') |temp['ABSTRACT'].str.contains(r'\bCorn\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bCorn\b')| temp['PROJECT_TITLE'].str.contains(r'\bCorn\b')|
           temp['ABSTRACT'].str.contains(r'\bmaize\b') | temp['PROJECT_TERMS'].str.contains(r'\bmaize\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bmaize\b') |temp['ABSTRACT'].str.contains(r'\bMaize\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bMaize\b')| temp['PROJECT_TITLE'].str.contains(r'\bMaize\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2006.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2006.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bcorn\b') | temp['PROJECT_TERMS'].str.contains(r'\bcorn\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bcorn\b') |temp['ABSTRACT'].str.contains(r'\bCorn\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bCorn\b')| temp['PROJECT_TITLE'].str.contains(r'\bCorn\b')|
           temp['ABSTRACT'].str.contains(r'\bmaize\b') | temp['PROJECT_TERMS'].str.contains(r'\bmaize\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bmaize\b') |temp['ABSTRACT'].str.contains(r'\bMaize\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bMaize\b')| temp['PROJECT_TITLE'].str.contains(r'\bMaize\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2007.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2007.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bcorn\b') | temp['PROJECT_TERMS'].str.contains(r'\bcorn\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bcorn\b') |temp['ABSTRACT'].str.contains(r'\bCorn\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bCorn\b')| temp['PROJECT_TITLE'].str.contains(r'\bCorn\b')|
           temp['ABSTRACT'].str.contains(r'\bmaize\b') | temp['PROJECT_TERMS'].str.contains(r'\bmaize\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bmaize\b') |temp['ABSTRACT'].str.contains(r'\bMaize\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bMaize\b')| temp['PROJECT_TITLE'].str.contains(r'\bMaize\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2008.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2008.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bcorn\b') | temp['PROJECT_TERMS'].str.contains(r'\bcorn\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bcorn\b') |temp['ABSTRACT'].str.contains(r'\bCorn\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bCorn\b')| temp['PROJECT_TITLE'].str.contains(r'\bCorn\b')|
           temp['ABSTRACT'].str.contains(r'\bmaize\b') | temp['PROJECT_TERMS'].str.contains(r'\bmaize\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bmaize\b') |temp['ABSTRACT'].str.contains(r'\bMaize\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bMaize\b')| temp['PROJECT_TITLE'].str.contains(r'\bMaize\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2009.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2009.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bcorn\b') | temp['PROJECT_TERMS'].str.contains(r'\bcorn\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bcorn\b') |temp['ABSTRACT'].str.contains(r'\bCorn\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bCorn\b')| temp['PROJECT_TITLE'].str.contains(r'\bCorn\b')|
           temp['ABSTRACT'].str.contains(r'\bmaize\b') | temp['PROJECT_TERMS'].str.contains(r'\bmaize\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bmaize\b') |temp['ABSTRACT'].str.contains(r'\bMaize\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bMaize\b')| temp['PROJECT_TITLE'].str.contains(r'\bMaize\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2010.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2010.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bcorn\b') | temp['PROJECT_TERMS'].str.contains(r'\bcorn\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bcorn\b') |temp['ABSTRACT'].str.contains(r'\bCorn\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bCorn\b')| temp['PROJECT_TITLE'].str.contains(r'\bCorn\b')|
           temp['ABSTRACT'].str.contains(r'\bmaize\b') | temp['PROJECT_TERMS'].str.contains(r'\bmaize\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bmaize\b') |temp['ABSTRACT'].str.contains(r'\bMaize\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bMaize\b')| temp['PROJECT_TITLE'].str.contains(r'\bMaize\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2011.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2011.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bcorn\b') | temp['PROJECT_TERMS'].str.contains(r'\bcorn\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bcorn\b') |temp['ABSTRACT'].str.contains(r'\bCorn\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bCorn\b')| temp['PROJECT_TITLE'].str.contains(r'\bCorn\b')|
           temp['ABSTRACT'].str.contains(r'\bmaize\b') | temp['PROJECT_TERMS'].str.contains(r'\bmaize\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bmaize\b') |temp['ABSTRACT'].str.contains(r'\bMaize\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bMaize\b')| temp['PROJECT_TITLE'].str.contains(r'\bMaize\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2012.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2012.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bcorn\b') | temp['PROJECT_TERMS'].str.contains(r'\bcorn\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bcorn\b') |temp['ABSTRACT'].str.contains(r'\bCorn\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bCorn\b')| temp['PROJECT_TITLE'].str.contains(r'\bCorn\b')|
           temp['ABSTRACT'].str.contains(r'\bmaize\b') | temp['PROJECT_TERMS'].str.contains(r'\bmaize\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bmaize\b') |temp['ABSTRACT'].str.contains(r'\bMaize\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bMaize\b')| temp['PROJECT_TITLE'].str.contains(r'\bMaize\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2013.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2013.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bcorn\b') | temp['PROJECT_TERMS'].str.contains(r'\bcorn\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bcorn\b') |temp['ABSTRACT'].str.contains(r'\bCorn\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bCorn\b')| temp['PROJECT_TITLE'].str.contains(r'\bCorn\b')|
           temp['ABSTRACT'].str.contains(r'\bmaize\b') | temp['PROJECT_TERMS'].str.contains(r'\bmaize\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bmaize\b') |temp['ABSTRACT'].str.contains(r'\bMaize\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bMaize\b')| temp['PROJECT_TITLE'].str.contains(r'\bMaize\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2014.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2014.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bcorn\b') | temp['PROJECT_TERMS'].str.contains(r'\bcorn\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bcorn\b') |temp['ABSTRACT'].str.contains(r'\bCorn\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bCorn\b')| temp['PROJECT_TITLE'].str.contains(r'\bCorn\b')|
           temp['ABSTRACT'].str.contains(r'\bmaize\b') | temp['PROJECT_TERMS'].str.contains(r'\bmaize\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bmaize\b') |temp['ABSTRACT'].str.contains(r'\bMaize\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bMaize\b')| temp['PROJECT_TITLE'].str.contains(r'\bMaize\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2015.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2015.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bcorn\b') | temp['PROJECT_TERMS'].str.contains(r'\bcorn\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bcorn\b') |temp['ABSTRACT'].str.contains(r'\bCorn\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bCorn\b')| temp['PROJECT_TITLE'].str.contains(r'\bCorn\b')|
           temp['ABSTRACT'].str.contains(r'\bmaize\b') | temp['PROJECT_TERMS'].str.contains(r'\bmaize\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bmaize\b') |temp['ABSTRACT'].str.contains(r'\bMaize\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bMaize\b')| temp['PROJECT_TITLE'].str.contains(r'\bMaize\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2016.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2016.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bcorn\b') | temp['PROJECT_TERMS'].str.contains(r'\bcorn\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bcorn\b') |temp['ABSTRACT'].str.contains(r'\bCorn\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bCorn\b')| temp['PROJECT_TITLE'].str.contains(r'\bCorn\b')|
           temp['ABSTRACT'].str.contains(r'\bmaize\b') | temp['PROJECT_TERMS'].str.contains(r'\bmaize\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bmaize\b') |temp['ABSTRACT'].str.contains(r'\bMaize\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bMaize\b')| temp['PROJECT_TITLE'].str.contains(r'\bMaize\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2017.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2017.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bcorn\b') | temp['PROJECT_TERMS'].str.contains(r'\bcorn\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bcorn\b') |temp['ABSTRACT'].str.contains(r'\bCorn\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bCorn\b')| temp['PROJECT_TITLE'].str.contains(r'\bCorn\b')|
           temp['ABSTRACT'].str.contains(r'\bmaize\b') | temp['PROJECT_TERMS'].str.contains(r'\bmaize\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bmaize\b') |temp['ABSTRACT'].str.contains(r'\bMaize\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bMaize\b')| temp['PROJECT_TITLE'].str.contains(r'\bMaize\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2018.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2018.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bcorn\b') | temp['PROJECT_TERMS'].str.contains(r'\bcorn\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bcorn\b') |temp['ABSTRACT'].str.contains(r'\bCorn\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bCorn\b')| temp['PROJECT_TITLE'].str.contains(r'\bCorn\b')|
           temp['ABSTRACT'].str.contains(r'\bmaize\b') | temp['PROJECT_TERMS'].str.contains(r'\bmaize\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bmaize\b') |temp['ABSTRACT'].str.contains(r'\bMaize\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bMaize\b')| temp['PROJECT_TITLE'].str.contains(r'\bMaize\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2019.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2019.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bcorn\b') | temp['PROJECT_TERMS'].str.contains(r'\bcorn\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bcorn\b') |temp['ABSTRACT'].str.contains(r'\bCorn\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bCorn\b')| temp['PROJECT_TITLE'].str.contains(r'\bCorn\b')|
           temp['ABSTRACT'].str.contains(r'\bmaize\b') | temp['PROJECT_TERMS'].str.contains(r'\bmaize\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bmaize\b') |temp['ABSTRACT'].str.contains(r'\bMaize\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bMaize\b')| temp['PROJECT_TITLE'].str.contains(r'\bMaize\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)
# Out:
# (668, 24) (1, 25)
# (340, 24) (2, 25)
# (351, 24) (3, 25)
# (310, 24) (6, 25)
# (641, 24) (15, 25)
# (618, 24) (37, 25)
# (640, 24) (61, 25)
# (598, 24) (78, 25)
# (104076, 24) (397, 25)
# (118557, 24) (742, 25)
# (111400, 24) (1062, 25)
# (98064, 24) (1356, 25)
# (93367, 24) (1581, 25)
# (91637, 24) (1862, 25)
# (90944, 24) (2082, 25)
# (92265, 24) (2321, 25)
# (91126, 24) (2623, 25)
# b'Skipping line 87965: expected 24 fields, saw 25\nSkipping line 87967: expected 24 fields, saw 25\n'
# (88420, 24) (2770, 25)
# b'Skipping line 95568: expected 24 fields, saw 25\nSkipping line 95570: expected 24 fields, saw 25\n'
# (96209, 24) (2952, 25)
# b'Skipping line 74736: expected 24 fields, saw 25\nSkipping line 79976: expected 24 fields, saw 25\n'
# (80066, 24) (3099, 25)

# %%
df['AGENCY'].unique()
# Out:
# array(['EPA', 'ARS', 'NSF', 'NIH', 'FDA', 'NIFA', 'CDMRP', 'ALLCDC',
#        'NASA', 'VA'], dtype=object)

# %%
df = df[df.AGENCY != 'NASA']
df = df[df.AGENCY != 'NIH']
df.shape
# Out:
# (2655, 25)

# %%
df.to_csv('corn_maize.csv')

# %% [markdown]
# # Soybeans

# %%
df=pd.DataFrame()
df_abs=pd.read_csv('abstract/PRJABS_2000.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2000.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[(temp['ABSTRACT'].str.contains(r'\bsoy') | temp['PROJECT_TERMS'].str.contains(r'\bsoy')| 
           temp['PROJECT_TITLE'].str.contains(r'\bsoy') |temp['ABSTRACT'].str.contains(r'\bSoy') | 
           temp['PROJECT_TERMS'].str.contains(r'\bSoy')| temp['PROJECT_TITLE'].str.contains(r'\bSoy')|
           temp['ABSTRACT'].str.contains(r'\bsoybean') | temp['PROJECT_TERMS'].str.contains(r'\bsoybean')| 
           temp['PROJECT_TITLE'].str.contains(r'\bsoybean') |temp['ABSTRACT'].str.contains(r'\bSoybean') | 
           temp['PROJECT_TERMS'].str.contains(r'\bSoybean')| temp['PROJECT_TITLE'].str.contains(r'\bSoybean'))&
           ((temp['ABSTRACT'].str.contains(r'\bedamame\b')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bedamame\b')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bedamame\b')==False) |(temp['ABSTRACT'].str.contains(r'\bEdamame\b')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bEdamame\b')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bEdamame\b')==False))]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2001.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2001.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[(temp['ABSTRACT'].str.contains(r'\bsoy') | temp['PROJECT_TERMS'].str.contains(r'\bsoy')| 
           temp['PROJECT_TITLE'].str.contains(r'\bsoy') |temp['ABSTRACT'].str.contains(r'\bSoy') | 
           temp['PROJECT_TERMS'].str.contains(r'\bSoy')| temp['PROJECT_TITLE'].str.contains(r'\bSoy')|
           temp['ABSTRACT'].str.contains(r'\bsoybean') | temp['PROJECT_TERMS'].str.contains(r'\bsoybean')| 
           temp['PROJECT_TITLE'].str.contains(r'\bsoybean') |temp['ABSTRACT'].str.contains(r'\bSoybean') | 
           temp['PROJECT_TERMS'].str.contains(r'\bSoybean')| temp['PROJECT_TITLE'].str.contains(r'\bSoybean'))&
           ((temp['ABSTRACT'].str.contains(r'\bedamame\b')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bedamame\b')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bedamame\b')==False) |(temp['ABSTRACT'].str.contains(r'\bEdamame\b')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bEdamame\b')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bEdamame\b')==False))]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)


df_abs=pd.read_csv('abstract/PRJABS_2002.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2002.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[(temp['ABSTRACT'].str.contains(r'\bsoy') | temp['PROJECT_TERMS'].str.contains(r'\bsoy')| 
           temp['PROJECT_TITLE'].str.contains(r'\bsoy') |temp['ABSTRACT'].str.contains(r'\bSoy') | 
           temp['PROJECT_TERMS'].str.contains(r'\bSoy')| temp['PROJECT_TITLE'].str.contains(r'\bSoy')|
           temp['ABSTRACT'].str.contains(r'\bsoybean') | temp['PROJECT_TERMS'].str.contains(r'\bsoybean')| 
           temp['PROJECT_TITLE'].str.contains(r'\bsoybean') |temp['ABSTRACT'].str.contains(r'\bSoybean') | 
           temp['PROJECT_TERMS'].str.contains(r'\bSoybean')| temp['PROJECT_TITLE'].str.contains(r'\bSoybean'))&
           ((temp['ABSTRACT'].str.contains(r'\bedamame\b')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bedamame\b')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bedamame\b')==False) |(temp['ABSTRACT'].str.contains(r'\bEdamame\b')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bEdamame\b')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bEdamame\b')==False))]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)


df_abs=pd.read_csv('abstract/PRJABS_2003.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2003.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[(temp['ABSTRACT'].str.contains(r'\bsoy') | temp['PROJECT_TERMS'].str.contains(r'\bsoy')| 
           temp['PROJECT_TITLE'].str.contains(r'\bsoy') |temp['ABSTRACT'].str.contains(r'\bSoy') | 
           temp['PROJECT_TERMS'].str.contains(r'\bSoy')| temp['PROJECT_TITLE'].str.contains(r'\bSoy')|
           temp['ABSTRACT'].str.contains(r'\bsoybean') | temp['PROJECT_TERMS'].str.contains(r'\bsoybean')| 
           temp['PROJECT_TITLE'].str.contains(r'\bsoybean') |temp['ABSTRACT'].str.contains(r'\bSoybean') | 
           temp['PROJECT_TERMS'].str.contains(r'\bSoybean')| temp['PROJECT_TITLE'].str.contains(r'\bSoybean'))&
           ((temp['ABSTRACT'].str.contains(r'\bedamame\b')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bedamame\b')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bedamame\b')==False) |(temp['ABSTRACT'].str.contains(r'\bEdamame\b')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bEdamame\b')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bEdamame\b')==False))]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2004.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2004.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[(temp['ABSTRACT'].str.contains(r'\bsoy') | temp['PROJECT_TERMS'].str.contains(r'\bsoy')| 
           temp['PROJECT_TITLE'].str.contains(r'\bsoy') |temp['ABSTRACT'].str.contains(r'\bSoy') | 
           temp['PROJECT_TERMS'].str.contains(r'\bSoy')| temp['PROJECT_TITLE'].str.contains(r'\bSoy')|
           temp['ABSTRACT'].str.contains(r'\bsoybean') | temp['PROJECT_TERMS'].str.contains(r'\bsoybean')| 
           temp['PROJECT_TITLE'].str.contains(r'\bsoybean') |temp['ABSTRACT'].str.contains(r'\bSoybean') | 
           temp['PROJECT_TERMS'].str.contains(r'\bSoybean')| temp['PROJECT_TITLE'].str.contains(r'\bSoybean'))&
           ((temp['ABSTRACT'].str.contains(r'\bedamame\b')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bedamame\b')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bedamame\b')==False) |(temp['ABSTRACT'].str.contains(r'\bEdamame\b')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bEdamame\b')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bEdamame\b')==False))]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2005.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2005.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[(temp['ABSTRACT'].str.contains(r'\bsoy') | temp['PROJECT_TERMS'].str.contains(r'\bsoy')| 
           temp['PROJECT_TITLE'].str.contains(r'\bsoy') |temp['ABSTRACT'].str.contains(r'\bSoy') | 
           temp['PROJECT_TERMS'].str.contains(r'\bSoy')| temp['PROJECT_TITLE'].str.contains(r'\bSoy')|
           temp['ABSTRACT'].str.contains(r'\bsoybean') | temp['PROJECT_TERMS'].str.contains(r'\bsoybean')| 
           temp['PROJECT_TITLE'].str.contains(r'\bsoybean') |temp['ABSTRACT'].str.contains(r'\bSoybean') | 
           temp['PROJECT_TERMS'].str.contains(r'\bSoybean')| temp['PROJECT_TITLE'].str.contains(r'\bSoybean'))&
           ((temp['ABSTRACT'].str.contains(r'\bedamame\b')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bedamame\b')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bedamame\b')==False) |(temp['ABSTRACT'].str.contains(r'\bEdamame\b')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bEdamame\b')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bEdamame\b')==False))]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2006.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2006.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[(temp['ABSTRACT'].str.contains(r'\bsoy') | temp['PROJECT_TERMS'].str.contains(r'\bsoy')| 
           temp['PROJECT_TITLE'].str.contains(r'\bsoy') |temp['ABSTRACT'].str.contains(r'\bSoy') | 
           temp['PROJECT_TERMS'].str.contains(r'\bSoy')| temp['PROJECT_TITLE'].str.contains(r'\bSoy')|
           temp['ABSTRACT'].str.contains(r'\bsoybean') | temp['PROJECT_TERMS'].str.contains(r'\bsoybean')| 
           temp['PROJECT_TITLE'].str.contains(r'\bsoybean') |temp['ABSTRACT'].str.contains(r'\bSoybean') | 
           temp['PROJECT_TERMS'].str.contains(r'\bSoybean')| temp['PROJECT_TITLE'].str.contains(r'\bSoybean'))&
           ((temp['ABSTRACT'].str.contains(r'\bedamame\b')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bedamame\b')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bedamame\b')==False) |(temp['ABSTRACT'].str.contains(r'\bEdamame\b')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bEdamame\b')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bEdamame\b')==False))]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)


df_abs=pd.read_csv('abstract/PRJABS_2007.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2007.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[(temp['ABSTRACT'].str.contains(r'\bsoy') | temp['PROJECT_TERMS'].str.contains(r'\bsoy')| 
           temp['PROJECT_TITLE'].str.contains(r'\bsoy') |temp['ABSTRACT'].str.contains(r'\bSoy') | 
           temp['PROJECT_TERMS'].str.contains(r'\bSoy')| temp['PROJECT_TITLE'].str.contains(r'\bSoy')|
           temp['ABSTRACT'].str.contains(r'\bsoybean') | temp['PROJECT_TERMS'].str.contains(r'\bsoybean')| 
           temp['PROJECT_TITLE'].str.contains(r'\bsoybean') |temp['ABSTRACT'].str.contains(r'\bSoybean') | 
           temp['PROJECT_TERMS'].str.contains(r'\bSoybean')| temp['PROJECT_TITLE'].str.contains(r'\bSoybean'))&
           ((temp['ABSTRACT'].str.contains(r'\bedamame\b')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bedamame\b')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bedamame\b')==False) |(temp['ABSTRACT'].str.contains(r'\bEdamame\b')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bEdamame\b')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bEdamame\b')==False))]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2008.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2008.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[(temp['ABSTRACT'].str.contains(r'\bsoy') | temp['PROJECT_TERMS'].str.contains(r'\bsoy')| 
           temp['PROJECT_TITLE'].str.contains(r'\bsoy') |temp['ABSTRACT'].str.contains(r'\bSoy') | 
           temp['PROJECT_TERMS'].str.contains(r'\bSoy')| temp['PROJECT_TITLE'].str.contains(r'\bSoy')|
           temp['ABSTRACT'].str.contains(r'\bsoybean') | temp['PROJECT_TERMS'].str.contains(r'\bsoybean')| 
           temp['PROJECT_TITLE'].str.contains(r'\bsoybean') |temp['ABSTRACT'].str.contains(r'\bSoybean') | 
           temp['PROJECT_TERMS'].str.contains(r'\bSoybean')| temp['PROJECT_TITLE'].str.contains(r'\bSoybean'))&
           ((temp['ABSTRACT'].str.contains(r'\bedamame\b')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bedamame\b')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bedamame\b')==False) |(temp['ABSTRACT'].str.contains(r'\bEdamame\b')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bEdamame\b')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bEdamame\b')==False))]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2009.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2009.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[(temp['ABSTRACT'].str.contains(r'\bsoy') | temp['PROJECT_TERMS'].str.contains(r'\bsoy')| 
           temp['PROJECT_TITLE'].str.contains(r'\bsoy') |temp['ABSTRACT'].str.contains(r'\bSoy') | 
           temp['PROJECT_TERMS'].str.contains(r'\bSoy')| temp['PROJECT_TITLE'].str.contains(r'\bSoy')|
           temp['ABSTRACT'].str.contains(r'\bsoybean') | temp['PROJECT_TERMS'].str.contains(r'\bsoybean')| 
           temp['PROJECT_TITLE'].str.contains(r'\bsoybean') |temp['ABSTRACT'].str.contains(r'\bSoybean') | 
           temp['PROJECT_TERMS'].str.contains(r'\bSoybean')| temp['PROJECT_TITLE'].str.contains(r'\bSoybean'))&
           ((temp['ABSTRACT'].str.contains(r'\bedamame\b')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bedamame\b')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bedamame\b')==False) |(temp['ABSTRACT'].str.contains(r'\bEdamame\b')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bEdamame\b')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bEdamame\b')==False))]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2010.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2010.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[(temp['ABSTRACT'].str.contains(r'\bsoy') | temp['PROJECT_TERMS'].str.contains(r'\bsoy')| 
           temp['PROJECT_TITLE'].str.contains(r'\bsoy') |temp['ABSTRACT'].str.contains(r'\bSoy') | 
           temp['PROJECT_TERMS'].str.contains(r'\bSoy')| temp['PROJECT_TITLE'].str.contains(r'\bSoy')|
           temp['ABSTRACT'].str.contains(r'\bsoybean') | temp['PROJECT_TERMS'].str.contains(r'\bsoybean')| 
           temp['PROJECT_TITLE'].str.contains(r'\bsoybean') |temp['ABSTRACT'].str.contains(r'\bSoybean') | 
           temp['PROJECT_TERMS'].str.contains(r'\bSoybean')| temp['PROJECT_TITLE'].str.contains(r'\bSoybean'))&
           ((temp['ABSTRACT'].str.contains(r'\bedamame\b')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bedamame\b')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bedamame\b')==False) |(temp['ABSTRACT'].str.contains(r'\bEdamame\b')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bEdamame\b')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bEdamame\b')==False))]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2011.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2011.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[(temp['ABSTRACT'].str.contains(r'\bsoy') | temp['PROJECT_TERMS'].str.contains(r'\bsoy')| 
           temp['PROJECT_TITLE'].str.contains(r'\bsoy') |temp['ABSTRACT'].str.contains(r'\bSoy') | 
           temp['PROJECT_TERMS'].str.contains(r'\bSoy')| temp['PROJECT_TITLE'].str.contains(r'\bSoy')|
           temp['ABSTRACT'].str.contains(r'\bsoybean') | temp['PROJECT_TERMS'].str.contains(r'\bsoybean')| 
           temp['PROJECT_TITLE'].str.contains(r'\bsoybean') |temp['ABSTRACT'].str.contains(r'\bSoybean') | 
           temp['PROJECT_TERMS'].str.contains(r'\bSoybean')| temp['PROJECT_TITLE'].str.contains(r'\bSoybean'))&
           ((temp['ABSTRACT'].str.contains(r'\bedamame\b')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bedamame\b')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bedamame\b')==False) |(temp['ABSTRACT'].str.contains(r'\bEdamame\b')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bEdamame\b')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bEdamame\b')==False))]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2012.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2012.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[(temp['ABSTRACT'].str.contains(r'\bsoy') | temp['PROJECT_TERMS'].str.contains(r'\bsoy')| 
           temp['PROJECT_TITLE'].str.contains(r'\bsoy') |temp['ABSTRACT'].str.contains(r'\bSoy') | 
           temp['PROJECT_TERMS'].str.contains(r'\bSoy')| temp['PROJECT_TITLE'].str.contains(r'\bSoy')|
           temp['ABSTRACT'].str.contains(r'\bsoybean') | temp['PROJECT_TERMS'].str.contains(r'\bsoybean')| 
           temp['PROJECT_TITLE'].str.contains(r'\bsoybean') |temp['ABSTRACT'].str.contains(r'\bSoybean') | 
           temp['PROJECT_TERMS'].str.contains(r'\bSoybean')| temp['PROJECT_TITLE'].str.contains(r'\bSoybean'))&
           ((temp['ABSTRACT'].str.contains(r'\bedamame\b')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bedamame\b')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bedamame\b')==False) |(temp['ABSTRACT'].str.contains(r'\bEdamame\b')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bEdamame\b')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bEdamame\b')==False))]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2013.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2013.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[(temp['ABSTRACT'].str.contains(r'\bsoy') | temp['PROJECT_TERMS'].str.contains(r'\bsoy')| 
           temp['PROJECT_TITLE'].str.contains(r'\bsoy') |temp['ABSTRACT'].str.contains(r'\bSoy') | 
           temp['PROJECT_TERMS'].str.contains(r'\bSoy')| temp['PROJECT_TITLE'].str.contains(r'\bSoy')|
           temp['ABSTRACT'].str.contains(r'\bsoybean') | temp['PROJECT_TERMS'].str.contains(r'\bsoybean')| 
           temp['PROJECT_TITLE'].str.contains(r'\bsoybean') |temp['ABSTRACT'].str.contains(r'\bSoybean') | 
           temp['PROJECT_TERMS'].str.contains(r'\bSoybean')| temp['PROJECT_TITLE'].str.contains(r'\bSoybean'))&
           ((temp['ABSTRACT'].str.contains(r'\bedamame\b')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bedamame\b')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bedamame\b')==False) |(temp['ABSTRACT'].str.contains(r'\bEdamame\b')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bEdamame\b')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bEdamame\b')==False))]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2014.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2014.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[(temp['ABSTRACT'].str.contains(r'\bsoy') | temp['PROJECT_TERMS'].str.contains(r'\bsoy')| 
           temp['PROJECT_TITLE'].str.contains(r'\bsoy') |temp['ABSTRACT'].str.contains(r'\bSoy') | 
           temp['PROJECT_TERMS'].str.contains(r'\bSoy')| temp['PROJECT_TITLE'].str.contains(r'\bSoy')|
           temp['ABSTRACT'].str.contains(r'\bsoybean') | temp['PROJECT_TERMS'].str.contains(r'\bsoybean')| 
           temp['PROJECT_TITLE'].str.contains(r'\bsoybean') |temp['ABSTRACT'].str.contains(r'\bSoybean') | 
           temp['PROJECT_TERMS'].str.contains(r'\bSoybean')| temp['PROJECT_TITLE'].str.contains(r'\bSoybean'))&
           ((temp['ABSTRACT'].str.contains(r'\bedamame\b')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bedamame\b')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bedamame\b')==False) |(temp['ABSTRACT'].str.contains(r'\bEdamame\b')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bEdamame\b')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bEdamame\b')==False))]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2015.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2015.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[(temp['ABSTRACT'].str.contains(r'\bsoy') | temp['PROJECT_TERMS'].str.contains(r'\bsoy')| 
           temp['PROJECT_TITLE'].str.contains(r'\bsoy') |temp['ABSTRACT'].str.contains(r'\bSoy') | 
           temp['PROJECT_TERMS'].str.contains(r'\bSoy')| temp['PROJECT_TITLE'].str.contains(r'\bSoy')|
           temp['ABSTRACT'].str.contains(r'\bsoybean') | temp['PROJECT_TERMS'].str.contains(r'\bsoybean')| 
           temp['PROJECT_TITLE'].str.contains(r'\bsoybean') |temp['ABSTRACT'].str.contains(r'\bSoybean') | 
           temp['PROJECT_TERMS'].str.contains(r'\bSoybean')| temp['PROJECT_TITLE'].str.contains(r'\bSoybean'))&
           ((temp['ABSTRACT'].str.contains(r'\bedamame\b')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bedamame\b')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bedamame\b')==False) |(temp['ABSTRACT'].str.contains(r'\bEdamame\b')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bEdamame\b')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bEdamame\b')==False))]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2016.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2016.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[(temp['ABSTRACT'].str.contains(r'\bsoy') | temp['PROJECT_TERMS'].str.contains(r'\bsoy')| 
           temp['PROJECT_TITLE'].str.contains(r'\bsoy') |temp['ABSTRACT'].str.contains(r'\bSoy') | 
           temp['PROJECT_TERMS'].str.contains(r'\bSoy')| temp['PROJECT_TITLE'].str.contains(r'\bSoy')|
           temp['ABSTRACT'].str.contains(r'\bsoybean') | temp['PROJECT_TERMS'].str.contains(r'\bsoybean')| 
           temp['PROJECT_TITLE'].str.contains(r'\bsoybean') |temp['ABSTRACT'].str.contains(r'\bSoybean') | 
           temp['PROJECT_TERMS'].str.contains(r'\bSoybean')| temp['PROJECT_TITLE'].str.contains(r'\bSoybean'))&
           ((temp['ABSTRACT'].str.contains(r'\bedamame\b')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bedamame\b')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bedamame\b')==False) |(temp['ABSTRACT'].str.contains(r'\bEdamame\b')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bEdamame\b')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bEdamame\b')==False))]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2017.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2017.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[(temp['ABSTRACT'].str.contains(r'\bsoy') | temp['PROJECT_TERMS'].str.contains(r'\bsoy')| 
           temp['PROJECT_TITLE'].str.contains(r'\bsoy') |temp['ABSTRACT'].str.contains(r'\bSoy') | 
           temp['PROJECT_TERMS'].str.contains(r'\bSoy')| temp['PROJECT_TITLE'].str.contains(r'\bSoy')|
           temp['ABSTRACT'].str.contains(r'\bsoybean') | temp['PROJECT_TERMS'].str.contains(r'\bsoybean')| 
           temp['PROJECT_TITLE'].str.contains(r'\bsoybean') |temp['ABSTRACT'].str.contains(r'\bSoybean') | 
           temp['PROJECT_TERMS'].str.contains(r'\bSoybean')| temp['PROJECT_TITLE'].str.contains(r'\bSoybean'))&
           ((temp['ABSTRACT'].str.contains(r'\bedamame\b')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bedamame\b')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bedamame\b')==False) |(temp['ABSTRACT'].str.contains(r'\bEdamame\b')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bEdamame\b')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bEdamame\b')==False))]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2018.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2018.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[(temp['ABSTRACT'].str.contains(r'\bsoy') | temp['PROJECT_TERMS'].str.contains(r'\bsoy')| 
           temp['PROJECT_TITLE'].str.contains(r'\bsoy') |temp['ABSTRACT'].str.contains(r'\bSoy') | 
           temp['PROJECT_TERMS'].str.contains(r'\bSoy')| temp['PROJECT_TITLE'].str.contains(r'\bSoy')|
           temp['ABSTRACT'].str.contains(r'\bsoybean') | temp['PROJECT_TERMS'].str.contains(r'\bsoybean')| 
           temp['PROJECT_TITLE'].str.contains(r'\bsoybean') |temp['ABSTRACT'].str.contains(r'\bSoybean') | 
           temp['PROJECT_TERMS'].str.contains(r'\bSoybean')| temp['PROJECT_TITLE'].str.contains(r'\bSoybean'))&
           ((temp['ABSTRACT'].str.contains(r'\bedamame\b')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bedamame\b')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bedamame\b')==False) |(temp['ABSTRACT'].str.contains(r'\bEdamame\b')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bEdamame\b')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bEdamame\b')==False))]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2019.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2019.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[(temp['ABSTRACT'].str.contains(r'\bsoy') | temp['PROJECT_TERMS'].str.contains(r'\bsoy')| 
           temp['PROJECT_TITLE'].str.contains(r'\bsoy') |temp['ABSTRACT'].str.contains(r'\bSoy') | 
           temp['PROJECT_TERMS'].str.contains(r'\bSoy')| temp['PROJECT_TITLE'].str.contains(r'\bSoy')|
           temp['ABSTRACT'].str.contains(r'\bsoybean') | temp['PROJECT_TERMS'].str.contains(r'\bsoybean')| 
           temp['PROJECT_TITLE'].str.contains(r'\bsoybean') |temp['ABSTRACT'].str.contains(r'\bSoybean') | 
           temp['PROJECT_TERMS'].str.contains(r'\bSoybean')| temp['PROJECT_TITLE'].str.contains(r'\bSoybean'))&
           ((temp['ABSTRACT'].str.contains(r'\bedamame\b')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bedamame\b')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bedamame\b')==False) |(temp['ABSTRACT'].str.contains(r'\bEdamame\b')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bEdamame\b')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bEdamame\b')==False))]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)
# Out:
# (668, 24) (0, 25)
# (340, 24) (0, 25)
# (351, 24) (2, 25)
# (310, 24) (4, 25)
# (641, 24) (16, 25)
# (618, 24) (34, 25)
# (640, 24) (55, 25)
# (598, 24) (71, 25)
# (104076, 24) (380, 25)
# (118557, 24) (684, 25)
# (111400, 24) (976, 25)
# (98064, 24) (1203, 25)
# (93367, 24) (1398, 25)
# (91637, 24) (1641, 25)
# (90944, 24) (1850, 25)
# (92265, 24) (2043, 25)
# (91126, 24) (2226, 25)
# b'Skipping line 87965: expected 24 fields, saw 25\nSkipping line 87967: expected 24 fields, saw 25\n'
# (88420, 24) (2355, 25)
# b'Skipping line 95568: expected 24 fields, saw 25\nSkipping line 95570: expected 24 fields, saw 25\n'
# (96209, 24) (2496, 25)
# b'Skipping line 74736: expected 24 fields, saw 25\nSkipping line 79976: expected 24 fields, saw 25\n'
# (80066, 24) (2638, 25)

# %%
df['AGENCY'].unique()
# Out:
# array(['EPA', 'ARS', 'NSF', 'NIH', 'FDA', 'NIFA', 'CDMRP', 'VA', 'ALLCDC'],
#       dtype=object)

# %%
df = df[df.AGENCY != 'NASA']
df = df[df.AGENCY != 'NIH']
print(df.shape)
df.to_csv('soybean.csv')
# Out:
# (1694, 25)

# %%
df.to_csv('soybean.csv')

# %% [markdown]
# # Legume- Nuts but No Peanuts

# %%
df=pd.DataFrame()
df_abs=pd.read_csv('abstract/PRJABS_2000.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2000.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[(temp['ABSTRACT'].str.contains(r'\blegume') | temp['PROJECT_TERMS'].str.contains(r'\blegume')| 
           temp['PROJECT_TITLE'].str.contains(r'\blegume') |temp['ABSTRACT'].str.contains(r'\bLegume') | 
           temp['PROJECT_TERMS'].str.contains(r'\bLegume')| temp['PROJECT_TITLE'].str.contains(r'\bLegume'))|
           (temp['ABSTRACT'].str.contains(r'\blentil') | temp['PROJECT_TERMS'].str.contains(r'\blentil')| 
           temp['PROJECT_TITLE'].str.contains(r'\blentil') |temp['ABSTRACT'].str.contains(r'\bLentil') | 
           temp['PROJECT_TERMS'].str.contains(r'\bLentil')| temp['PROJECT_TITLE'].str.contains(r'\bLentil')) |
           (temp['ABSTRACT'].str.contains(r'\bedamame\b') | temp['PROJECT_TERMS'].str.contains(r'\bedamame\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bedamame\b') |temp['ABSTRACT'].str.contains(r'\bEdamame\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bEdamame\b')| temp['PROJECT_TITLE'].str.contains(r'\bEdamame\b'))|
          ((temp['ABSTRACT'].str.contains(r'\bbean') | temp['PROJECT_TERMS'].str.contains(r'\bbean')| 
           temp['PROJECT_TITLE'].str.contains(r'\bbean') |temp['ABSTRACT'].str.contains(r'\bbean') | 
           temp['PROJECT_TERMS'].str.contains(r'\bbean')| temp['PROJECT_TITLE'].str.contains(r'\bbean'))&
           ((temp['ABSTRACT'].str.contains(r'\bsoybean')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bsoybean')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bsoybean')==False) |(temp['ABSTRACT'].str.contains(r'\bSoybean')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bSoybean')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bSoybean')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bsoy')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bsoy')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bsoy')==False) |(temp['ABSTRACT'].str.contains(r'\bSoy')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bSoy')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bSoy')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bgreen bean')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bgreen bean')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bgreen bean')==False) |(temp['ABSTRACT'].str.contains(r'\bGreen bean')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bGreen bean')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bGreen bean')==False))) |
          ((temp['ABSTRACT'].str.contains(r'\bnut\b') | temp['PROJECT_TERMS'].str.contains(r'\bnut\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bnut\b') |temp['ABSTRACT'].str.contains(r'\bNut\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bNut\b')| temp['PROJECT_TITLE'].str.contains(r'\bNut\b'))|
           (temp['ABSTRACT'].str.contains(r'\bnuts\b') | temp['PROJECT_TERMS'].str.contains(r'\bnuts\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bnuts\b') |temp['ABSTRACT'].str.contains(r'\bNuts\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bNuts\b')| temp['PROJECT_TITLE'].str.contains(r'\bNuts\b'))&
           ((temp['ABSTRACT'].str.contains(r'\bpeanut')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bpeanut')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bpeanut')==False) |(temp['ABSTRACT'].str.contains(r'\bPeanut')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bPeanut')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bPeanut')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bpeanuts')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bpeanuts')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bpeanuts')==False) |(temp['ABSTRACT'].str.contains(r'\bPeanuts')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bPeanuts')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bPeanuts')==False))|
           (temp['ABSTRACT'].str.contains(r'\bhazelnuts\b') | temp['PROJECT_TERMS'].str.contains(r'\bhazelnuts\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bHazelnuts\b') |temp['ABSTRACT'].str.contains(r'\bhazelnuts\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bHazelnuts\b')| temp['PROJECT_TITLE'].str.contains(r'\bHazelnuts\b'))|
           (temp['ABSTRACT'].str.contains(r'\bchickpea\b') | temp['PROJECT_TERMS'].str.contains(r'\bchickpea\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bchickpea\b') |temp['ABSTRACT'].str.contains(r'\bChickpea\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bChickpea\b')| temp['PROJECT_TITLE'].str.contains(r'\bChickpea\b'))|
           (temp['ABSTRACT'].str.contains(r'\bpea\b') | temp['PROJECT_TERMS'].str.contains(r'\bpea\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bpea\b') |temp['ABSTRACT'].str.contains(r'\bPea\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bPea\b')| temp['PROJECT_TITLE'].str.contains(r'\bPea\b')) &
           ((temp['ABSTRACT'].str.contains(r'\bgreen pea\b')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bgreen pea\b')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bgreen p\b')==False) |(temp['ABSTRACT'].str.contains(r'\bGreen pea\b')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bGreen pea\b')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bGreen pea\b')==False)))]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)


df_abs=pd.read_csv('abstract/PRJABS_2001.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2001.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[(temp['ABSTRACT'].str.contains(r'\blegume') | temp['PROJECT_TERMS'].str.contains(r'\blegume')| 
           temp['PROJECT_TITLE'].str.contains(r'\blegume') |temp['ABSTRACT'].str.contains(r'\bLegume') | 
           temp['PROJECT_TERMS'].str.contains(r'\bLegume')| temp['PROJECT_TITLE'].str.contains(r'\bLegume'))|
           (temp['ABSTRACT'].str.contains(r'\blentil') | temp['PROJECT_TERMS'].str.contains(r'\blentil')| 
           temp['PROJECT_TITLE'].str.contains(r'\blentil') |temp['ABSTRACT'].str.contains(r'\bLentil') | 
           temp['PROJECT_TERMS'].str.contains(r'\bLentil')| temp['PROJECT_TITLE'].str.contains(r'\bLentil')) |
           (temp['ABSTRACT'].str.contains(r'\bedamame\b') | temp['PROJECT_TERMS'].str.contains(r'\bedamame\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bedamame\b') |temp['ABSTRACT'].str.contains(r'\bEdamame\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bEdamame\b')| temp['PROJECT_TITLE'].str.contains(r'\bEdamame\b'))|
          ((temp['ABSTRACT'].str.contains(r'\bbean') | temp['PROJECT_TERMS'].str.contains(r'\bbean')| 
           temp['PROJECT_TITLE'].str.contains(r'\bbean') |temp['ABSTRACT'].str.contains(r'\bbean') | 
           temp['PROJECT_TERMS'].str.contains(r'\bbean')| temp['PROJECT_TITLE'].str.contains(r'\bbean'))&
           ((temp['ABSTRACT'].str.contains(r'\bsoybean')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bsoybean')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bsoybean')==False) |(temp['ABSTRACT'].str.contains(r'\bSoybean')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bSoybean')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bSoybean')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bsoy')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bsoy')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bsoy')==False) |(temp['ABSTRACT'].str.contains(r'\bSoy')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bSoy')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bSoy')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bgreen bean')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bgreen bean')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bgreen bean')==False) |(temp['ABSTRACT'].str.contains(r'\bGreen bean')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bGreen bean')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bGreen bean')==False))) |
          ((temp['ABSTRACT'].str.contains(r'\bnut\b') | temp['PROJECT_TERMS'].str.contains(r'\bnut\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bnut\b') |temp['ABSTRACT'].str.contains(r'\bNut\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bNut\b')| temp['PROJECT_TITLE'].str.contains(r'\bNut\b'))|
           (temp['ABSTRACT'].str.contains(r'\bnuts\b') | temp['PROJECT_TERMS'].str.contains(r'\bnuts\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bnuts\b') |temp['ABSTRACT'].str.contains(r'\bNuts\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bNuts\b')| temp['PROJECT_TITLE'].str.contains(r'\bNuts\b'))&
           ((temp['ABSTRACT'].str.contains(r'\bpeanut')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bpeanut')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bpeanut')==False) |(temp['ABSTRACT'].str.contains(r'\bPeanut')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bPeanut')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bPeanut')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bpeanuts')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bpeanuts')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bpeanuts')==False) |(temp['ABSTRACT'].str.contains(r'\bPeanuts')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bPeanuts')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bPeanuts')==False))|
           (temp['ABSTRACT'].str.contains(r'\bhazelnuts\b') | temp['PROJECT_TERMS'].str.contains(r'\bhazelnuts\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bHazelnuts\b') |temp['ABSTRACT'].str.contains(r'\bhazelnuts\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bHazelnuts\b')| temp['PROJECT_TITLE'].str.contains(r'\bHazelnuts\b'))|
           (temp['ABSTRACT'].str.contains(r'\bchickpea\b') | temp['PROJECT_TERMS'].str.contains(r'\bchickpea\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bchickpea\b') |temp['ABSTRACT'].str.contains(r'\bChickpea\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bChickpea\b')| temp['PROJECT_TITLE'].str.contains(r'\bChickpea\b'))|
           (temp['ABSTRACT'].str.contains(r'\bpea\b') | temp['PROJECT_TERMS'].str.contains(r'\bpea\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bpea\b') |temp['ABSTRACT'].str.contains(r'\bPea\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bPea\b')| temp['PROJECT_TITLE'].str.contains(r'\bPea\b')) &
           ((temp['ABSTRACT'].str.contains(r'\bgreen pea\b')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bgreen pea\b')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bgreen p\b')==False) |(temp['ABSTRACT'].str.contains(r'\bGreen pea\b')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bGreen pea\b')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bGreen pea\b')==False)))]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)



df_abs=pd.read_csv('abstract/PRJABS_2002.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2002.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[(temp['ABSTRACT'].str.contains(r'\blegume') | temp['PROJECT_TERMS'].str.contains(r'\blegume')| 
           temp['PROJECT_TITLE'].str.contains(r'\blegume') |temp['ABSTRACT'].str.contains(r'\bLegume') | 
           temp['PROJECT_TERMS'].str.contains(r'\bLegume')| temp['PROJECT_TITLE'].str.contains(r'\bLegume'))|
           (temp['ABSTRACT'].str.contains(r'\blentil') | temp['PROJECT_TERMS'].str.contains(r'\blentil')| 
           temp['PROJECT_TITLE'].str.contains(r'\blentil') |temp['ABSTRACT'].str.contains(r'\bLentil') | 
           temp['PROJECT_TERMS'].str.contains(r'\bLentil')| temp['PROJECT_TITLE'].str.contains(r'\bLentil')) |
           (temp['ABSTRACT'].str.contains(r'\bedamame\b') | temp['PROJECT_TERMS'].str.contains(r'\bedamame\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bedamame\b') |temp['ABSTRACT'].str.contains(r'\bEdamame\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bEdamame\b')| temp['PROJECT_TITLE'].str.contains(r'\bEdamame\b'))|
          ((temp['ABSTRACT'].str.contains(r'\bbean') | temp['PROJECT_TERMS'].str.contains(r'\bbean')| 
           temp['PROJECT_TITLE'].str.contains(r'\bbean') |temp['ABSTRACT'].str.contains(r'\bbean') | 
           temp['PROJECT_TERMS'].str.contains(r'\bbean')| temp['PROJECT_TITLE'].str.contains(r'\bbean'))&
           ((temp['ABSTRACT'].str.contains(r'\bsoybean')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bsoybean')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bsoybean')==False) |(temp['ABSTRACT'].str.contains(r'\bSoybean')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bSoybean')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bSoybean')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bsoy')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bsoy')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bsoy')==False) |(temp['ABSTRACT'].str.contains(r'\bSoy')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bSoy')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bSoy')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bgreen bean')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bgreen bean')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bgreen bean')==False) |(temp['ABSTRACT'].str.contains(r'\bGreen bean')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bGreen bean')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bGreen bean')==False))) |
          ((temp['ABSTRACT'].str.contains(r'\bnut\b') | temp['PROJECT_TERMS'].str.contains(r'\bnut\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bnut\b') |temp['ABSTRACT'].str.contains(r'\bNut\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bNut\b')| temp['PROJECT_TITLE'].str.contains(r'\bNut\b'))|
           (temp['ABSTRACT'].str.contains(r'\bnuts\b') | temp['PROJECT_TERMS'].str.contains(r'\bnuts\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bnuts\b') |temp['ABSTRACT'].str.contains(r'\bNuts\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bNuts\b')| temp['PROJECT_TITLE'].str.contains(r'\bNuts\b'))&
           ((temp['ABSTRACT'].str.contains(r'\bpeanut')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bpeanut')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bpeanut')==False) |(temp['ABSTRACT'].str.contains(r'\bPeanut')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bPeanut')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bPeanut')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bpeanuts')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bpeanuts')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bpeanuts')==False) |(temp['ABSTRACT'].str.contains(r'\bPeanuts')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bPeanuts')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bPeanuts')==False))|
           (temp['ABSTRACT'].str.contains(r'\bhazelnuts\b') | temp['PROJECT_TERMS'].str.contains(r'\bhazelnuts\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bHazelnuts\b') |temp['ABSTRACT'].str.contains(r'\bhazelnuts\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bHazelnuts\b')| temp['PROJECT_TITLE'].str.contains(r'\bHazelnuts\b'))|
           (temp['ABSTRACT'].str.contains(r'\bchickpea\b') | temp['PROJECT_TERMS'].str.contains(r'\bchickpea\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bchickpea\b') |temp['ABSTRACT'].str.contains(r'\bChickpea\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bChickpea\b')| temp['PROJECT_TITLE'].str.contains(r'\bChickpea\b'))|
           (temp['ABSTRACT'].str.contains(r'\bpea\b') | temp['PROJECT_TERMS'].str.contains(r'\bpea\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bpea\b') |temp['ABSTRACT'].str.contains(r'\bPea\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bPea\b')| temp['PROJECT_TITLE'].str.contains(r'\bPea\b')) &
           ((temp['ABSTRACT'].str.contains(r'\bgreen pea\b')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bgreen pea\b')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bgreen p\b')==False) |(temp['ABSTRACT'].str.contains(r'\bGreen pea\b')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bGreen pea\b')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bGreen pea\b')==False)))]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)


df_abs=pd.read_csv('abstract/PRJABS_2003.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2003.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[(temp['ABSTRACT'].str.contains(r'\blegume') | temp['PROJECT_TERMS'].str.contains(r'\blegume')| 
           temp['PROJECT_TITLE'].str.contains(r'\blegume') |temp['ABSTRACT'].str.contains(r'\bLegume') | 
           temp['PROJECT_TERMS'].str.contains(r'\bLegume')| temp['PROJECT_TITLE'].str.contains(r'\bLegume'))|
           (temp['ABSTRACT'].str.contains(r'\blentil') | temp['PROJECT_TERMS'].str.contains(r'\blentil')| 
           temp['PROJECT_TITLE'].str.contains(r'\blentil') |temp['ABSTRACT'].str.contains(r'\bLentil') | 
           temp['PROJECT_TERMS'].str.contains(r'\bLentil')| temp['PROJECT_TITLE'].str.contains(r'\bLentil')) |
           (temp['ABSTRACT'].str.contains(r'\bedamame\b') | temp['PROJECT_TERMS'].str.contains(r'\bedamame\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bedamame\b') |temp['ABSTRACT'].str.contains(r'\bEdamame\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bEdamame\b')| temp['PROJECT_TITLE'].str.contains(r'\bEdamame\b'))|
          ((temp['ABSTRACT'].str.contains(r'\bbean') | temp['PROJECT_TERMS'].str.contains(r'\bbean')| 
           temp['PROJECT_TITLE'].str.contains(r'\bbean') |temp['ABSTRACT'].str.contains(r'\bbean') | 
           temp['PROJECT_TERMS'].str.contains(r'\bbean')| temp['PROJECT_TITLE'].str.contains(r'\bbean'))&
           ((temp['ABSTRACT'].str.contains(r'\bsoybean')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bsoybean')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bsoybean')==False) |(temp['ABSTRACT'].str.contains(r'\bSoybean')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bSoybean')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bSoybean')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bsoy')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bsoy')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bsoy')==False) |(temp['ABSTRACT'].str.contains(r'\bSoy')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bSoy')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bSoy')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bgreen bean')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bgreen bean')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bgreen bean')==False) |(temp['ABSTRACT'].str.contains(r'\bGreen bean')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bGreen bean')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bGreen bean')==False))) |
          ((temp['ABSTRACT'].str.contains(r'\bnut\b') | temp['PROJECT_TERMS'].str.contains(r'\bnut\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bnut\b') |temp['ABSTRACT'].str.contains(r'\bNut\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bNut\b')| temp['PROJECT_TITLE'].str.contains(r'\bNut\b'))|
           (temp['ABSTRACT'].str.contains(r'\bnuts\b') | temp['PROJECT_TERMS'].str.contains(r'\bnuts\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bnuts\b') |temp['ABSTRACT'].str.contains(r'\bNuts\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bNuts\b')| temp['PROJECT_TITLE'].str.contains(r'\bNuts\b'))&
           ((temp['ABSTRACT'].str.contains(r'\bpeanut')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bpeanut')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bpeanut')==False) |(temp['ABSTRACT'].str.contains(r'\bPeanut')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bPeanut')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bPeanut')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bpeanuts')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bpeanuts')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bpeanuts')==False) |(temp['ABSTRACT'].str.contains(r'\bPeanuts')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bPeanuts')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bPeanuts')==False))|
           (temp['ABSTRACT'].str.contains(r'\bhazelnuts\b') | temp['PROJECT_TERMS'].str.contains(r'\bhazelnuts\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bHazelnuts\b') |temp['ABSTRACT'].str.contains(r'\bhazelnuts\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bHazelnuts\b')| temp['PROJECT_TITLE'].str.contains(r'\bHazelnuts\b'))|
           (temp['ABSTRACT'].str.contains(r'\bchickpea\b') | temp['PROJECT_TERMS'].str.contains(r'\bchickpea\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bchickpea\b') |temp['ABSTRACT'].str.contains(r'\bChickpea\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bChickpea\b')| temp['PROJECT_TITLE'].str.contains(r'\bChickpea\b'))|
           (temp['ABSTRACT'].str.contains(r'\bpea\b') | temp['PROJECT_TERMS'].str.contains(r'\bpea\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bpea\b') |temp['ABSTRACT'].str.contains(r'\bPea\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bPea\b')| temp['PROJECT_TITLE'].str.contains(r'\bPea\b')) &
           ((temp['ABSTRACT'].str.contains(r'\bgreen pea\b')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bgreen pea\b')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bgreen p\b')==False) |(temp['ABSTRACT'].str.contains(r'\bGreen pea\b')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bGreen pea\b')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bGreen pea\b')==False)))]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)


df_abs=pd.read_csv('abstract/PRJABS_2004.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2004.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[(temp['ABSTRACT'].str.contains(r'\blegume') | temp['PROJECT_TERMS'].str.contains(r'\blegume')| 
           temp['PROJECT_TITLE'].str.contains(r'\blegume') |temp['ABSTRACT'].str.contains(r'\bLegume') | 
           temp['PROJECT_TERMS'].str.contains(r'\bLegume')| temp['PROJECT_TITLE'].str.contains(r'\bLegume'))|
           (temp['ABSTRACT'].str.contains(r'\blentil') | temp['PROJECT_TERMS'].str.contains(r'\blentil')| 
           temp['PROJECT_TITLE'].str.contains(r'\blentil') |temp['ABSTRACT'].str.contains(r'\bLentil') | 
           temp['PROJECT_TERMS'].str.contains(r'\bLentil')| temp['PROJECT_TITLE'].str.contains(r'\bLentil')) |
           (temp['ABSTRACT'].str.contains(r'\bedamame\b') | temp['PROJECT_TERMS'].str.contains(r'\bedamame\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bedamame\b') |temp['ABSTRACT'].str.contains(r'\bEdamame\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bEdamame\b')| temp['PROJECT_TITLE'].str.contains(r'\bEdamame\b'))|
          ((temp['ABSTRACT'].str.contains(r'\bbean') | temp['PROJECT_TERMS'].str.contains(r'\bbean')| 
           temp['PROJECT_TITLE'].str.contains(r'\bbean') |temp['ABSTRACT'].str.contains(r'\bbean') | 
           temp['PROJECT_TERMS'].str.contains(r'\bbean')| temp['PROJECT_TITLE'].str.contains(r'\bbean'))&
           ((temp['ABSTRACT'].str.contains(r'\bsoybean')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bsoybean')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bsoybean')==False) |(temp['ABSTRACT'].str.contains(r'\bSoybean')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bSoybean')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bSoybean')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bsoy')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bsoy')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bsoy')==False) |(temp['ABSTRACT'].str.contains(r'\bSoy')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bSoy')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bSoy')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bgreen bean')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bgreen bean')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bgreen bean')==False) |(temp['ABSTRACT'].str.contains(r'\bGreen bean')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bGreen bean')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bGreen bean')==False))) |
          ((temp['ABSTRACT'].str.contains(r'\bnut\b') | temp['PROJECT_TERMS'].str.contains(r'\bnut\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bnut\b') |temp['ABSTRACT'].str.contains(r'\bNut\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bNut\b')| temp['PROJECT_TITLE'].str.contains(r'\bNut\b'))|
           (temp['ABSTRACT'].str.contains(r'\bnuts\b') | temp['PROJECT_TERMS'].str.contains(r'\bnuts\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bnuts\b') |temp['ABSTRACT'].str.contains(r'\bNuts\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bNuts\b')| temp['PROJECT_TITLE'].str.contains(r'\bNuts\b'))&
           ((temp['ABSTRACT'].str.contains(r'\bpeanut')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bpeanut')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bpeanut')==False) |(temp['ABSTRACT'].str.contains(r'\bPeanut')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bPeanut')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bPeanut')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bpeanuts')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bpeanuts')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bpeanuts')==False) |(temp['ABSTRACT'].str.contains(r'\bPeanuts')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bPeanuts')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bPeanuts')==False))|
           (temp['ABSTRACT'].str.contains(r'\bhazelnuts\b') | temp['PROJECT_TERMS'].str.contains(r'\bhazelnuts\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bHazelnuts\b') |temp['ABSTRACT'].str.contains(r'\bhazelnuts\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bHazelnuts\b')| temp['PROJECT_TITLE'].str.contains(r'\bHazelnuts\b'))|
           (temp['ABSTRACT'].str.contains(r'\bchickpea\b') | temp['PROJECT_TERMS'].str.contains(r'\bchickpea\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bchickpea\b') |temp['ABSTRACT'].str.contains(r'\bChickpea\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bChickpea\b')| temp['PROJECT_TITLE'].str.contains(r'\bChickpea\b'))|
           (temp['ABSTRACT'].str.contains(r'\bpea\b') | temp['PROJECT_TERMS'].str.contains(r'\bpea\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bpea\b') |temp['ABSTRACT'].str.contains(r'\bPea\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bPea\b')| temp['PROJECT_TITLE'].str.contains(r'\bPea\b')) &
           ((temp['ABSTRACT'].str.contains(r'\bgreen pea\b')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bgreen pea\b')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bgreen p\b')==False) |(temp['ABSTRACT'].str.contains(r'\bGreen pea\b')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bGreen pea\b')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bGreen pea\b')==False)))]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2005.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2005.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[(temp['ABSTRACT'].str.contains(r'\blegume') | temp['PROJECT_TERMS'].str.contains(r'\blegume')| 
           temp['PROJECT_TITLE'].str.contains(r'\blegume') |temp['ABSTRACT'].str.contains(r'\bLegume') | 
           temp['PROJECT_TERMS'].str.contains(r'\bLegume')| temp['PROJECT_TITLE'].str.contains(r'\bLegume'))|
           (temp['ABSTRACT'].str.contains(r'\blentil') | temp['PROJECT_TERMS'].str.contains(r'\blentil')| 
           temp['PROJECT_TITLE'].str.contains(r'\blentil') |temp['ABSTRACT'].str.contains(r'\bLentil') | 
           temp['PROJECT_TERMS'].str.contains(r'\bLentil')| temp['PROJECT_TITLE'].str.contains(r'\bLentil')) |
           (temp['ABSTRACT'].str.contains(r'\bedamame\b') | temp['PROJECT_TERMS'].str.contains(r'\bedamame\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bedamame\b') |temp['ABSTRACT'].str.contains(r'\bEdamame\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bEdamame\b')| temp['PROJECT_TITLE'].str.contains(r'\bEdamame\b'))|
          ((temp['ABSTRACT'].str.contains(r'\bbean') | temp['PROJECT_TERMS'].str.contains(r'\bbean')| 
           temp['PROJECT_TITLE'].str.contains(r'\bbean') |temp['ABSTRACT'].str.contains(r'\bbean') | 
           temp['PROJECT_TERMS'].str.contains(r'\bbean')| temp['PROJECT_TITLE'].str.contains(r'\bbean'))&
           ((temp['ABSTRACT'].str.contains(r'\bsoybean')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bsoybean')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bsoybean')==False) |(temp['ABSTRACT'].str.contains(r'\bSoybean')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bSoybean')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bSoybean')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bsoy')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bsoy')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bsoy')==False) |(temp['ABSTRACT'].str.contains(r'\bSoy')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bSoy')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bSoy')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bgreen bean')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bgreen bean')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bgreen bean')==False) |(temp['ABSTRACT'].str.contains(r'\bGreen bean')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bGreen bean')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bGreen bean')==False))) |
          ((temp['ABSTRACT'].str.contains(r'\bnut\b') | temp['PROJECT_TERMS'].str.contains(r'\bnut\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bnut\b') |temp['ABSTRACT'].str.contains(r'\bNut\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bNut\b')| temp['PROJECT_TITLE'].str.contains(r'\bNut\b'))|
           (temp['ABSTRACT'].str.contains(r'\bnuts\b') | temp['PROJECT_TERMS'].str.contains(r'\bnuts\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bnuts\b') |temp['ABSTRACT'].str.contains(r'\bNuts\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bNuts\b')| temp['PROJECT_TITLE'].str.contains(r'\bNuts\b'))&
           ((temp['ABSTRACT'].str.contains(r'\bpeanut')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bpeanut')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bpeanut')==False) |(temp['ABSTRACT'].str.contains(r'\bPeanut')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bPeanut')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bPeanut')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bpeanuts')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bpeanuts')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bpeanuts')==False) |(temp['ABSTRACT'].str.contains(r'\bPeanuts')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bPeanuts')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bPeanuts')==False))|
           (temp['ABSTRACT'].str.contains(r'\bhazelnuts\b') | temp['PROJECT_TERMS'].str.contains(r'\bhazelnuts\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bHazelnuts\b') |temp['ABSTRACT'].str.contains(r'\bhazelnuts\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bHazelnuts\b')| temp['PROJECT_TITLE'].str.contains(r'\bHazelnuts\b'))|
           (temp['ABSTRACT'].str.contains(r'\bchickpea\b') | temp['PROJECT_TERMS'].str.contains(r'\bchickpea\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bchickpea\b') |temp['ABSTRACT'].str.contains(r'\bChickpea\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bChickpea\b')| temp['PROJECT_TITLE'].str.contains(r'\bChickpea\b'))|
           (temp['ABSTRACT'].str.contains(r'\bpea\b') | temp['PROJECT_TERMS'].str.contains(r'\bpea\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bpea\b') |temp['ABSTRACT'].str.contains(r'\bPea\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bPea\b')| temp['PROJECT_TITLE'].str.contains(r'\bPea\b')) &
           ((temp['ABSTRACT'].str.contains(r'\bgreen pea\b')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bgreen pea\b')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bgreen p\b')==False) |(temp['ABSTRACT'].str.contains(r'\bGreen pea\b')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bGreen pea\b')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bGreen pea\b')==False)))]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)


df_abs=pd.read_csv('abstract/PRJABS_2006.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2006.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[(temp['ABSTRACT'].str.contains(r'\blegume') | temp['PROJECT_TERMS'].str.contains(r'\blegume')| 
           temp['PROJECT_TITLE'].str.contains(r'\blegume') |temp['ABSTRACT'].str.contains(r'\bLegume') | 
           temp['PROJECT_TERMS'].str.contains(r'\bLegume')| temp['PROJECT_TITLE'].str.contains(r'\bLegume'))|
           (temp['ABSTRACT'].str.contains(r'\blentil') | temp['PROJECT_TERMS'].str.contains(r'\blentil')| 
           temp['PROJECT_TITLE'].str.contains(r'\blentil') |temp['ABSTRACT'].str.contains(r'\bLentil') | 
           temp['PROJECT_TERMS'].str.contains(r'\bLentil')| temp['PROJECT_TITLE'].str.contains(r'\bLentil')) |
           (temp['ABSTRACT'].str.contains(r'\bedamame\b') | temp['PROJECT_TERMS'].str.contains(r'\bedamame\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bedamame\b') |temp['ABSTRACT'].str.contains(r'\bEdamame\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bEdamame\b')| temp['PROJECT_TITLE'].str.contains(r'\bEdamame\b'))|
          ((temp['ABSTRACT'].str.contains(r'\bbean') | temp['PROJECT_TERMS'].str.contains(r'\bbean')| 
           temp['PROJECT_TITLE'].str.contains(r'\bbean') |temp['ABSTRACT'].str.contains(r'\bbean') | 
           temp['PROJECT_TERMS'].str.contains(r'\bbean')| temp['PROJECT_TITLE'].str.contains(r'\bbean'))&
           ((temp['ABSTRACT'].str.contains(r'\bsoybean')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bsoybean')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bsoybean')==False) |(temp['ABSTRACT'].str.contains(r'\bSoybean')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bSoybean')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bSoybean')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bsoy')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bsoy')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bsoy')==False) |(temp['ABSTRACT'].str.contains(r'\bSoy')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bSoy')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bSoy')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bgreen bean')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bgreen bean')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bgreen bean')==False) |(temp['ABSTRACT'].str.contains(r'\bGreen bean')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bGreen bean')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bGreen bean')==False))) |
          ((temp['ABSTRACT'].str.contains(r'\bnut\b') | temp['PROJECT_TERMS'].str.contains(r'\bnut\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bnut\b') |temp['ABSTRACT'].str.contains(r'\bNut\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bNut\b')| temp['PROJECT_TITLE'].str.contains(r'\bNut\b'))|
           (temp['ABSTRACT'].str.contains(r'\bnuts\b') | temp['PROJECT_TERMS'].str.contains(r'\bnuts\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bnuts\b') |temp['ABSTRACT'].str.contains(r'\bNuts\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bNuts\b')| temp['PROJECT_TITLE'].str.contains(r'\bNuts\b'))&
           ((temp['ABSTRACT'].str.contains(r'\bpeanut')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bpeanut')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bpeanut')==False) |(temp['ABSTRACT'].str.contains(r'\bPeanut')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bPeanut')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bPeanut')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bpeanuts')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bpeanuts')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bpeanuts')==False) |(temp['ABSTRACT'].str.contains(r'\bPeanuts')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bPeanuts')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bPeanuts')==False))|
           (temp['ABSTRACT'].str.contains(r'\bhazelnuts\b') | temp['PROJECT_TERMS'].str.contains(r'\bhazelnuts\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bHazelnuts\b') |temp['ABSTRACT'].str.contains(r'\bhazelnuts\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bHazelnuts\b')| temp['PROJECT_TITLE'].str.contains(r'\bHazelnuts\b'))|
           (temp['ABSTRACT'].str.contains(r'\bchickpea\b') | temp['PROJECT_TERMS'].str.contains(r'\bchickpea\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bchickpea\b') |temp['ABSTRACT'].str.contains(r'\bChickpea\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bChickpea\b')| temp['PROJECT_TITLE'].str.contains(r'\bChickpea\b'))|
           (temp['ABSTRACT'].str.contains(r'\bpea\b') | temp['PROJECT_TERMS'].str.contains(r'\bpea\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bpea\b') |temp['ABSTRACT'].str.contains(r'\bPea\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bPea\b')| temp['PROJECT_TITLE'].str.contains(r'\bPea\b')) &
           ((temp['ABSTRACT'].str.contains(r'\bgreen pea\b')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bgreen pea\b')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bgreen p\b')==False) |(temp['ABSTRACT'].str.contains(r'\bGreen pea\b')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bGreen pea\b')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bGreen pea\b')==False)))]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)



df_abs=pd.read_csv('abstract/PRJABS_2007.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2007.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[(temp['ABSTRACT'].str.contains(r'\blegume') | temp['PROJECT_TERMS'].str.contains(r'\blegume')| 
           temp['PROJECT_TITLE'].str.contains(r'\blegume') |temp['ABSTRACT'].str.contains(r'\bLegume') | 
           temp['PROJECT_TERMS'].str.contains(r'\bLegume')| temp['PROJECT_TITLE'].str.contains(r'\bLegume'))|
           (temp['ABSTRACT'].str.contains(r'\blentil') | temp['PROJECT_TERMS'].str.contains(r'\blentil')| 
           temp['PROJECT_TITLE'].str.contains(r'\blentil') |temp['ABSTRACT'].str.contains(r'\bLentil') | 
           temp['PROJECT_TERMS'].str.contains(r'\bLentil')| temp['PROJECT_TITLE'].str.contains(r'\bLentil')) |
           (temp['ABSTRACT'].str.contains(r'\bedamame\b') | temp['PROJECT_TERMS'].str.contains(r'\bedamame\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bedamame\b') |temp['ABSTRACT'].str.contains(r'\bEdamame\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bEdamame\b')| temp['PROJECT_TITLE'].str.contains(r'\bEdamame\b'))|
          ((temp['ABSTRACT'].str.contains(r'\bbean') | temp['PROJECT_TERMS'].str.contains(r'\bbean')| 
           temp['PROJECT_TITLE'].str.contains(r'\bbean') |temp['ABSTRACT'].str.contains(r'\bbean') | 
           temp['PROJECT_TERMS'].str.contains(r'\bbean')| temp['PROJECT_TITLE'].str.contains(r'\bbean'))&
           ((temp['ABSTRACT'].str.contains(r'\bsoybean')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bsoybean')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bsoybean')==False) |(temp['ABSTRACT'].str.contains(r'\bSoybean')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bSoybean')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bSoybean')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bsoy')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bsoy')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bsoy')==False) |(temp['ABSTRACT'].str.contains(r'\bSoy')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bSoy')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bSoy')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bgreen bean')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bgreen bean')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bgreen bean')==False) |(temp['ABSTRACT'].str.contains(r'\bGreen bean')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bGreen bean')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bGreen bean')==False))) |
          ((temp['ABSTRACT'].str.contains(r'\bnut\b') | temp['PROJECT_TERMS'].str.contains(r'\bnut\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bnut\b') |temp['ABSTRACT'].str.contains(r'\bNut\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bNut\b')| temp['PROJECT_TITLE'].str.contains(r'\bNut\b'))|
           (temp['ABSTRACT'].str.contains(r'\bnuts\b') | temp['PROJECT_TERMS'].str.contains(r'\bnuts\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bnuts\b') |temp['ABSTRACT'].str.contains(r'\bNuts\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bNuts\b')| temp['PROJECT_TITLE'].str.contains(r'\bNuts\b'))&
           ((temp['ABSTRACT'].str.contains(r'\bpeanut')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bpeanut')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bpeanut')==False) |(temp['ABSTRACT'].str.contains(r'\bPeanut')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bPeanut')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bPeanut')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bpeanuts')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bpeanuts')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bpeanuts')==False) |(temp['ABSTRACT'].str.contains(r'\bPeanuts')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bPeanuts')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bPeanuts')==False))|
           (temp['ABSTRACT'].str.contains(r'\bhazelnuts\b') | temp['PROJECT_TERMS'].str.contains(r'\bhazelnuts\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bHazelnuts\b') |temp['ABSTRACT'].str.contains(r'\bhazelnuts\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bHazelnuts\b')| temp['PROJECT_TITLE'].str.contains(r'\bHazelnuts\b'))|
           (temp['ABSTRACT'].str.contains(r'\bchickpea\b') | temp['PROJECT_TERMS'].str.contains(r'\bchickpea\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bchickpea\b') |temp['ABSTRACT'].str.contains(r'\bChickpea\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bChickpea\b')| temp['PROJECT_TITLE'].str.contains(r'\bChickpea\b'))|
           (temp['ABSTRACT'].str.contains(r'\bpea\b') | temp['PROJECT_TERMS'].str.contains(r'\bpea\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bpea\b') |temp['ABSTRACT'].str.contains(r'\bPea\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bPea\b')| temp['PROJECT_TITLE'].str.contains(r'\bPea\b')) &
           ((temp['ABSTRACT'].str.contains(r'\bgreen pea\b')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bgreen pea\b')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bgreen p\b')==False) |(temp['ABSTRACT'].str.contains(r'\bGreen pea\b')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bGreen pea\b')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bGreen pea\b')==False)))]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)


df_abs=pd.read_csv('abstract/PRJABS_2008.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2008.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[(temp['ABSTRACT'].str.contains(r'\blegume') | temp['PROJECT_TERMS'].str.contains(r'\blegume')| 
           temp['PROJECT_TITLE'].str.contains(r'\blegume') |temp['ABSTRACT'].str.contains(r'\bLegume') | 
           temp['PROJECT_TERMS'].str.contains(r'\bLegume')| temp['PROJECT_TITLE'].str.contains(r'\bLegume'))|
           (temp['ABSTRACT'].str.contains(r'\blentil') | temp['PROJECT_TERMS'].str.contains(r'\blentil')| 
           temp['PROJECT_TITLE'].str.contains(r'\blentil') |temp['ABSTRACT'].str.contains(r'\bLentil') | 
           temp['PROJECT_TERMS'].str.contains(r'\bLentil')| temp['PROJECT_TITLE'].str.contains(r'\bLentil')) |
           (temp['ABSTRACT'].str.contains(r'\bedamame\b') | temp['PROJECT_TERMS'].str.contains(r'\bedamame\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bedamame\b') |temp['ABSTRACT'].str.contains(r'\bEdamame\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bEdamame\b')| temp['PROJECT_TITLE'].str.contains(r'\bEdamame\b'))|
          ((temp['ABSTRACT'].str.contains(r'\bbean') | temp['PROJECT_TERMS'].str.contains(r'\bbean')| 
           temp['PROJECT_TITLE'].str.contains(r'\bbean') |temp['ABSTRACT'].str.contains(r'\bbean') | 
           temp['PROJECT_TERMS'].str.contains(r'\bbean')| temp['PROJECT_TITLE'].str.contains(r'\bbean'))&
           ((temp['ABSTRACT'].str.contains(r'\bsoybean')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bsoybean')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bsoybean')==False) |(temp['ABSTRACT'].str.contains(r'\bSoybean')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bSoybean')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bSoybean')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bsoy')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bsoy')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bsoy')==False) |(temp['ABSTRACT'].str.contains(r'\bSoy')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bSoy')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bSoy')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bgreen bean')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bgreen bean')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bgreen bean')==False) |(temp['ABSTRACT'].str.contains(r'\bGreen bean')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bGreen bean')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bGreen bean')==False))) |
          ((temp['ABSTRACT'].str.contains(r'\bnut\b') | temp['PROJECT_TERMS'].str.contains(r'\bnut\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bnut\b') |temp['ABSTRACT'].str.contains(r'\bNut\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bNut\b')| temp['PROJECT_TITLE'].str.contains(r'\bNut\b'))|
           (temp['ABSTRACT'].str.contains(r'\bnuts\b') | temp['PROJECT_TERMS'].str.contains(r'\bnuts\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bnuts\b') |temp['ABSTRACT'].str.contains(r'\bNuts\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bNuts\b')| temp['PROJECT_TITLE'].str.contains(r'\bNuts\b'))&
           ((temp['ABSTRACT'].str.contains(r'\bpeanut')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bpeanut')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bpeanut')==False) |(temp['ABSTRACT'].str.contains(r'\bPeanut')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bPeanut')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bPeanut')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bpeanuts')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bpeanuts')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bpeanuts')==False) |(temp['ABSTRACT'].str.contains(r'\bPeanuts')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bPeanuts')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bPeanuts')==False))|
           (temp['ABSTRACT'].str.contains(r'\bhazelnuts\b') | temp['PROJECT_TERMS'].str.contains(r'\bhazelnuts\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bHazelnuts\b') |temp['ABSTRACT'].str.contains(r'\bhazelnuts\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bHazelnuts\b')| temp['PROJECT_TITLE'].str.contains(r'\bHazelnuts\b'))|
           (temp['ABSTRACT'].str.contains(r'\bchickpea\b') | temp['PROJECT_TERMS'].str.contains(r'\bchickpea\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bchickpea\b') |temp['ABSTRACT'].str.contains(r'\bChickpea\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bChickpea\b')| temp['PROJECT_TITLE'].str.contains(r'\bChickpea\b'))|
           (temp['ABSTRACT'].str.contains(r'\bpea\b') | temp['PROJECT_TERMS'].str.contains(r'\bpea\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bpea\b') |temp['ABSTRACT'].str.contains(r'\bPea\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bPea\b')| temp['PROJECT_TITLE'].str.contains(r'\bPea\b')) &
           ((temp['ABSTRACT'].str.contains(r'\bgreen pea\b')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bgreen pea\b')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bgreen p\b')==False) |(temp['ABSTRACT'].str.contains(r'\bGreen pea\b')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bGreen pea\b')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bGreen pea\b')==False)))]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)


df_abs=pd.read_csv('abstract/PRJABS_2009.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2009.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[(temp['ABSTRACT'].str.contains(r'\blegume') | temp['PROJECT_TERMS'].str.contains(r'\blegume')| 
           temp['PROJECT_TITLE'].str.contains(r'\blegume') |temp['ABSTRACT'].str.contains(r'\bLegume') | 
           temp['PROJECT_TERMS'].str.contains(r'\bLegume')| temp['PROJECT_TITLE'].str.contains(r'\bLegume'))|
           (temp['ABSTRACT'].str.contains(r'\blentil') | temp['PROJECT_TERMS'].str.contains(r'\blentil')| 
           temp['PROJECT_TITLE'].str.contains(r'\blentil') |temp['ABSTRACT'].str.contains(r'\bLentil') | 
           temp['PROJECT_TERMS'].str.contains(r'\bLentil')| temp['PROJECT_TITLE'].str.contains(r'\bLentil')) |
           (temp['ABSTRACT'].str.contains(r'\bedamame\b') | temp['PROJECT_TERMS'].str.contains(r'\bedamame\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bedamame\b') |temp['ABSTRACT'].str.contains(r'\bEdamame\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bEdamame\b')| temp['PROJECT_TITLE'].str.contains(r'\bEdamame\b'))|
          ((temp['ABSTRACT'].str.contains(r'\bbean') | temp['PROJECT_TERMS'].str.contains(r'\bbean')| 
           temp['PROJECT_TITLE'].str.contains(r'\bbean') |temp['ABSTRACT'].str.contains(r'\bbean') | 
           temp['PROJECT_TERMS'].str.contains(r'\bbean')| temp['PROJECT_TITLE'].str.contains(r'\bbean'))&
           ((temp['ABSTRACT'].str.contains(r'\bsoybean')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bsoybean')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bsoybean')==False) |(temp['ABSTRACT'].str.contains(r'\bSoybean')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bSoybean')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bSoybean')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bsoy')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bsoy')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bsoy')==False) |(temp['ABSTRACT'].str.contains(r'\bSoy')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bSoy')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bSoy')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bgreen bean')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bgreen bean')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bgreen bean')==False) |(temp['ABSTRACT'].str.contains(r'\bGreen bean')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bGreen bean')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bGreen bean')==False))) |
          ((temp['ABSTRACT'].str.contains(r'\bnut\b') | temp['PROJECT_TERMS'].str.contains(r'\bnut\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bnut\b') |temp['ABSTRACT'].str.contains(r'\bNut\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bNut\b')| temp['PROJECT_TITLE'].str.contains(r'\bNut\b'))|
           (temp['ABSTRACT'].str.contains(r'\bnuts\b') | temp['PROJECT_TERMS'].str.contains(r'\bnuts\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bnuts\b') |temp['ABSTRACT'].str.contains(r'\bNuts\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bNuts\b')| temp['PROJECT_TITLE'].str.contains(r'\bNuts\b'))&
           ((temp['ABSTRACT'].str.contains(r'\bpeanut')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bpeanut')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bpeanut')==False) |(temp['ABSTRACT'].str.contains(r'\bPeanut')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bPeanut')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bPeanut')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bpeanuts')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bpeanuts')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bpeanuts')==False) |(temp['ABSTRACT'].str.contains(r'\bPeanuts')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bPeanuts')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bPeanuts')==False))|
           (temp['ABSTRACT'].str.contains(r'\bhazelnuts\b') | temp['PROJECT_TERMS'].str.contains(r'\bhazelnuts\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bHazelnuts\b') |temp['ABSTRACT'].str.contains(r'\bhazelnuts\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bHazelnuts\b')| temp['PROJECT_TITLE'].str.contains(r'\bHazelnuts\b'))|
           (temp['ABSTRACT'].str.contains(r'\bchickpea\b') | temp['PROJECT_TERMS'].str.contains(r'\bchickpea\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bchickpea\b') |temp['ABSTRACT'].str.contains(r'\bChickpea\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bChickpea\b')| temp['PROJECT_TITLE'].str.contains(r'\bChickpea\b'))|
           (temp['ABSTRACT'].str.contains(r'\bpea\b') | temp['PROJECT_TERMS'].str.contains(r'\bpea\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bpea\b') |temp['ABSTRACT'].str.contains(r'\bPea\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bPea\b')| temp['PROJECT_TITLE'].str.contains(r'\bPea\b')) &
           ((temp['ABSTRACT'].str.contains(r'\bgreen pea\b')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bgreen pea\b')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bgreen p\b')==False) |(temp['ABSTRACT'].str.contains(r'\bGreen pea\b')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bGreen pea\b')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bGreen pea\b')==False)))]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)


df_abs=pd.read_csv('abstract/PRJABS_2010.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2010.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[(temp['ABSTRACT'].str.contains(r'\blegume') | temp['PROJECT_TERMS'].str.contains(r'\blegume')| 
           temp['PROJECT_TITLE'].str.contains(r'\blegume') |temp['ABSTRACT'].str.contains(r'\bLegume') | 
           temp['PROJECT_TERMS'].str.contains(r'\bLegume')| temp['PROJECT_TITLE'].str.contains(r'\bLegume'))|
           (temp['ABSTRACT'].str.contains(r'\blentil') | temp['PROJECT_TERMS'].str.contains(r'\blentil')| 
           temp['PROJECT_TITLE'].str.contains(r'\blentil') |temp['ABSTRACT'].str.contains(r'\bLentil') | 
           temp['PROJECT_TERMS'].str.contains(r'\bLentil')| temp['PROJECT_TITLE'].str.contains(r'\bLentil')) |
           (temp['ABSTRACT'].str.contains(r'\bedamame\b') | temp['PROJECT_TERMS'].str.contains(r'\bedamame\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bedamame\b') |temp['ABSTRACT'].str.contains(r'\bEdamame\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bEdamame\b')| temp['PROJECT_TITLE'].str.contains(r'\bEdamame\b'))|
          ((temp['ABSTRACT'].str.contains(r'\bbean') | temp['PROJECT_TERMS'].str.contains(r'\bbean')| 
           temp['PROJECT_TITLE'].str.contains(r'\bbean') |temp['ABSTRACT'].str.contains(r'\bbean') | 
           temp['PROJECT_TERMS'].str.contains(r'\bbean')| temp['PROJECT_TITLE'].str.contains(r'\bbean'))&
           ((temp['ABSTRACT'].str.contains(r'\bsoybean')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bsoybean')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bsoybean')==False) |(temp['ABSTRACT'].str.contains(r'\bSoybean')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bSoybean')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bSoybean')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bsoy')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bsoy')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bsoy')==False) |(temp['ABSTRACT'].str.contains(r'\bSoy')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bSoy')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bSoy')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bgreen bean')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bgreen bean')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bgreen bean')==False) |(temp['ABSTRACT'].str.contains(r'\bGreen bean')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bGreen bean')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bGreen bean')==False))) |
          ((temp['ABSTRACT'].str.contains(r'\bnut\b') | temp['PROJECT_TERMS'].str.contains(r'\bnut\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bnut\b') |temp['ABSTRACT'].str.contains(r'\bNut\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bNut\b')| temp['PROJECT_TITLE'].str.contains(r'\bNut\b'))|
           (temp['ABSTRACT'].str.contains(r'\bnuts\b') | temp['PROJECT_TERMS'].str.contains(r'\bnuts\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bnuts\b') |temp['ABSTRACT'].str.contains(r'\bNuts\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bNuts\b')| temp['PROJECT_TITLE'].str.contains(r'\bNuts\b'))&
           ((temp['ABSTRACT'].str.contains(r'\bpeanut')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bpeanut')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bpeanut')==False) |(temp['ABSTRACT'].str.contains(r'\bPeanut')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bPeanut')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bPeanut')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bpeanuts')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bpeanuts')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bpeanuts')==False) |(temp['ABSTRACT'].str.contains(r'\bPeanuts')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bPeanuts')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bPeanuts')==False))|
           (temp['ABSTRACT'].str.contains(r'\bhazelnuts\b') | temp['PROJECT_TERMS'].str.contains(r'\bhazelnuts\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bHazelnuts\b') |temp['ABSTRACT'].str.contains(r'\bhazelnuts\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bHazelnuts\b')| temp['PROJECT_TITLE'].str.contains(r'\bHazelnuts\b'))|
           (temp['ABSTRACT'].str.contains(r'\bchickpea\b') | temp['PROJECT_TERMS'].str.contains(r'\bchickpea\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bchickpea\b') |temp['ABSTRACT'].str.contains(r'\bChickpea\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bChickpea\b')| temp['PROJECT_TITLE'].str.contains(r'\bChickpea\b'))|
           (temp['ABSTRACT'].str.contains(r'\bpea\b') | temp['PROJECT_TERMS'].str.contains(r'\bpea\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bpea\b') |temp['ABSTRACT'].str.contains(r'\bPea\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bPea\b')| temp['PROJECT_TITLE'].str.contains(r'\bPea\b')) &
           ((temp['ABSTRACT'].str.contains(r'\bgreen pea\b')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bgreen pea\b')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bgreen p\b')==False) |(temp['ABSTRACT'].str.contains(r'\bGreen pea\b')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bGreen pea\b')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bGreen pea\b')==False)))]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)


df_abs=pd.read_csv('abstract/PRJABS_2011.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2011.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[(temp['ABSTRACT'].str.contains(r'\blegume') | temp['PROJECT_TERMS'].str.contains(r'\blegume')| 
           temp['PROJECT_TITLE'].str.contains(r'\blegume') |temp['ABSTRACT'].str.contains(r'\bLegume') | 
           temp['PROJECT_TERMS'].str.contains(r'\bLegume')| temp['PROJECT_TITLE'].str.contains(r'\bLegume'))|
           (temp['ABSTRACT'].str.contains(r'\blentil') | temp['PROJECT_TERMS'].str.contains(r'\blentil')| 
           temp['PROJECT_TITLE'].str.contains(r'\blentil') |temp['ABSTRACT'].str.contains(r'\bLentil') | 
           temp['PROJECT_TERMS'].str.contains(r'\bLentil')| temp['PROJECT_TITLE'].str.contains(r'\bLentil')) |
           (temp['ABSTRACT'].str.contains(r'\bedamame\b') | temp['PROJECT_TERMS'].str.contains(r'\bedamame\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bedamame\b') |temp['ABSTRACT'].str.contains(r'\bEdamame\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bEdamame\b')| temp['PROJECT_TITLE'].str.contains(r'\bEdamame\b'))|
          ((temp['ABSTRACT'].str.contains(r'\bbean') | temp['PROJECT_TERMS'].str.contains(r'\bbean')| 
           temp['PROJECT_TITLE'].str.contains(r'\bbean') |temp['ABSTRACT'].str.contains(r'\bbean') | 
           temp['PROJECT_TERMS'].str.contains(r'\bbean')| temp['PROJECT_TITLE'].str.contains(r'\bbean'))&
           ((temp['ABSTRACT'].str.contains(r'\bsoybean')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bsoybean')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bsoybean')==False) |(temp['ABSTRACT'].str.contains(r'\bSoybean')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bSoybean')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bSoybean')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bsoy')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bsoy')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bsoy')==False) |(temp['ABSTRACT'].str.contains(r'\bSoy')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bSoy')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bSoy')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bgreen bean')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bgreen bean')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bgreen bean')==False) |(temp['ABSTRACT'].str.contains(r'\bGreen bean')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bGreen bean')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bGreen bean')==False))) |
          ((temp['ABSTRACT'].str.contains(r'\bnut\b') | temp['PROJECT_TERMS'].str.contains(r'\bnut\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bnut\b') |temp['ABSTRACT'].str.contains(r'\bNut\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bNut\b')| temp['PROJECT_TITLE'].str.contains(r'\bNut\b'))|
           (temp['ABSTRACT'].str.contains(r'\bnuts\b') | temp['PROJECT_TERMS'].str.contains(r'\bnuts\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bnuts\b') |temp['ABSTRACT'].str.contains(r'\bNuts\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bNuts\b')| temp['PROJECT_TITLE'].str.contains(r'\bNuts\b'))&
           ((temp['ABSTRACT'].str.contains(r'\bpeanut')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bpeanut')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bpeanut')==False) |(temp['ABSTRACT'].str.contains(r'\bPeanut')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bPeanut')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bPeanut')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bpeanuts')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bpeanuts')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bpeanuts')==False) |(temp['ABSTRACT'].str.contains(r'\bPeanuts')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bPeanuts')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bPeanuts')==False))|
           (temp['ABSTRACT'].str.contains(r'\bhazelnuts\b') | temp['PROJECT_TERMS'].str.contains(r'\bhazelnuts\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bHazelnuts\b') |temp['ABSTRACT'].str.contains(r'\bhazelnuts\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bHazelnuts\b')| temp['PROJECT_TITLE'].str.contains(r'\bHazelnuts\b'))|
           (temp['ABSTRACT'].str.contains(r'\bchickpea\b') | temp['PROJECT_TERMS'].str.contains(r'\bchickpea\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bchickpea\b') |temp['ABSTRACT'].str.contains(r'\bChickpea\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bChickpea\b')| temp['PROJECT_TITLE'].str.contains(r'\bChickpea\b'))|
           (temp['ABSTRACT'].str.contains(r'\bpea\b') | temp['PROJECT_TERMS'].str.contains(r'\bpea\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bpea\b') |temp['ABSTRACT'].str.contains(r'\bPea\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bPea\b')| temp['PROJECT_TITLE'].str.contains(r'\bPea\b')) &
           ((temp['ABSTRACT'].str.contains(r'\bgreen pea\b')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bgreen pea\b')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bgreen p\b')==False) |(temp['ABSTRACT'].str.contains(r'\bGreen pea\b')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bGreen pea\b')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bGreen pea\b')==False)))]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)


df_abs=pd.read_csv('abstract/PRJABS_2012.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2012.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[(temp['ABSTRACT'].str.contains(r'\blegume') | temp['PROJECT_TERMS'].str.contains(r'\blegume')| 
           temp['PROJECT_TITLE'].str.contains(r'\blegume') |temp['ABSTRACT'].str.contains(r'\bLegume') | 
           temp['PROJECT_TERMS'].str.contains(r'\bLegume')| temp['PROJECT_TITLE'].str.contains(r'\bLegume'))|
           (temp['ABSTRACT'].str.contains(r'\blentil') | temp['PROJECT_TERMS'].str.contains(r'\blentil')| 
           temp['PROJECT_TITLE'].str.contains(r'\blentil') |temp['ABSTRACT'].str.contains(r'\bLentil') | 
           temp['PROJECT_TERMS'].str.contains(r'\bLentil')| temp['PROJECT_TITLE'].str.contains(r'\bLentil')) |
           (temp['ABSTRACT'].str.contains(r'\bedamame\b') | temp['PROJECT_TERMS'].str.contains(r'\bedamame\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bedamame\b') |temp['ABSTRACT'].str.contains(r'\bEdamame\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bEdamame\b')| temp['PROJECT_TITLE'].str.contains(r'\bEdamame\b'))|
          ((temp['ABSTRACT'].str.contains(r'\bbean') | temp['PROJECT_TERMS'].str.contains(r'\bbean')| 
           temp['PROJECT_TITLE'].str.contains(r'\bbean') |temp['ABSTRACT'].str.contains(r'\bbean') | 
           temp['PROJECT_TERMS'].str.contains(r'\bbean')| temp['PROJECT_TITLE'].str.contains(r'\bbean'))&
           ((temp['ABSTRACT'].str.contains(r'\bsoybean')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bsoybean')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bsoybean')==False) |(temp['ABSTRACT'].str.contains(r'\bSoybean')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bSoybean')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bSoybean')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bsoy')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bsoy')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bsoy')==False) |(temp['ABSTRACT'].str.contains(r'\bSoy')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bSoy')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bSoy')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bgreen bean')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bgreen bean')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bgreen bean')==False) |(temp['ABSTRACT'].str.contains(r'\bGreen bean')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bGreen bean')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bGreen bean')==False))) |
          ((temp['ABSTRACT'].str.contains(r'\bnut\b') | temp['PROJECT_TERMS'].str.contains(r'\bnut\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bnut\b') |temp['ABSTRACT'].str.contains(r'\bNut\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bNut\b')| temp['PROJECT_TITLE'].str.contains(r'\bNut\b'))|
           (temp['ABSTRACT'].str.contains(r'\bnuts\b') | temp['PROJECT_TERMS'].str.contains(r'\bnuts\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bnuts\b') |temp['ABSTRACT'].str.contains(r'\bNuts\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bNuts\b')| temp['PROJECT_TITLE'].str.contains(r'\bNuts\b'))&
           ((temp['ABSTRACT'].str.contains(r'\bpeanut')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bpeanut')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bpeanut')==False) |(temp['ABSTRACT'].str.contains(r'\bPeanut')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bPeanut')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bPeanut')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bpeanuts')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bpeanuts')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bpeanuts')==False) |(temp['ABSTRACT'].str.contains(r'\bPeanuts')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bPeanuts')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bPeanuts')==False))|
           (temp['ABSTRACT'].str.contains(r'\bhazelnuts\b') | temp['PROJECT_TERMS'].str.contains(r'\bhazelnuts\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bHazelnuts\b') |temp['ABSTRACT'].str.contains(r'\bhazelnuts\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bHazelnuts\b')| temp['PROJECT_TITLE'].str.contains(r'\bHazelnuts\b'))|
           (temp['ABSTRACT'].str.contains(r'\bchickpea\b') | temp['PROJECT_TERMS'].str.contains(r'\bchickpea\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bchickpea\b') |temp['ABSTRACT'].str.contains(r'\bChickpea\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bChickpea\b')| temp['PROJECT_TITLE'].str.contains(r'\bChickpea\b'))|
           (temp['ABSTRACT'].str.contains(r'\bpea\b') | temp['PROJECT_TERMS'].str.contains(r'\bpea\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bpea\b') |temp['ABSTRACT'].str.contains(r'\bPea\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bPea\b')| temp['PROJECT_TITLE'].str.contains(r'\bPea\b')) &
           ((temp['ABSTRACT'].str.contains(r'\bgreen pea\b')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bgreen pea\b')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bgreen p\b')==False) |(temp['ABSTRACT'].str.contains(r'\bGreen pea\b')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bGreen pea\b')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bGreen pea\b')==False)))]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2013.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2013.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[(temp['ABSTRACT'].str.contains(r'\blegume') | temp['PROJECT_TERMS'].str.contains(r'\blegume')| 
           temp['PROJECT_TITLE'].str.contains(r'\blegume') |temp['ABSTRACT'].str.contains(r'\bLegume') | 
           temp['PROJECT_TERMS'].str.contains(r'\bLegume')| temp['PROJECT_TITLE'].str.contains(r'\bLegume'))|
           (temp['ABSTRACT'].str.contains(r'\blentil') | temp['PROJECT_TERMS'].str.contains(r'\blentil')| 
           temp['PROJECT_TITLE'].str.contains(r'\blentil') |temp['ABSTRACT'].str.contains(r'\bLentil') | 
           temp['PROJECT_TERMS'].str.contains(r'\bLentil')| temp['PROJECT_TITLE'].str.contains(r'\bLentil')) |
           (temp['ABSTRACT'].str.contains(r'\bedamame\b') | temp['PROJECT_TERMS'].str.contains(r'\bedamame\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bedamame\b') |temp['ABSTRACT'].str.contains(r'\bEdamame\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bEdamame\b')| temp['PROJECT_TITLE'].str.contains(r'\bEdamame\b'))|
          ((temp['ABSTRACT'].str.contains(r'\bbean') | temp['PROJECT_TERMS'].str.contains(r'\bbean')| 
           temp['PROJECT_TITLE'].str.contains(r'\bbean') |temp['ABSTRACT'].str.contains(r'\bbean') | 
           temp['PROJECT_TERMS'].str.contains(r'\bbean')| temp['PROJECT_TITLE'].str.contains(r'\bbean'))&
           ((temp['ABSTRACT'].str.contains(r'\bsoybean')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bsoybean')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bsoybean')==False) |(temp['ABSTRACT'].str.contains(r'\bSoybean')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bSoybean')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bSoybean')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bsoy')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bsoy')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bsoy')==False) |(temp['ABSTRACT'].str.contains(r'\bSoy')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bSoy')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bSoy')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bgreen bean')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bgreen bean')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bgreen bean')==False) |(temp['ABSTRACT'].str.contains(r'\bGreen bean')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bGreen bean')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bGreen bean')==False))) |
          ((temp['ABSTRACT'].str.contains(r'\bnut\b') | temp['PROJECT_TERMS'].str.contains(r'\bnut\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bnut\b') |temp['ABSTRACT'].str.contains(r'\bNut\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bNut\b')| temp['PROJECT_TITLE'].str.contains(r'\bNut\b'))|
           (temp['ABSTRACT'].str.contains(r'\bnuts\b') | temp['PROJECT_TERMS'].str.contains(r'\bnuts\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bnuts\b') |temp['ABSTRACT'].str.contains(r'\bNuts\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bNuts\b')| temp['PROJECT_TITLE'].str.contains(r'\bNuts\b'))&
           ((temp['ABSTRACT'].str.contains(r'\bpeanut')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bpeanut')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bpeanut')==False) |(temp['ABSTRACT'].str.contains(r'\bPeanut')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bPeanut')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bPeanut')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bpeanuts')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bpeanuts')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bpeanuts')==False) |(temp['ABSTRACT'].str.contains(r'\bPeanuts')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bPeanuts')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bPeanuts')==False))|
           (temp['ABSTRACT'].str.contains(r'\bhazelnuts\b') | temp['PROJECT_TERMS'].str.contains(r'\bhazelnuts\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bHazelnuts\b') |temp['ABSTRACT'].str.contains(r'\bhazelnuts\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bHazelnuts\b')| temp['PROJECT_TITLE'].str.contains(r'\bHazelnuts\b'))|
           (temp['ABSTRACT'].str.contains(r'\bchickpea\b') | temp['PROJECT_TERMS'].str.contains(r'\bchickpea\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bchickpea\b') |temp['ABSTRACT'].str.contains(r'\bChickpea\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bChickpea\b')| temp['PROJECT_TITLE'].str.contains(r'\bChickpea\b'))|
           (temp['ABSTRACT'].str.contains(r'\bpea\b') | temp['PROJECT_TERMS'].str.contains(r'\bpea\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bpea\b') |temp['ABSTRACT'].str.contains(r'\bPea\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bPea\b')| temp['PROJECT_TITLE'].str.contains(r'\bPea\b')) &
           ((temp['ABSTRACT'].str.contains(r'\bgreen pea\b')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bgreen pea\b')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bgreen p\b')==False) |(temp['ABSTRACT'].str.contains(r'\bGreen pea\b')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bGreen pea\b')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bGreen pea\b')==False)))]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)


df_abs=pd.read_csv('abstract/PRJABS_2014.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2014.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[(temp['ABSTRACT'].str.contains(r'\blegume') | temp['PROJECT_TERMS'].str.contains(r'\blegume')| 
           temp['PROJECT_TITLE'].str.contains(r'\blegume') |temp['ABSTRACT'].str.contains(r'\bLegume') | 
           temp['PROJECT_TERMS'].str.contains(r'\bLegume')| temp['PROJECT_TITLE'].str.contains(r'\bLegume'))|
           (temp['ABSTRACT'].str.contains(r'\blentil') | temp['PROJECT_TERMS'].str.contains(r'\blentil')| 
           temp['PROJECT_TITLE'].str.contains(r'\blentil') |temp['ABSTRACT'].str.contains(r'\bLentil') | 
           temp['PROJECT_TERMS'].str.contains(r'\bLentil')| temp['PROJECT_TITLE'].str.contains(r'\bLentil')) |
           (temp['ABSTRACT'].str.contains(r'\bedamame\b') | temp['PROJECT_TERMS'].str.contains(r'\bedamame\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bedamame\b') |temp['ABSTRACT'].str.contains(r'\bEdamame\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bEdamame\b')| temp['PROJECT_TITLE'].str.contains(r'\bEdamame\b'))|
          ((temp['ABSTRACT'].str.contains(r'\bbean') | temp['PROJECT_TERMS'].str.contains(r'\bbean')| 
           temp['PROJECT_TITLE'].str.contains(r'\bbean') |temp['ABSTRACT'].str.contains(r'\bbean') | 
           temp['PROJECT_TERMS'].str.contains(r'\bbean')| temp['PROJECT_TITLE'].str.contains(r'\bbean'))&
           ((temp['ABSTRACT'].str.contains(r'\bsoybean')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bsoybean')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bsoybean')==False) |(temp['ABSTRACT'].str.contains(r'\bSoybean')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bSoybean')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bSoybean')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bsoy')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bsoy')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bsoy')==False) |(temp['ABSTRACT'].str.contains(r'\bSoy')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bSoy')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bSoy')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bgreen bean')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bgreen bean')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bgreen bean')==False) |(temp['ABSTRACT'].str.contains(r'\bGreen bean')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bGreen bean')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bGreen bean')==False))) |
          ((temp['ABSTRACT'].str.contains(r'\bnut\b') | temp['PROJECT_TERMS'].str.contains(r'\bnut\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bnut\b') |temp['ABSTRACT'].str.contains(r'\bNut\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bNut\b')| temp['PROJECT_TITLE'].str.contains(r'\bNut\b'))|
           (temp['ABSTRACT'].str.contains(r'\bnuts\b') | temp['PROJECT_TERMS'].str.contains(r'\bnuts\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bnuts\b') |temp['ABSTRACT'].str.contains(r'\bNuts\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bNuts\b')| temp['PROJECT_TITLE'].str.contains(r'\bNuts\b'))&
           ((temp['ABSTRACT'].str.contains(r'\bpeanut')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bpeanut')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bpeanut')==False) |(temp['ABSTRACT'].str.contains(r'\bPeanut')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bPeanut')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bPeanut')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bpeanuts')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bpeanuts')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bpeanuts')==False) |(temp['ABSTRACT'].str.contains(r'\bPeanuts')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bPeanuts')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bPeanuts')==False))|
           (temp['ABSTRACT'].str.contains(r'\bhazelnuts\b') | temp['PROJECT_TERMS'].str.contains(r'\bhazelnuts\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bHazelnuts\b') |temp['ABSTRACT'].str.contains(r'\bhazelnuts\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bHazelnuts\b')| temp['PROJECT_TITLE'].str.contains(r'\bHazelnuts\b'))|
           (temp['ABSTRACT'].str.contains(r'\bchickpea\b') | temp['PROJECT_TERMS'].str.contains(r'\bchickpea\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bchickpea\b') |temp['ABSTRACT'].str.contains(r'\bChickpea\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bChickpea\b')| temp['PROJECT_TITLE'].str.contains(r'\bChickpea\b'))|
           (temp['ABSTRACT'].str.contains(r'\bpea\b') | temp['PROJECT_TERMS'].str.contains(r'\bpea\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bpea\b') |temp['ABSTRACT'].str.contains(r'\bPea\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bPea\b')| temp['PROJECT_TITLE'].str.contains(r'\bPea\b')) &
           ((temp['ABSTRACT'].str.contains(r'\bgreen pea\b')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bgreen pea\b')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bgreen p\b')==False) |(temp['ABSTRACT'].str.contains(r'\bGreen pea\b')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bGreen pea\b')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bGreen pea\b')==False)))]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)


df_abs=pd.read_csv('abstract/PRJABS_2015.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2015.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[(temp['ABSTRACT'].str.contains(r'\blegume') | temp['PROJECT_TERMS'].str.contains(r'\blegume')| 
           temp['PROJECT_TITLE'].str.contains(r'\blegume') |temp['ABSTRACT'].str.contains(r'\bLegume') | 
           temp['PROJECT_TERMS'].str.contains(r'\bLegume')| temp['PROJECT_TITLE'].str.contains(r'\bLegume'))|
           (temp['ABSTRACT'].str.contains(r'\blentil') | temp['PROJECT_TERMS'].str.contains(r'\blentil')| 
           temp['PROJECT_TITLE'].str.contains(r'\blentil') |temp['ABSTRACT'].str.contains(r'\bLentil') | 
           temp['PROJECT_TERMS'].str.contains(r'\bLentil')| temp['PROJECT_TITLE'].str.contains(r'\bLentil')) |
           (temp['ABSTRACT'].str.contains(r'\bedamame\b') | temp['PROJECT_TERMS'].str.contains(r'\bedamame\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bedamame\b') |temp['ABSTRACT'].str.contains(r'\bEdamame\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bEdamame\b')| temp['PROJECT_TITLE'].str.contains(r'\bEdamame\b'))|
          ((temp['ABSTRACT'].str.contains(r'\bbean') | temp['PROJECT_TERMS'].str.contains(r'\bbean')| 
           temp['PROJECT_TITLE'].str.contains(r'\bbean') |temp['ABSTRACT'].str.contains(r'\bbean') | 
           temp['PROJECT_TERMS'].str.contains(r'\bbean')| temp['PROJECT_TITLE'].str.contains(r'\bbean'))&
           ((temp['ABSTRACT'].str.contains(r'\bsoybean')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bsoybean')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bsoybean')==False) |(temp['ABSTRACT'].str.contains(r'\bSoybean')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bSoybean')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bSoybean')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bsoy')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bsoy')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bsoy')==False) |(temp['ABSTRACT'].str.contains(r'\bSoy')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bSoy')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bSoy')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bgreen bean')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bgreen bean')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bgreen bean')==False) |(temp['ABSTRACT'].str.contains(r'\bGreen bean')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bGreen bean')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bGreen bean')==False))) |
          ((temp['ABSTRACT'].str.contains(r'\bnut\b') | temp['PROJECT_TERMS'].str.contains(r'\bnut\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bnut\b') |temp['ABSTRACT'].str.contains(r'\bNut\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bNut\b')| temp['PROJECT_TITLE'].str.contains(r'\bNut\b'))|
           (temp['ABSTRACT'].str.contains(r'\bnuts\b') | temp['PROJECT_TERMS'].str.contains(r'\bnuts\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bnuts\b') |temp['ABSTRACT'].str.contains(r'\bNuts\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bNuts\b')| temp['PROJECT_TITLE'].str.contains(r'\bNuts\b'))&
           ((temp['ABSTRACT'].str.contains(r'\bpeanut')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bpeanut')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bpeanut')==False) |(temp['ABSTRACT'].str.contains(r'\bPeanut')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bPeanut')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bPeanut')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bpeanuts')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bpeanuts')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bpeanuts')==False) |(temp['ABSTRACT'].str.contains(r'\bPeanuts')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bPeanuts')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bPeanuts')==False))|
           (temp['ABSTRACT'].str.contains(r'\bhazelnuts\b') | temp['PROJECT_TERMS'].str.contains(r'\bhazelnuts\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bHazelnuts\b') |temp['ABSTRACT'].str.contains(r'\bhazelnuts\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bHazelnuts\b')| temp['PROJECT_TITLE'].str.contains(r'\bHazelnuts\b'))|
           (temp['ABSTRACT'].str.contains(r'\bchickpea\b') | temp['PROJECT_TERMS'].str.contains(r'\bchickpea\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bchickpea\b') |temp['ABSTRACT'].str.contains(r'\bChickpea\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bChickpea\b')| temp['PROJECT_TITLE'].str.contains(r'\bChickpea\b'))|
           (temp['ABSTRACT'].str.contains(r'\bpea\b') | temp['PROJECT_TERMS'].str.contains(r'\bpea\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bpea\b') |temp['ABSTRACT'].str.contains(r'\bPea\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bPea\b')| temp['PROJECT_TITLE'].str.contains(r'\bPea\b')) &
           ((temp['ABSTRACT'].str.contains(r'\bgreen pea\b')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bgreen pea\b')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bgreen p\b')==False) |(temp['ABSTRACT'].str.contains(r'\bGreen pea\b')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bGreen pea\b')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bGreen pea\b')==False)))]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)


df_abs=pd.read_csv('abstract/PRJABS_2016.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2016.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[(temp['ABSTRACT'].str.contains(r'\blegume') | temp['PROJECT_TERMS'].str.contains(r'\blegume')| 
           temp['PROJECT_TITLE'].str.contains(r'\blegume') |temp['ABSTRACT'].str.contains(r'\bLegume') | 
           temp['PROJECT_TERMS'].str.contains(r'\bLegume')| temp['PROJECT_TITLE'].str.contains(r'\bLegume'))|
           (temp['ABSTRACT'].str.contains(r'\blentil') | temp['PROJECT_TERMS'].str.contains(r'\blentil')| 
           temp['PROJECT_TITLE'].str.contains(r'\blentil') |temp['ABSTRACT'].str.contains(r'\bLentil') | 
           temp['PROJECT_TERMS'].str.contains(r'\bLentil')| temp['PROJECT_TITLE'].str.contains(r'\bLentil')) |
           (temp['ABSTRACT'].str.contains(r'\bedamame\b') | temp['PROJECT_TERMS'].str.contains(r'\bedamame\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bedamame\b') |temp['ABSTRACT'].str.contains(r'\bEdamame\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bEdamame\b')| temp['PROJECT_TITLE'].str.contains(r'\bEdamame\b'))|
          ((temp['ABSTRACT'].str.contains(r'\bbean') | temp['PROJECT_TERMS'].str.contains(r'\bbean')| 
           temp['PROJECT_TITLE'].str.contains(r'\bbean') |temp['ABSTRACT'].str.contains(r'\bbean') | 
           temp['PROJECT_TERMS'].str.contains(r'\bbean')| temp['PROJECT_TITLE'].str.contains(r'\bbean'))&
           ((temp['ABSTRACT'].str.contains(r'\bsoybean')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bsoybean')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bsoybean')==False) |(temp['ABSTRACT'].str.contains(r'\bSoybean')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bSoybean')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bSoybean')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bsoy')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bsoy')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bsoy')==False) |(temp['ABSTRACT'].str.contains(r'\bSoy')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bSoy')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bSoy')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bgreen bean')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bgreen bean')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bgreen bean')==False) |(temp['ABSTRACT'].str.contains(r'\bGreen bean')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bGreen bean')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bGreen bean')==False))) |
          ((temp['ABSTRACT'].str.contains(r'\bnut\b') | temp['PROJECT_TERMS'].str.contains(r'\bnut\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bnut\b') |temp['ABSTRACT'].str.contains(r'\bNut\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bNut\b')| temp['PROJECT_TITLE'].str.contains(r'\bNut\b'))|
           (temp['ABSTRACT'].str.contains(r'\bnuts\b') | temp['PROJECT_TERMS'].str.contains(r'\bnuts\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bnuts\b') |temp['ABSTRACT'].str.contains(r'\bNuts\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bNuts\b')| temp['PROJECT_TITLE'].str.contains(r'\bNuts\b'))&
           ((temp['ABSTRACT'].str.contains(r'\bpeanut')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bpeanut')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bpeanut')==False) |(temp['ABSTRACT'].str.contains(r'\bPeanut')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bPeanut')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bPeanut')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bpeanuts')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bpeanuts')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bpeanuts')==False) |(temp['ABSTRACT'].str.contains(r'\bPeanuts')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bPeanuts')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bPeanuts')==False))|
           (temp['ABSTRACT'].str.contains(r'\bhazelnuts\b') | temp['PROJECT_TERMS'].str.contains(r'\bhazelnuts\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bHazelnuts\b') |temp['ABSTRACT'].str.contains(r'\bhazelnuts\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bHazelnuts\b')| temp['PROJECT_TITLE'].str.contains(r'\bHazelnuts\b'))|
           (temp['ABSTRACT'].str.contains(r'\bchickpea\b') | temp['PROJECT_TERMS'].str.contains(r'\bchickpea\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bchickpea\b') |temp['ABSTRACT'].str.contains(r'\bChickpea\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bChickpea\b')| temp['PROJECT_TITLE'].str.contains(r'\bChickpea\b'))|
           (temp['ABSTRACT'].str.contains(r'\bpea\b') | temp['PROJECT_TERMS'].str.contains(r'\bpea\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bpea\b') |temp['ABSTRACT'].str.contains(r'\bPea\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bPea\b')| temp['PROJECT_TITLE'].str.contains(r'\bPea\b')) &
           ((temp['ABSTRACT'].str.contains(r'\bgreen pea\b')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bgreen pea\b')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bgreen p\b')==False) |(temp['ABSTRACT'].str.contains(r'\bGreen pea\b')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bGreen pea\b')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bGreen pea\b')==False)))]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2017.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2017.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[(temp['ABSTRACT'].str.contains(r'\blegume') | temp['PROJECT_TERMS'].str.contains(r'\blegume')| 
           temp['PROJECT_TITLE'].str.contains(r'\blegume') |temp['ABSTRACT'].str.contains(r'\bLegume') | 
           temp['PROJECT_TERMS'].str.contains(r'\bLegume')| temp['PROJECT_TITLE'].str.contains(r'\bLegume'))|
           (temp['ABSTRACT'].str.contains(r'\blentil') | temp['PROJECT_TERMS'].str.contains(r'\blentil')| 
           temp['PROJECT_TITLE'].str.contains(r'\blentil') |temp['ABSTRACT'].str.contains(r'\bLentil') | 
           temp['PROJECT_TERMS'].str.contains(r'\bLentil')| temp['PROJECT_TITLE'].str.contains(r'\bLentil')) |
           (temp['ABSTRACT'].str.contains(r'\bedamame\b') | temp['PROJECT_TERMS'].str.contains(r'\bedamame\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bedamame\b') |temp['ABSTRACT'].str.contains(r'\bEdamame\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bEdamame\b')| temp['PROJECT_TITLE'].str.contains(r'\bEdamame\b'))|
          ((temp['ABSTRACT'].str.contains(r'\bbean') | temp['PROJECT_TERMS'].str.contains(r'\bbean')| 
           temp['PROJECT_TITLE'].str.contains(r'\bbean') |temp['ABSTRACT'].str.contains(r'\bbean') | 
           temp['PROJECT_TERMS'].str.contains(r'\bbean')| temp['PROJECT_TITLE'].str.contains(r'\bbean'))&
           ((temp['ABSTRACT'].str.contains(r'\bsoybean')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bsoybean')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bsoybean')==False) |(temp['ABSTRACT'].str.contains(r'\bSoybean')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bSoybean')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bSoybean')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bsoy')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bsoy')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bsoy')==False) |(temp['ABSTRACT'].str.contains(r'\bSoy')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bSoy')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bSoy')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bgreen bean')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bgreen bean')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bgreen bean')==False) |(temp['ABSTRACT'].str.contains(r'\bGreen bean')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bGreen bean')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bGreen bean')==False))) |
          ((temp['ABSTRACT'].str.contains(r'\bnut\b') | temp['PROJECT_TERMS'].str.contains(r'\bnut\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bnut\b') |temp['ABSTRACT'].str.contains(r'\bNut\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bNut\b')| temp['PROJECT_TITLE'].str.contains(r'\bNut\b'))|
           (temp['ABSTRACT'].str.contains(r'\bnuts\b') | temp['PROJECT_TERMS'].str.contains(r'\bnuts\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bnuts\b') |temp['ABSTRACT'].str.contains(r'\bNuts\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bNuts\b')| temp['PROJECT_TITLE'].str.contains(r'\bNuts\b'))&
           ((temp['ABSTRACT'].str.contains(r'\bpeanut')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bpeanut')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bpeanut')==False) |(temp['ABSTRACT'].str.contains(r'\bPeanut')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bPeanut')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bPeanut')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bpeanuts')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bpeanuts')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bpeanuts')==False) |(temp['ABSTRACT'].str.contains(r'\bPeanuts')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bPeanuts')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bPeanuts')==False))|
           (temp['ABSTRACT'].str.contains(r'\bhazelnuts\b') | temp['PROJECT_TERMS'].str.contains(r'\bhazelnuts\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bHazelnuts\b') |temp['ABSTRACT'].str.contains(r'\bhazelnuts\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bHazelnuts\b')| temp['PROJECT_TITLE'].str.contains(r'\bHazelnuts\b'))|
           (temp['ABSTRACT'].str.contains(r'\bchickpea\b') | temp['PROJECT_TERMS'].str.contains(r'\bchickpea\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bchickpea\b') |temp['ABSTRACT'].str.contains(r'\bChickpea\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bChickpea\b')| temp['PROJECT_TITLE'].str.contains(r'\bChickpea\b'))|
           (temp['ABSTRACT'].str.contains(r'\bpea\b') | temp['PROJECT_TERMS'].str.contains(r'\bpea\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bpea\b') |temp['ABSTRACT'].str.contains(r'\bPea\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bPea\b')| temp['PROJECT_TITLE'].str.contains(r'\bPea\b')) &
           ((temp['ABSTRACT'].str.contains(r'\bgreen pea\b')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bgreen pea\b')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bgreen p\b')==False) |(temp['ABSTRACT'].str.contains(r'\bGreen pea\b')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bGreen pea\b')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bGreen pea\b')==False)))]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2018.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2018.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[(temp['ABSTRACT'].str.contains(r'\blegume') | temp['PROJECT_TERMS'].str.contains(r'\blegume')| 
           temp['PROJECT_TITLE'].str.contains(r'\blegume') |temp['ABSTRACT'].str.contains(r'\bLegume') | 
           temp['PROJECT_TERMS'].str.contains(r'\bLegume')| temp['PROJECT_TITLE'].str.contains(r'\bLegume'))|
           (temp['ABSTRACT'].str.contains(r'\blentil') | temp['PROJECT_TERMS'].str.contains(r'\blentil')| 
           temp['PROJECT_TITLE'].str.contains(r'\blentil') |temp['ABSTRACT'].str.contains(r'\bLentil') | 
           temp['PROJECT_TERMS'].str.contains(r'\bLentil')| temp['PROJECT_TITLE'].str.contains(r'\bLentil')) |
           (temp['ABSTRACT'].str.contains(r'\bedamame\b') | temp['PROJECT_TERMS'].str.contains(r'\bedamame\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bedamame\b') |temp['ABSTRACT'].str.contains(r'\bEdamame\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bEdamame\b')| temp['PROJECT_TITLE'].str.contains(r'\bEdamame\b'))|
          ((temp['ABSTRACT'].str.contains(r'\bbean') | temp['PROJECT_TERMS'].str.contains(r'\bbean')| 
           temp['PROJECT_TITLE'].str.contains(r'\bbean') |temp['ABSTRACT'].str.contains(r'\bbean') | 
           temp['PROJECT_TERMS'].str.contains(r'\bbean')| temp['PROJECT_TITLE'].str.contains(r'\bbean'))&
           ((temp['ABSTRACT'].str.contains(r'\bsoybean')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bsoybean')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bsoybean')==False) |(temp['ABSTRACT'].str.contains(r'\bSoybean')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bSoybean')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bSoybean')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bsoy')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bsoy')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bsoy')==False) |(temp['ABSTRACT'].str.contains(r'\bSoy')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bSoy')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bSoy')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bgreen bean')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bgreen bean')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bgreen bean')==False) |(temp['ABSTRACT'].str.contains(r'\bGreen bean')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bGreen bean')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bGreen bean')==False))) |
          ((temp['ABSTRACT'].str.contains(r'\bnut\b') | temp['PROJECT_TERMS'].str.contains(r'\bnut\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bnut\b') |temp['ABSTRACT'].str.contains(r'\bNut\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bNut\b')| temp['PROJECT_TITLE'].str.contains(r'\bNut\b'))|
           (temp['ABSTRACT'].str.contains(r'\bnuts\b') | temp['PROJECT_TERMS'].str.contains(r'\bnuts\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bnuts\b') |temp['ABSTRACT'].str.contains(r'\bNuts\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bNuts\b')| temp['PROJECT_TITLE'].str.contains(r'\bNuts\b'))&
           ((temp['ABSTRACT'].str.contains(r'\bpeanut')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bpeanut')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bpeanut')==False) |(temp['ABSTRACT'].str.contains(r'\bPeanut')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bPeanut')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bPeanut')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bpeanuts')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bpeanuts')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bpeanuts')==False) |(temp['ABSTRACT'].str.contains(r'\bPeanuts')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bPeanuts')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bPeanuts')==False))|
           (temp['ABSTRACT'].str.contains(r'\bhazelnuts\b') | temp['PROJECT_TERMS'].str.contains(r'\bhazelnuts\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bHazelnuts\b') |temp['ABSTRACT'].str.contains(r'\bhazelnuts\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bHazelnuts\b')| temp['PROJECT_TITLE'].str.contains(r'\bHazelnuts\b'))|
           (temp['ABSTRACT'].str.contains(r'\bchickpea\b') | temp['PROJECT_TERMS'].str.contains(r'\bchickpea\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bchickpea\b') |temp['ABSTRACT'].str.contains(r'\bChickpea\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bChickpea\b')| temp['PROJECT_TITLE'].str.contains(r'\bChickpea\b'))|
           (temp['ABSTRACT'].str.contains(r'\bpea\b') | temp['PROJECT_TERMS'].str.contains(r'\bpea\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bpea\b') |temp['ABSTRACT'].str.contains(r'\bPea\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bPea\b')| temp['PROJECT_TITLE'].str.contains(r'\bPea\b')) &
           ((temp['ABSTRACT'].str.contains(r'\bgreen pea\b')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bgreen pea\b')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bgreen p\b')==False) |(temp['ABSTRACT'].str.contains(r'\bGreen pea\b')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bGreen pea\b')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bGreen pea\b')==False)))]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2019.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2019.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[(temp['ABSTRACT'].str.contains(r'\blegume') | temp['PROJECT_TERMS'].str.contains(r'\blegume')| 
           temp['PROJECT_TITLE'].str.contains(r'\blegume') |temp['ABSTRACT'].str.contains(r'\bLegume') | 
           temp['PROJECT_TERMS'].str.contains(r'\bLegume')| temp['PROJECT_TITLE'].str.contains(r'\bLegume'))|
           (temp['ABSTRACT'].str.contains(r'\blentil') | temp['PROJECT_TERMS'].str.contains(r'\blentil')| 
           temp['PROJECT_TITLE'].str.contains(r'\blentil') |temp['ABSTRACT'].str.contains(r'\bLentil') | 
           temp['PROJECT_TERMS'].str.contains(r'\bLentil')| temp['PROJECT_TITLE'].str.contains(r'\bLentil')) |
           (temp['ABSTRACT'].str.contains(r'\bedamame\b') | temp['PROJECT_TERMS'].str.contains(r'\bedamame\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bedamame\b') |temp['ABSTRACT'].str.contains(r'\bEdamame\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bEdamame\b')| temp['PROJECT_TITLE'].str.contains(r'\bEdamame\b'))|
          ((temp['ABSTRACT'].str.contains(r'\bbean') | temp['PROJECT_TERMS'].str.contains(r'\bbean')| 
           temp['PROJECT_TITLE'].str.contains(r'\bbean') |temp['ABSTRACT'].str.contains(r'\bbean') | 
           temp['PROJECT_TERMS'].str.contains(r'\bbean')| temp['PROJECT_TITLE'].str.contains(r'\bbean'))&
           ((temp['ABSTRACT'].str.contains(r'\bsoybean')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bsoybean')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bsoybean')==False) |(temp['ABSTRACT'].str.contains(r'\bSoybean')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bSoybean')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bSoybean')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bsoy')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bsoy')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bsoy')==False) |(temp['ABSTRACT'].str.contains(r'\bSoy')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bSoy')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bSoy')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bgreen bean')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bgreen bean')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bgreen bean')==False) |(temp['ABSTRACT'].str.contains(r'\bGreen bean')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bGreen bean')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bGreen bean')==False))) |
          ((temp['ABSTRACT'].str.contains(r'\bnut\b') | temp['PROJECT_TERMS'].str.contains(r'\bnut\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bnut\b') |temp['ABSTRACT'].str.contains(r'\bNut\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bNut\b')| temp['PROJECT_TITLE'].str.contains(r'\bNut\b'))|
           (temp['ABSTRACT'].str.contains(r'\bnuts\b') | temp['PROJECT_TERMS'].str.contains(r'\bnuts\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bnuts\b') |temp['ABSTRACT'].str.contains(r'\bNuts\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bNuts\b')| temp['PROJECT_TITLE'].str.contains(r'\bNuts\b'))&
           ((temp['ABSTRACT'].str.contains(r'\bpeanut')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bpeanut')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bpeanut')==False) |(temp['ABSTRACT'].str.contains(r'\bPeanut')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bPeanut')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bPeanut')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bpeanuts')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bpeanuts')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bpeanuts')==False) |(temp['ABSTRACT'].str.contains(r'\bPeanuts')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bPeanuts')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bPeanuts')==False))|
           (temp['ABSTRACT'].str.contains(r'\bhazelnuts\b') | temp['PROJECT_TERMS'].str.contains(r'\bhazelnuts\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bHazelnuts\b') |temp['ABSTRACT'].str.contains(r'\bhazelnuts\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bHazelnuts\b')| temp['PROJECT_TITLE'].str.contains(r'\bHazelnuts\b'))|
           (temp['ABSTRACT'].str.contains(r'\bchickpea\b') | temp['PROJECT_TERMS'].str.contains(r'\bchickpea\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bchickpea\b') |temp['ABSTRACT'].str.contains(r'\bChickpea\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bChickpea\b')| temp['PROJECT_TITLE'].str.contains(r'\bChickpea\b'))|
           (temp['ABSTRACT'].str.contains(r'\bpea\b') | temp['PROJECT_TERMS'].str.contains(r'\bpea\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bpea\b') |temp['ABSTRACT'].str.contains(r'\bPea\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bPea\b')| temp['PROJECT_TITLE'].str.contains(r'\bPea\b')) &
           ((temp['ABSTRACT'].str.contains(r'\bgreen pea\b')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bgreen pea\b')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bgreen p\b')==False) |(temp['ABSTRACT'].str.contains(r'\bGreen pea\b')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bGreen pea\b')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bGreen pea\b')==False)))]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)
# Out:
# (668, 24) (0, 25)
# (340, 24) (0, 25)
# (351, 24) (1, 25)
# (310, 24) (2, 25)
# (641, 24) (10, 25)
# (618, 24) (20, 25)
# (640, 24) (32, 25)
# (598, 24) (42, 25)
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3071: DtypeWarning: Columns (12,20) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# (104076, 24) (306, 25)
# (118557, 24) (614, 25)
# (111400, 24) (889, 25)
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3071: DtypeWarning: Columns (12) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# (98064, 24) (1131, 25)
# (93367, 24) (1305, 25)
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3071: DtypeWarning: Columns (20) have mixed types.Specify dtype option on import or set low_memory=False.
# ...

# %%
df = df[df.AGENCY != 'NASA']
df = df[df.AGENCY != 'NIH']
print(df.shape)
df.to_csv('legume_nuts_no_peanuts.csv')
# Out:
# (1654, 25)

# %% [markdown]
# # Legume- Peanuts

# %%
df=pd.DataFrame()
df_abs=pd.read_csv('abstract/PRJABS_2000.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2000.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[(temp['ABSTRACT'].str.contains(r'\blegume') | temp['PROJECT_TERMS'].str.contains(r'\blegume')| 
           temp['PROJECT_TITLE'].str.contains(r'\blegume') |temp['ABSTRACT'].str.contains(r'\bLegume') | 
           temp['PROJECT_TERMS'].str.contains(r'\bLegume')| temp['PROJECT_TITLE'].str.contains(r'\bLegume'))|
           (temp['ABSTRACT'].str.contains(r'\blentil') | temp['PROJECT_TERMS'].str.contains(r'\blentil')| 
           temp['PROJECT_TITLE'].str.contains(r'\blentil') |temp['ABSTRACT'].str.contains(r'\bLentil') | 
           temp['PROJECT_TERMS'].str.contains(r'\bLentil')| temp['PROJECT_TITLE'].str.contains(r'\bLentil')) |
           (temp['ABSTRACT'].str.contains(r'\bedamame\b') | temp['PROJECT_TERMS'].str.contains(r'\bedamame\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bedamame\b') |temp['ABSTRACT'].str.contains(r'\bEdamame\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bEdamame\b')| temp['PROJECT_TITLE'].str.contains(r'\bEdamame\b'))|
          ((temp['ABSTRACT'].str.contains(r'\bbean') | temp['PROJECT_TERMS'].str.contains(r'\bbean')| 
           temp['PROJECT_TITLE'].str.contains(r'\bbean') |temp['ABSTRACT'].str.contains(r'\bbean') | 
           temp['PROJECT_TERMS'].str.contains(r'\bbean')| temp['PROJECT_TITLE'].str.contains(r'\bbean'))&
           ((temp['ABSTRACT'].str.contains(r'\bsoybean')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bsoybean')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bsoybean')==False) |(temp['ABSTRACT'].str.contains(r'\bSoybean')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bSoybean')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bSoybean')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bsoy')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bsoy')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bsoy')==False) |(temp['ABSTRACT'].str.contains(r'\bSoy')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bSoy')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bSoy')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bgreen bean')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bgreen bean')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bgreen bean')==False) |(temp['ABSTRACT'].str.contains(r'\bGreen bean')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bGreen bean')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bGreen bean')==False))) |
          ((temp['ABSTRACT'].str.contains(r'\bpeanut\b') | temp['PROJECT_TERMS'].str.contains(r'\bpeanut\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bpeanut\b') |temp['ABSTRACT'].str.contains(r'\bPeanut\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bPeaut\b')| temp['PROJECT_TITLE'].str.contains(r'\bPeanut\b'))|
           (temp['ABSTRACT'].str.contains(r'\bpeanuts\b') | temp['PROJECT_TERMS'].str.contains(r'\bpeanuts\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bpeanuts\b') |temp['ABSTRACT'].str.contains(r'\bPeanuts\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bPeanuts\b')| temp['PROJECT_TITLE'].str.contains(r'\bPeanuts\b'))&
           ((temp['ABSTRACT'].str.contains(r'\bnut')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bnut')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bnut')==False) |(temp['ABSTRACT'].str.contains(r'\bNut')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bNut')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bNut')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bnuts')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bnuts')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bnuts')==False) |(temp['ABSTRACT'].str.contains(r'\bNuts')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bNuts')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bNuts')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bhazelnuts')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bhazelnuts')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bhazelnuts')==False) |(temp['ABSTRACT'].str.contains(r'\bHazelnuts')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bHazelnuts')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bHazelnuts')==False))&
           (temp['ABSTRACT'].str.contains(r'\bchickpea\b') | temp['PROJECT_TERMS'].str.contains(r'\bchickpea\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bchickpea\b') |temp['ABSTRACT'].str.contains(r'\bChickpea\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bChickpea\b')| temp['PROJECT_TITLE'].str.contains(r'\bChickpea\b'))|
           (temp['ABSTRACT'].str.contains(r'\bpea\b') | temp['PROJECT_TERMS'].str.contains(r'\bpea\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bpea\b') |temp['ABSTRACT'].str.contains(r'\bPea\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bPea\b')| temp['PROJECT_TITLE'].str.contains(r'\bPea\b')) &
           ((temp['ABSTRACT'].str.contains(r'\bgreen pea\b')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bgreen pea\b')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bgreen p\b')==False) |(temp['ABSTRACT'].str.contains(r'\bGreen pea\b')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bGreen pea\b')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bGreen pea\b')==False)))]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2001.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2001.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[(temp['ABSTRACT'].str.contains(r'\blegume') | temp['PROJECT_TERMS'].str.contains(r'\blegume')| 
           temp['PROJECT_TITLE'].str.contains(r'\blegume') |temp['ABSTRACT'].str.contains(r'\bLegume') | 
           temp['PROJECT_TERMS'].str.contains(r'\bLegume')| temp['PROJECT_TITLE'].str.contains(r'\bLegume'))|
           (temp['ABSTRACT'].str.contains(r'\blentil') | temp['PROJECT_TERMS'].str.contains(r'\blentil')| 
           temp['PROJECT_TITLE'].str.contains(r'\blentil') |temp['ABSTRACT'].str.contains(r'\bLentil') | 
           temp['PROJECT_TERMS'].str.contains(r'\bLentil')| temp['PROJECT_TITLE'].str.contains(r'\bLentil')) |
           (temp['ABSTRACT'].str.contains(r'\bedamame\b') | temp['PROJECT_TERMS'].str.contains(r'\bedamame\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bedamame\b') |temp['ABSTRACT'].str.contains(r'\bEdamame\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bEdamame\b')| temp['PROJECT_TITLE'].str.contains(r'\bEdamame\b'))|
          ((temp['ABSTRACT'].str.contains(r'\bbean') | temp['PROJECT_TERMS'].str.contains(r'\bbean')| 
           temp['PROJECT_TITLE'].str.contains(r'\bbean') |temp['ABSTRACT'].str.contains(r'\bbean') | 
           temp['PROJECT_TERMS'].str.contains(r'\bbean')| temp['PROJECT_TITLE'].str.contains(r'\bbean'))&
           ((temp['ABSTRACT'].str.contains(r'\bsoybean')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bsoybean')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bsoybean')==False) |(temp['ABSTRACT'].str.contains(r'\bSoybean')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bSoybean')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bSoybean')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bsoy')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bsoy')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bsoy')==False) |(temp['ABSTRACT'].str.contains(r'\bSoy')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bSoy')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bSoy')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bgreen bean')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bgreen bean')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bgreen bean')==False) |(temp['ABSTRACT'].str.contains(r'\bGreen bean')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bGreen bean')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bGreen bean')==False))) |
          ((temp['ABSTRACT'].str.contains(r'\bpeanut\b') | temp['PROJECT_TERMS'].str.contains(r'\bpeanut\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bpeanut\b') |temp['ABSTRACT'].str.contains(r'\bPeanut\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bPeaut\b')| temp['PROJECT_TITLE'].str.contains(r'\bPeanut\b'))|
           (temp['ABSTRACT'].str.contains(r'\bpeanuts\b') | temp['PROJECT_TERMS'].str.contains(r'\bpeanuts\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bpeanuts\b') |temp['ABSTRACT'].str.contains(r'\bPeanuts\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bPeanuts\b')| temp['PROJECT_TITLE'].str.contains(r'\bPeanuts\b'))&
           ((temp['ABSTRACT'].str.contains(r'\bnut')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bnut')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bnut')==False) |(temp['ABSTRACT'].str.contains(r'\bNut')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bNut')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bNut')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bnuts')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bnuts')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bnuts')==False) |(temp['ABSTRACT'].str.contains(r'\bNuts')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bNuts')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bNuts')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bhazelnuts')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bhazelnuts')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bhazelnuts')==False) |(temp['ABSTRACT'].str.contains(r'\bHazelnuts')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bHazelnuts')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bHazelnuts')==False))&
           (temp['ABSTRACT'].str.contains(r'\bchickpea\b') | temp['PROJECT_TERMS'].str.contains(r'\bchickpea\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bchickpea\b') |temp['ABSTRACT'].str.contains(r'\bChickpea\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bChickpea\b')| temp['PROJECT_TITLE'].str.contains(r'\bChickpea\b'))|
           (temp['ABSTRACT'].str.contains(r'\bpea\b') | temp['PROJECT_TERMS'].str.contains(r'\bpea\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bpea\b') |temp['ABSTRACT'].str.contains(r'\bPea\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bPea\b')| temp['PROJECT_TITLE'].str.contains(r'\bPea\b')) &
           ((temp['ABSTRACT'].str.contains(r'\bgreen pea\b')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bgreen pea\b')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bgreen p\b')==False) |(temp['ABSTRACT'].str.contains(r'\bGreen pea\b')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bGreen pea\b')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bGreen pea\b')==False)))]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2002.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2002.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[(temp['ABSTRACT'].str.contains(r'\blegume') | temp['PROJECT_TERMS'].str.contains(r'\blegume')| 
           temp['PROJECT_TITLE'].str.contains(r'\blegume') |temp['ABSTRACT'].str.contains(r'\bLegume') | 
           temp['PROJECT_TERMS'].str.contains(r'\bLegume')| temp['PROJECT_TITLE'].str.contains(r'\bLegume'))|
           (temp['ABSTRACT'].str.contains(r'\blentil') | temp['PROJECT_TERMS'].str.contains(r'\blentil')| 
           temp['PROJECT_TITLE'].str.contains(r'\blentil') |temp['ABSTRACT'].str.contains(r'\bLentil') | 
           temp['PROJECT_TERMS'].str.contains(r'\bLentil')| temp['PROJECT_TITLE'].str.contains(r'\bLentil')) |
           (temp['ABSTRACT'].str.contains(r'\bedamame\b') | temp['PROJECT_TERMS'].str.contains(r'\bedamame\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bedamame\b') |temp['ABSTRACT'].str.contains(r'\bEdamame\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bEdamame\b')| temp['PROJECT_TITLE'].str.contains(r'\bEdamame\b'))|
          ((temp['ABSTRACT'].str.contains(r'\bbean') | temp['PROJECT_TERMS'].str.contains(r'\bbean')| 
           temp['PROJECT_TITLE'].str.contains(r'\bbean') |temp['ABSTRACT'].str.contains(r'\bbean') | 
           temp['PROJECT_TERMS'].str.contains(r'\bbean')| temp['PROJECT_TITLE'].str.contains(r'\bbean'))&
           ((temp['ABSTRACT'].str.contains(r'\bsoybean')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bsoybean')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bsoybean')==False) |(temp['ABSTRACT'].str.contains(r'\bSoybean')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bSoybean')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bSoybean')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bsoy')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bsoy')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bsoy')==False) |(temp['ABSTRACT'].str.contains(r'\bSoy')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bSoy')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bSoy')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bgreen bean')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bgreen bean')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bgreen bean')==False) |(temp['ABSTRACT'].str.contains(r'\bGreen bean')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bGreen bean')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bGreen bean')==False))) |
          ((temp['ABSTRACT'].str.contains(r'\bpeanut\b') | temp['PROJECT_TERMS'].str.contains(r'\bpeanut\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bpeanut\b') |temp['ABSTRACT'].str.contains(r'\bPeanut\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bPeaut\b')| temp['PROJECT_TITLE'].str.contains(r'\bPeanut\b'))|
           (temp['ABSTRACT'].str.contains(r'\bpeanuts\b') | temp['PROJECT_TERMS'].str.contains(r'\bpeanuts\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bpeanuts\b') |temp['ABSTRACT'].str.contains(r'\bPeanuts\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bPeanuts\b')| temp['PROJECT_TITLE'].str.contains(r'\bPeanuts\b'))&
           ((temp['ABSTRACT'].str.contains(r'\bnut')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bnut')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bnut')==False) |(temp['ABSTRACT'].str.contains(r'\bNut')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bNut')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bNut')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bnuts')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bnuts')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bnuts')==False) |(temp['ABSTRACT'].str.contains(r'\bNuts')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bNuts')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bNuts')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bhazelnuts')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bhazelnuts')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bhazelnuts')==False) |(temp['ABSTRACT'].str.contains(r'\bHazelnuts')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bHazelnuts')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bHazelnuts')==False))&
           (temp['ABSTRACT'].str.contains(r'\bchickpea\b') | temp['PROJECT_TERMS'].str.contains(r'\bchickpea\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bchickpea\b') |temp['ABSTRACT'].str.contains(r'\bChickpea\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bChickpea\b')| temp['PROJECT_TITLE'].str.contains(r'\bChickpea\b'))|
           (temp['ABSTRACT'].str.contains(r'\bpea\b') | temp['PROJECT_TERMS'].str.contains(r'\bpea\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bpea\b') |temp['ABSTRACT'].str.contains(r'\bPea\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bPea\b')| temp['PROJECT_TITLE'].str.contains(r'\bPea\b')) &
           ((temp['ABSTRACT'].str.contains(r'\bgreen pea\b')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bgreen pea\b')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bgreen p\b')==False) |(temp['ABSTRACT'].str.contains(r'\bGreen pea\b')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bGreen pea\b')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bGreen pea\b')==False)))]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2003.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2003.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[(temp['ABSTRACT'].str.contains(r'\blegume') | temp['PROJECT_TERMS'].str.contains(r'\blegume')| 
           temp['PROJECT_TITLE'].str.contains(r'\blegume') |temp['ABSTRACT'].str.contains(r'\bLegume') | 
           temp['PROJECT_TERMS'].str.contains(r'\bLegume')| temp['PROJECT_TITLE'].str.contains(r'\bLegume'))|
           (temp['ABSTRACT'].str.contains(r'\blentil') | temp['PROJECT_TERMS'].str.contains(r'\blentil')| 
           temp['PROJECT_TITLE'].str.contains(r'\blentil') |temp['ABSTRACT'].str.contains(r'\bLentil') | 
           temp['PROJECT_TERMS'].str.contains(r'\bLentil')| temp['PROJECT_TITLE'].str.contains(r'\bLentil')) |
           (temp['ABSTRACT'].str.contains(r'\bedamame\b') | temp['PROJECT_TERMS'].str.contains(r'\bedamame\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bedamame\b') |temp['ABSTRACT'].str.contains(r'\bEdamame\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bEdamame\b')| temp['PROJECT_TITLE'].str.contains(r'\bEdamame\b'))|
          ((temp['ABSTRACT'].str.contains(r'\bbean') | temp['PROJECT_TERMS'].str.contains(r'\bbean')| 
           temp['PROJECT_TITLE'].str.contains(r'\bbean') |temp['ABSTRACT'].str.contains(r'\bbean') | 
           temp['PROJECT_TERMS'].str.contains(r'\bbean')| temp['PROJECT_TITLE'].str.contains(r'\bbean'))&
           ((temp['ABSTRACT'].str.contains(r'\bsoybean')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bsoybean')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bsoybean')==False) |(temp['ABSTRACT'].str.contains(r'\bSoybean')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bSoybean')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bSoybean')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bsoy')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bsoy')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bsoy')==False) |(temp['ABSTRACT'].str.contains(r'\bSoy')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bSoy')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bSoy')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bgreen bean')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bgreen bean')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bgreen bean')==False) |(temp['ABSTRACT'].str.contains(r'\bGreen bean')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bGreen bean')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bGreen bean')==False))) |
          ((temp['ABSTRACT'].str.contains(r'\bpeanut\b') | temp['PROJECT_TERMS'].str.contains(r'\bpeanut\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bpeanut\b') |temp['ABSTRACT'].str.contains(r'\bPeanut\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bPeaut\b')| temp['PROJECT_TITLE'].str.contains(r'\bPeanut\b'))|
           (temp['ABSTRACT'].str.contains(r'\bpeanuts\b') | temp['PROJECT_TERMS'].str.contains(r'\bpeanuts\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bpeanuts\b') |temp['ABSTRACT'].str.contains(r'\bPeanuts\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bPeanuts\b')| temp['PROJECT_TITLE'].str.contains(r'\bPeanuts\b'))&
           ((temp['ABSTRACT'].str.contains(r'\bnut')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bnut')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bnut')==False) |(temp['ABSTRACT'].str.contains(r'\bNut')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bNut')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bNut')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bnuts')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bnuts')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bnuts')==False) |(temp['ABSTRACT'].str.contains(r'\bNuts')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bNuts')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bNuts')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bhazelnuts')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bhazelnuts')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bhazelnuts')==False) |(temp['ABSTRACT'].str.contains(r'\bHazelnuts')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bHazelnuts')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bHazelnuts')==False))&
           (temp['ABSTRACT'].str.contains(r'\bchickpea\b') | temp['PROJECT_TERMS'].str.contains(r'\bchickpea\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bchickpea\b') |temp['ABSTRACT'].str.contains(r'\bChickpea\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bChickpea\b')| temp['PROJECT_TITLE'].str.contains(r'\bChickpea\b'))|
           (temp['ABSTRACT'].str.contains(r'\bpea\b') | temp['PROJECT_TERMS'].str.contains(r'\bpea\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bpea\b') |temp['ABSTRACT'].str.contains(r'\bPea\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bPea\b')| temp['PROJECT_TITLE'].str.contains(r'\bPea\b')) &
           ((temp['ABSTRACT'].str.contains(r'\bgreen pea\b')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bgreen pea\b')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bgreen p\b')==False) |(temp['ABSTRACT'].str.contains(r'\bGreen pea\b')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bGreen pea\b')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bGreen pea\b')==False)))]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)


df_abs=pd.read_csv('abstract/PRJABS_2004.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2004.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[(temp['ABSTRACT'].str.contains(r'\blegume') | temp['PROJECT_TERMS'].str.contains(r'\blegume')| 
           temp['PROJECT_TITLE'].str.contains(r'\blegume') |temp['ABSTRACT'].str.contains(r'\bLegume') | 
           temp['PROJECT_TERMS'].str.contains(r'\bLegume')| temp['PROJECT_TITLE'].str.contains(r'\bLegume'))|
           (temp['ABSTRACT'].str.contains(r'\blentil') | temp['PROJECT_TERMS'].str.contains(r'\blentil')| 
           temp['PROJECT_TITLE'].str.contains(r'\blentil') |temp['ABSTRACT'].str.contains(r'\bLentil') | 
           temp['PROJECT_TERMS'].str.contains(r'\bLentil')| temp['PROJECT_TITLE'].str.contains(r'\bLentil')) |
           (temp['ABSTRACT'].str.contains(r'\bedamame\b') | temp['PROJECT_TERMS'].str.contains(r'\bedamame\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bedamame\b') |temp['ABSTRACT'].str.contains(r'\bEdamame\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bEdamame\b')| temp['PROJECT_TITLE'].str.contains(r'\bEdamame\b'))|
          ((temp['ABSTRACT'].str.contains(r'\bbean') | temp['PROJECT_TERMS'].str.contains(r'\bbean')| 
           temp['PROJECT_TITLE'].str.contains(r'\bbean') |temp['ABSTRACT'].str.contains(r'\bbean') | 
           temp['PROJECT_TERMS'].str.contains(r'\bbean')| temp['PROJECT_TITLE'].str.contains(r'\bbean'))&
           ((temp['ABSTRACT'].str.contains(r'\bsoybean')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bsoybean')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bsoybean')==False) |(temp['ABSTRACT'].str.contains(r'\bSoybean')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bSoybean')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bSoybean')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bsoy')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bsoy')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bsoy')==False) |(temp['ABSTRACT'].str.contains(r'\bSoy')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bSoy')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bSoy')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bgreen bean')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bgreen bean')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bgreen bean')==False) |(temp['ABSTRACT'].str.contains(r'\bGreen bean')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bGreen bean')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bGreen bean')==False))) |
          ((temp['ABSTRACT'].str.contains(r'\bpeanut\b') | temp['PROJECT_TERMS'].str.contains(r'\bpeanut\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bpeanut\b') |temp['ABSTRACT'].str.contains(r'\bPeanut\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bPeaut\b')| temp['PROJECT_TITLE'].str.contains(r'\bPeanut\b'))|
           (temp['ABSTRACT'].str.contains(r'\bpeanuts\b') | temp['PROJECT_TERMS'].str.contains(r'\bpeanuts\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bpeanuts\b') |temp['ABSTRACT'].str.contains(r'\bPeanuts\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bPeanuts\b')| temp['PROJECT_TITLE'].str.contains(r'\bPeanuts\b'))&
           ((temp['ABSTRACT'].str.contains(r'\bnut')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bnut')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bnut')==False) |(temp['ABSTRACT'].str.contains(r'\bNut')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bNut')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bNut')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bnuts')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bnuts')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bnuts')==False) |(temp['ABSTRACT'].str.contains(r'\bNuts')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bNuts')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bNuts')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bhazelnuts')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bhazelnuts')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bhazelnuts')==False) |(temp['ABSTRACT'].str.contains(r'\bHazelnuts')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bHazelnuts')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bHazelnuts')==False))&
           (temp['ABSTRACT'].str.contains(r'\bchickpea\b') | temp['PROJECT_TERMS'].str.contains(r'\bchickpea\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bchickpea\b') |temp['ABSTRACT'].str.contains(r'\bChickpea\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bChickpea\b')| temp['PROJECT_TITLE'].str.contains(r'\bChickpea\b'))|
           (temp['ABSTRACT'].str.contains(r'\bpea\b') | temp['PROJECT_TERMS'].str.contains(r'\bpea\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bpea\b') |temp['ABSTRACT'].str.contains(r'\bPea\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bPea\b')| temp['PROJECT_TITLE'].str.contains(r'\bPea\b')) &
           ((temp['ABSTRACT'].str.contains(r'\bgreen pea\b')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bgreen pea\b')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bgreen p\b')==False) |(temp['ABSTRACT'].str.contains(r'\bGreen pea\b')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bGreen pea\b')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bGreen pea\b')==False)))]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2005.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2005.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[(temp['ABSTRACT'].str.contains(r'\blegume') | temp['PROJECT_TERMS'].str.contains(r'\blegume')| 
           temp['PROJECT_TITLE'].str.contains(r'\blegume') |temp['ABSTRACT'].str.contains(r'\bLegume') | 
           temp['PROJECT_TERMS'].str.contains(r'\bLegume')| temp['PROJECT_TITLE'].str.contains(r'\bLegume'))|
           (temp['ABSTRACT'].str.contains(r'\blentil') | temp['PROJECT_TERMS'].str.contains(r'\blentil')| 
           temp['PROJECT_TITLE'].str.contains(r'\blentil') |temp['ABSTRACT'].str.contains(r'\bLentil') | 
           temp['PROJECT_TERMS'].str.contains(r'\bLentil')| temp['PROJECT_TITLE'].str.contains(r'\bLentil')) |
           (temp['ABSTRACT'].str.contains(r'\bedamame\b') | temp['PROJECT_TERMS'].str.contains(r'\bedamame\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bedamame\b') |temp['ABSTRACT'].str.contains(r'\bEdamame\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bEdamame\b')| temp['PROJECT_TITLE'].str.contains(r'\bEdamame\b'))|
          ((temp['ABSTRACT'].str.contains(r'\bbean') | temp['PROJECT_TERMS'].str.contains(r'\bbean')| 
           temp['PROJECT_TITLE'].str.contains(r'\bbean') |temp['ABSTRACT'].str.contains(r'\bbean') | 
           temp['PROJECT_TERMS'].str.contains(r'\bbean')| temp['PROJECT_TITLE'].str.contains(r'\bbean'))&
           ((temp['ABSTRACT'].str.contains(r'\bsoybean')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bsoybean')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bsoybean')==False) |(temp['ABSTRACT'].str.contains(r'\bSoybean')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bSoybean')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bSoybean')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bsoy')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bsoy')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bsoy')==False) |(temp['ABSTRACT'].str.contains(r'\bSoy')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bSoy')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bSoy')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bgreen bean')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bgreen bean')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bgreen bean')==False) |(temp['ABSTRACT'].str.contains(r'\bGreen bean')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bGreen bean')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bGreen bean')==False))) |
          ((temp['ABSTRACT'].str.contains(r'\bpeanut\b') | temp['PROJECT_TERMS'].str.contains(r'\bpeanut\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bpeanut\b') |temp['ABSTRACT'].str.contains(r'\bPeanut\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bPeaut\b')| temp['PROJECT_TITLE'].str.contains(r'\bPeanut\b'))|
           (temp['ABSTRACT'].str.contains(r'\bpeanuts\b') | temp['PROJECT_TERMS'].str.contains(r'\bpeanuts\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bpeanuts\b') |temp['ABSTRACT'].str.contains(r'\bPeanuts\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bPeanuts\b')| temp['PROJECT_TITLE'].str.contains(r'\bPeanuts\b'))&
           ((temp['ABSTRACT'].str.contains(r'\bnut')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bnut')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bnut')==False) |(temp['ABSTRACT'].str.contains(r'\bNut')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bNut')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bNut')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bnuts')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bnuts')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bnuts')==False) |(temp['ABSTRACT'].str.contains(r'\bNuts')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bNuts')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bNuts')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bhazelnuts')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bhazelnuts')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bhazelnuts')==False) |(temp['ABSTRACT'].str.contains(r'\bHazelnuts')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bHazelnuts')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bHazelnuts')==False))&
           (temp['ABSTRACT'].str.contains(r'\bchickpea\b') | temp['PROJECT_TERMS'].str.contains(r'\bchickpea\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bchickpea\b') |temp['ABSTRACT'].str.contains(r'\bChickpea\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bChickpea\b')| temp['PROJECT_TITLE'].str.contains(r'\bChickpea\b'))|
           (temp['ABSTRACT'].str.contains(r'\bpea\b') | temp['PROJECT_TERMS'].str.contains(r'\bpea\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bpea\b') |temp['ABSTRACT'].str.contains(r'\bPea\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bPea\b')| temp['PROJECT_TITLE'].str.contains(r'\bPea\b')) &
           ((temp['ABSTRACT'].str.contains(r'\bgreen pea\b')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bgreen pea\b')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bgreen p\b')==False) |(temp['ABSTRACT'].str.contains(r'\bGreen pea\b')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bGreen pea\b')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bGreen pea\b')==False)))]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)


df_abs=pd.read_csv('abstract/PRJABS_2006.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2006.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[(temp['ABSTRACT'].str.contains(r'\blegume') | temp['PROJECT_TERMS'].str.contains(r'\blegume')| 
           temp['PROJECT_TITLE'].str.contains(r'\blegume') |temp['ABSTRACT'].str.contains(r'\bLegume') | 
           temp['PROJECT_TERMS'].str.contains(r'\bLegume')| temp['PROJECT_TITLE'].str.contains(r'\bLegume'))|
           (temp['ABSTRACT'].str.contains(r'\blentil') | temp['PROJECT_TERMS'].str.contains(r'\blentil')| 
           temp['PROJECT_TITLE'].str.contains(r'\blentil') |temp['ABSTRACT'].str.contains(r'\bLentil') | 
           temp['PROJECT_TERMS'].str.contains(r'\bLentil')| temp['PROJECT_TITLE'].str.contains(r'\bLentil')) |
           (temp['ABSTRACT'].str.contains(r'\bedamame\b') | temp['PROJECT_TERMS'].str.contains(r'\bedamame\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bedamame\b') |temp['ABSTRACT'].str.contains(r'\bEdamame\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bEdamame\b')| temp['PROJECT_TITLE'].str.contains(r'\bEdamame\b'))|
          ((temp['ABSTRACT'].str.contains(r'\bbean') | temp['PROJECT_TERMS'].str.contains(r'\bbean')| 
           temp['PROJECT_TITLE'].str.contains(r'\bbean') |temp['ABSTRACT'].str.contains(r'\bbean') | 
           temp['PROJECT_TERMS'].str.contains(r'\bbean')| temp['PROJECT_TITLE'].str.contains(r'\bbean'))&
           ((temp['ABSTRACT'].str.contains(r'\bsoybean')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bsoybean')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bsoybean')==False) |(temp['ABSTRACT'].str.contains(r'\bSoybean')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bSoybean')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bSoybean')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bsoy')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bsoy')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bsoy')==False) |(temp['ABSTRACT'].str.contains(r'\bSoy')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bSoy')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bSoy')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bgreen bean')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bgreen bean')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bgreen bean')==False) |(temp['ABSTRACT'].str.contains(r'\bGreen bean')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bGreen bean')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bGreen bean')==False))) |
          ((temp['ABSTRACT'].str.contains(r'\bpeanut\b') | temp['PROJECT_TERMS'].str.contains(r'\bpeanut\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bpeanut\b') |temp['ABSTRACT'].str.contains(r'\bPeanut\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bPeaut\b')| temp['PROJECT_TITLE'].str.contains(r'\bPeanut\b'))|
           (temp['ABSTRACT'].str.contains(r'\bpeanuts\b') | temp['PROJECT_TERMS'].str.contains(r'\bpeanuts\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bpeanuts\b') |temp['ABSTRACT'].str.contains(r'\bPeanuts\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bPeanuts\b')| temp['PROJECT_TITLE'].str.contains(r'\bPeanuts\b'))&
           ((temp['ABSTRACT'].str.contains(r'\bnut')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bnut')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bnut')==False) |(temp['ABSTRACT'].str.contains(r'\bNut')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bNut')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bNut')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bnuts')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bnuts')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bnuts')==False) |(temp['ABSTRACT'].str.contains(r'\bNuts')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bNuts')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bNuts')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bhazelnuts')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bhazelnuts')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bhazelnuts')==False) |(temp['ABSTRACT'].str.contains(r'\bHazelnuts')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bHazelnuts')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bHazelnuts')==False))&
           (temp['ABSTRACT'].str.contains(r'\bchickpea\b') | temp['PROJECT_TERMS'].str.contains(r'\bchickpea\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bchickpea\b') |temp['ABSTRACT'].str.contains(r'\bChickpea\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bChickpea\b')| temp['PROJECT_TITLE'].str.contains(r'\bChickpea\b'))|
           (temp['ABSTRACT'].str.contains(r'\bpea\b') | temp['PROJECT_TERMS'].str.contains(r'\bpea\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bpea\b') |temp['ABSTRACT'].str.contains(r'\bPea\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bPea\b')| temp['PROJECT_TITLE'].str.contains(r'\bPea\b')) &
           ((temp['ABSTRACT'].str.contains(r'\bgreen pea\b')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bgreen pea\b')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bgreen p\b')==False) |(temp['ABSTRACT'].str.contains(r'\bGreen pea\b')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bGreen pea\b')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bGreen pea\b')==False)))]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)


df_abs=pd.read_csv('abstract/PRJABS_2007.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2007.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[(temp['ABSTRACT'].str.contains(r'\blegume') | temp['PROJECT_TERMS'].str.contains(r'\blegume')| 
           temp['PROJECT_TITLE'].str.contains(r'\blegume') |temp['ABSTRACT'].str.contains(r'\bLegume') | 
           temp['PROJECT_TERMS'].str.contains(r'\bLegume')| temp['PROJECT_TITLE'].str.contains(r'\bLegume'))|
           (temp['ABSTRACT'].str.contains(r'\blentil') | temp['PROJECT_TERMS'].str.contains(r'\blentil')| 
           temp['PROJECT_TITLE'].str.contains(r'\blentil') |temp['ABSTRACT'].str.contains(r'\bLentil') | 
           temp['PROJECT_TERMS'].str.contains(r'\bLentil')| temp['PROJECT_TITLE'].str.contains(r'\bLentil')) |
           (temp['ABSTRACT'].str.contains(r'\bedamame\b') | temp['PROJECT_TERMS'].str.contains(r'\bedamame\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bedamame\b') |temp['ABSTRACT'].str.contains(r'\bEdamame\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bEdamame\b')| temp['PROJECT_TITLE'].str.contains(r'\bEdamame\b'))|
          ((temp['ABSTRACT'].str.contains(r'\bbean') | temp['PROJECT_TERMS'].str.contains(r'\bbean')| 
           temp['PROJECT_TITLE'].str.contains(r'\bbean') |temp['ABSTRACT'].str.contains(r'\bbean') | 
           temp['PROJECT_TERMS'].str.contains(r'\bbean')| temp['PROJECT_TITLE'].str.contains(r'\bbean'))&
           ((temp['ABSTRACT'].str.contains(r'\bsoybean')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bsoybean')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bsoybean')==False) |(temp['ABSTRACT'].str.contains(r'\bSoybean')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bSoybean')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bSoybean')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bsoy')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bsoy')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bsoy')==False) |(temp['ABSTRACT'].str.contains(r'\bSoy')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bSoy')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bSoy')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bgreen bean')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bgreen bean')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bgreen bean')==False) |(temp['ABSTRACT'].str.contains(r'\bGreen bean')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bGreen bean')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bGreen bean')==False))) |
          ((temp['ABSTRACT'].str.contains(r'\bpeanut\b') | temp['PROJECT_TERMS'].str.contains(r'\bpeanut\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bpeanut\b') |temp['ABSTRACT'].str.contains(r'\bPeanut\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bPeaut\b')| temp['PROJECT_TITLE'].str.contains(r'\bPeanut\b'))|
           (temp['ABSTRACT'].str.contains(r'\bpeanuts\b') | temp['PROJECT_TERMS'].str.contains(r'\bpeanuts\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bpeanuts\b') |temp['ABSTRACT'].str.contains(r'\bPeanuts\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bPeanuts\b')| temp['PROJECT_TITLE'].str.contains(r'\bPeanuts\b'))&
           ((temp['ABSTRACT'].str.contains(r'\bnut')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bnut')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bnut')==False) |(temp['ABSTRACT'].str.contains(r'\bNut')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bNut')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bNut')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bnuts')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bnuts')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bnuts')==False) |(temp['ABSTRACT'].str.contains(r'\bNuts')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bNuts')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bNuts')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bhazelnuts')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bhazelnuts')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bhazelnuts')==False) |(temp['ABSTRACT'].str.contains(r'\bHazelnuts')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bHazelnuts')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bHazelnuts')==False))&
           (temp['ABSTRACT'].str.contains(r'\bchickpea\b') | temp['PROJECT_TERMS'].str.contains(r'\bchickpea\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bchickpea\b') |temp['ABSTRACT'].str.contains(r'\bChickpea\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bChickpea\b')| temp['PROJECT_TITLE'].str.contains(r'\bChickpea\b'))|
           (temp['ABSTRACT'].str.contains(r'\bpea\b') | temp['PROJECT_TERMS'].str.contains(r'\bpea\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bpea\b') |temp['ABSTRACT'].str.contains(r'\bPea\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bPea\b')| temp['PROJECT_TITLE'].str.contains(r'\bPea\b')) &
           ((temp['ABSTRACT'].str.contains(r'\bgreen pea\b')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bgreen pea\b')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bgreen p\b')==False) |(temp['ABSTRACT'].str.contains(r'\bGreen pea\b')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bGreen pea\b')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bGreen pea\b')==False)))]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2008.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2008.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[(temp['ABSTRACT'].str.contains(r'\blegume') | temp['PROJECT_TERMS'].str.contains(r'\blegume')| 
           temp['PROJECT_TITLE'].str.contains(r'\blegume') |temp['ABSTRACT'].str.contains(r'\bLegume') | 
           temp['PROJECT_TERMS'].str.contains(r'\bLegume')| temp['PROJECT_TITLE'].str.contains(r'\bLegume'))|
           (temp['ABSTRACT'].str.contains(r'\blentil') | temp['PROJECT_TERMS'].str.contains(r'\blentil')| 
           temp['PROJECT_TITLE'].str.contains(r'\blentil') |temp['ABSTRACT'].str.contains(r'\bLentil') | 
           temp['PROJECT_TERMS'].str.contains(r'\bLentil')| temp['PROJECT_TITLE'].str.contains(r'\bLentil')) |
           (temp['ABSTRACT'].str.contains(r'\bedamame\b') | temp['PROJECT_TERMS'].str.contains(r'\bedamame\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bedamame\b') |temp['ABSTRACT'].str.contains(r'\bEdamame\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bEdamame\b')| temp['PROJECT_TITLE'].str.contains(r'\bEdamame\b'))|
          ((temp['ABSTRACT'].str.contains(r'\bbean') | temp['PROJECT_TERMS'].str.contains(r'\bbean')| 
           temp['PROJECT_TITLE'].str.contains(r'\bbean') |temp['ABSTRACT'].str.contains(r'\bbean') | 
           temp['PROJECT_TERMS'].str.contains(r'\bbean')| temp['PROJECT_TITLE'].str.contains(r'\bbean'))&
           ((temp['ABSTRACT'].str.contains(r'\bsoybean')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bsoybean')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bsoybean')==False) |(temp['ABSTRACT'].str.contains(r'\bSoybean')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bSoybean')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bSoybean')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bsoy')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bsoy')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bsoy')==False) |(temp['ABSTRACT'].str.contains(r'\bSoy')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bSoy')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bSoy')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bgreen bean')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bgreen bean')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bgreen bean')==False) |(temp['ABSTRACT'].str.contains(r'\bGreen bean')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bGreen bean')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bGreen bean')==False))) |
          ((temp['ABSTRACT'].str.contains(r'\bpeanut\b') | temp['PROJECT_TERMS'].str.contains(r'\bpeanut\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bpeanut\b') |temp['ABSTRACT'].str.contains(r'\bPeanut\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bPeaut\b')| temp['PROJECT_TITLE'].str.contains(r'\bPeanut\b'))|
           (temp['ABSTRACT'].str.contains(r'\bpeanuts\b') | temp['PROJECT_TERMS'].str.contains(r'\bpeanuts\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bpeanuts\b') |temp['ABSTRACT'].str.contains(r'\bPeanuts\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bPeanuts\b')| temp['PROJECT_TITLE'].str.contains(r'\bPeanuts\b'))&
           ((temp['ABSTRACT'].str.contains(r'\bnut')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bnut')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bnut')==False) |(temp['ABSTRACT'].str.contains(r'\bNut')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bNut')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bNut')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bnuts')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bnuts')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bnuts')==False) |(temp['ABSTRACT'].str.contains(r'\bNuts')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bNuts')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bNuts')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bhazelnuts')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bhazelnuts')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bhazelnuts')==False) |(temp['ABSTRACT'].str.contains(r'\bHazelnuts')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bHazelnuts')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bHazelnuts')==False))&
           (temp['ABSTRACT'].str.contains(r'\bchickpea\b') | temp['PROJECT_TERMS'].str.contains(r'\bchickpea\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bchickpea\b') |temp['ABSTRACT'].str.contains(r'\bChickpea\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bChickpea\b')| temp['PROJECT_TITLE'].str.contains(r'\bChickpea\b'))|
           (temp['ABSTRACT'].str.contains(r'\bpea\b') | temp['PROJECT_TERMS'].str.contains(r'\bpea\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bpea\b') |temp['ABSTRACT'].str.contains(r'\bPea\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bPea\b')| temp['PROJECT_TITLE'].str.contains(r'\bPea\b')) &
           ((temp['ABSTRACT'].str.contains(r'\bgreen pea\b')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bgreen pea\b')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bgreen p\b')==False) |(temp['ABSTRACT'].str.contains(r'\bGreen pea\b')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bGreen pea\b')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bGreen pea\b')==False)))]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)


df_abs=pd.read_csv('abstract/PRJABS_2009.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2009.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[(temp['ABSTRACT'].str.contains(r'\blegume') | temp['PROJECT_TERMS'].str.contains(r'\blegume')| 
           temp['PROJECT_TITLE'].str.contains(r'\blegume') |temp['ABSTRACT'].str.contains(r'\bLegume') | 
           temp['PROJECT_TERMS'].str.contains(r'\bLegume')| temp['PROJECT_TITLE'].str.contains(r'\bLegume'))|
           (temp['ABSTRACT'].str.contains(r'\blentil') | temp['PROJECT_TERMS'].str.contains(r'\blentil')| 
           temp['PROJECT_TITLE'].str.contains(r'\blentil') |temp['ABSTRACT'].str.contains(r'\bLentil') | 
           temp['PROJECT_TERMS'].str.contains(r'\bLentil')| temp['PROJECT_TITLE'].str.contains(r'\bLentil')) |
           (temp['ABSTRACT'].str.contains(r'\bedamame\b') | temp['PROJECT_TERMS'].str.contains(r'\bedamame\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bedamame\b') |temp['ABSTRACT'].str.contains(r'\bEdamame\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bEdamame\b')| temp['PROJECT_TITLE'].str.contains(r'\bEdamame\b'))|
          ((temp['ABSTRACT'].str.contains(r'\bbean') | temp['PROJECT_TERMS'].str.contains(r'\bbean')| 
           temp['PROJECT_TITLE'].str.contains(r'\bbean') |temp['ABSTRACT'].str.contains(r'\bbean') | 
           temp['PROJECT_TERMS'].str.contains(r'\bbean')| temp['PROJECT_TITLE'].str.contains(r'\bbean'))&
           ((temp['ABSTRACT'].str.contains(r'\bsoybean')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bsoybean')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bsoybean')==False) |(temp['ABSTRACT'].str.contains(r'\bSoybean')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bSoybean')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bSoybean')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bsoy')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bsoy')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bsoy')==False) |(temp['ABSTRACT'].str.contains(r'\bSoy')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bSoy')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bSoy')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bgreen bean')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bgreen bean')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bgreen bean')==False) |(temp['ABSTRACT'].str.contains(r'\bGreen bean')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bGreen bean')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bGreen bean')==False))) |
          ((temp['ABSTRACT'].str.contains(r'\bpeanut\b') | temp['PROJECT_TERMS'].str.contains(r'\bpeanut\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bpeanut\b') |temp['ABSTRACT'].str.contains(r'\bPeanut\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bPeaut\b')| temp['PROJECT_TITLE'].str.contains(r'\bPeanut\b'))|
           (temp['ABSTRACT'].str.contains(r'\bpeanuts\b') | temp['PROJECT_TERMS'].str.contains(r'\bpeanuts\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bpeanuts\b') |temp['ABSTRACT'].str.contains(r'\bPeanuts\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bPeanuts\b')| temp['PROJECT_TITLE'].str.contains(r'\bPeanuts\b'))&
           ((temp['ABSTRACT'].str.contains(r'\bnut')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bnut')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bnut')==False) |(temp['ABSTRACT'].str.contains(r'\bNut')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bNut')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bNut')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bnuts')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bnuts')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bnuts')==False) |(temp['ABSTRACT'].str.contains(r'\bNuts')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bNuts')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bNuts')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bhazelnuts')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bhazelnuts')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bhazelnuts')==False) |(temp['ABSTRACT'].str.contains(r'\bHazelnuts')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bHazelnuts')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bHazelnuts')==False))&
           (temp['ABSTRACT'].str.contains(r'\bchickpea\b') | temp['PROJECT_TERMS'].str.contains(r'\bchickpea\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bchickpea\b') |temp['ABSTRACT'].str.contains(r'\bChickpea\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bChickpea\b')| temp['PROJECT_TITLE'].str.contains(r'\bChickpea\b'))|
           (temp['ABSTRACT'].str.contains(r'\bpea\b') | temp['PROJECT_TERMS'].str.contains(r'\bpea\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bpea\b') |temp['ABSTRACT'].str.contains(r'\bPea\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bPea\b')| temp['PROJECT_TITLE'].str.contains(r'\bPea\b')) &
           ((temp['ABSTRACT'].str.contains(r'\bgreen pea\b')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bgreen pea\b')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bgreen p\b')==False) |(temp['ABSTRACT'].str.contains(r'\bGreen pea\b')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bGreen pea\b')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bGreen pea\b')==False)))]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)


df_abs=pd.read_csv('abstract/PRJABS_2010.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2010.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[(temp['ABSTRACT'].str.contains(r'\blegume') | temp['PROJECT_TERMS'].str.contains(r'\blegume')| 
           temp['PROJECT_TITLE'].str.contains(r'\blegume') |temp['ABSTRACT'].str.contains(r'\bLegume') | 
           temp['PROJECT_TERMS'].str.contains(r'\bLegume')| temp['PROJECT_TITLE'].str.contains(r'\bLegume'))|
           (temp['ABSTRACT'].str.contains(r'\blentil') | temp['PROJECT_TERMS'].str.contains(r'\blentil')| 
           temp['PROJECT_TITLE'].str.contains(r'\blentil') |temp['ABSTRACT'].str.contains(r'\bLentil') | 
           temp['PROJECT_TERMS'].str.contains(r'\bLentil')| temp['PROJECT_TITLE'].str.contains(r'\bLentil')) |
           (temp['ABSTRACT'].str.contains(r'\bedamame\b') | temp['PROJECT_TERMS'].str.contains(r'\bedamame\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bedamame\b') |temp['ABSTRACT'].str.contains(r'\bEdamame\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bEdamame\b')| temp['PROJECT_TITLE'].str.contains(r'\bEdamame\b'))|
          ((temp['ABSTRACT'].str.contains(r'\bbean') | temp['PROJECT_TERMS'].str.contains(r'\bbean')| 
           temp['PROJECT_TITLE'].str.contains(r'\bbean') |temp['ABSTRACT'].str.contains(r'\bbean') | 
           temp['PROJECT_TERMS'].str.contains(r'\bbean')| temp['PROJECT_TITLE'].str.contains(r'\bbean'))&
           ((temp['ABSTRACT'].str.contains(r'\bsoybean')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bsoybean')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bsoybean')==False) |(temp['ABSTRACT'].str.contains(r'\bSoybean')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bSoybean')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bSoybean')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bsoy')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bsoy')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bsoy')==False) |(temp['ABSTRACT'].str.contains(r'\bSoy')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bSoy')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bSoy')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bgreen bean')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bgreen bean')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bgreen bean')==False) |(temp['ABSTRACT'].str.contains(r'\bGreen bean')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bGreen bean')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bGreen bean')==False))) |
          ((temp['ABSTRACT'].str.contains(r'\bpeanut\b') | temp['PROJECT_TERMS'].str.contains(r'\bpeanut\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bpeanut\b') |temp['ABSTRACT'].str.contains(r'\bPeanut\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bPeaut\b')| temp['PROJECT_TITLE'].str.contains(r'\bPeanut\b'))|
           (temp['ABSTRACT'].str.contains(r'\bpeanuts\b') | temp['PROJECT_TERMS'].str.contains(r'\bpeanuts\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bpeanuts\b') |temp['ABSTRACT'].str.contains(r'\bPeanuts\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bPeanuts\b')| temp['PROJECT_TITLE'].str.contains(r'\bPeanuts\b'))&
           ((temp['ABSTRACT'].str.contains(r'\bnut')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bnut')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bnut')==False) |(temp['ABSTRACT'].str.contains(r'\bNut')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bNut')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bNut')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bnuts')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bnuts')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bnuts')==False) |(temp['ABSTRACT'].str.contains(r'\bNuts')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bNuts')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bNuts')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bhazelnuts')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bhazelnuts')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bhazelnuts')==False) |(temp['ABSTRACT'].str.contains(r'\bHazelnuts')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bHazelnuts')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bHazelnuts')==False))&
           (temp['ABSTRACT'].str.contains(r'\bchickpea\b') | temp['PROJECT_TERMS'].str.contains(r'\bchickpea\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bchickpea\b') |temp['ABSTRACT'].str.contains(r'\bChickpea\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bChickpea\b')| temp['PROJECT_TITLE'].str.contains(r'\bChickpea\b'))|
           (temp['ABSTRACT'].str.contains(r'\bpea\b') | temp['PROJECT_TERMS'].str.contains(r'\bpea\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bpea\b') |temp['ABSTRACT'].str.contains(r'\bPea\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bPea\b')| temp['PROJECT_TITLE'].str.contains(r'\bPea\b')) &
           ((temp['ABSTRACT'].str.contains(r'\bgreen pea\b')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bgreen pea\b')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bgreen p\b')==False) |(temp['ABSTRACT'].str.contains(r'\bGreen pea\b')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bGreen pea\b')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bGreen pea\b')==False)))]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)


df_abs=pd.read_csv('abstract/PRJABS_2011.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2011.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[(temp['ABSTRACT'].str.contains(r'\blegume') | temp['PROJECT_TERMS'].str.contains(r'\blegume')| 
           temp['PROJECT_TITLE'].str.contains(r'\blegume') |temp['ABSTRACT'].str.contains(r'\bLegume') | 
           temp['PROJECT_TERMS'].str.contains(r'\bLegume')| temp['PROJECT_TITLE'].str.contains(r'\bLegume'))|
           (temp['ABSTRACT'].str.contains(r'\blentil') | temp['PROJECT_TERMS'].str.contains(r'\blentil')| 
           temp['PROJECT_TITLE'].str.contains(r'\blentil') |temp['ABSTRACT'].str.contains(r'\bLentil') | 
           temp['PROJECT_TERMS'].str.contains(r'\bLentil')| temp['PROJECT_TITLE'].str.contains(r'\bLentil')) |
           (temp['ABSTRACT'].str.contains(r'\bedamame\b') | temp['PROJECT_TERMS'].str.contains(r'\bedamame\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bedamame\b') |temp['ABSTRACT'].str.contains(r'\bEdamame\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bEdamame\b')| temp['PROJECT_TITLE'].str.contains(r'\bEdamame\b'))|
          ((temp['ABSTRACT'].str.contains(r'\bbean') | temp['PROJECT_TERMS'].str.contains(r'\bbean')| 
           temp['PROJECT_TITLE'].str.contains(r'\bbean') |temp['ABSTRACT'].str.contains(r'\bbean') | 
           temp['PROJECT_TERMS'].str.contains(r'\bbean')| temp['PROJECT_TITLE'].str.contains(r'\bbean'))&
           ((temp['ABSTRACT'].str.contains(r'\bsoybean')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bsoybean')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bsoybean')==False) |(temp['ABSTRACT'].str.contains(r'\bSoybean')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bSoybean')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bSoybean')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bsoy')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bsoy')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bsoy')==False) |(temp['ABSTRACT'].str.contains(r'\bSoy')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bSoy')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bSoy')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bgreen bean')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bgreen bean')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bgreen bean')==False) |(temp['ABSTRACT'].str.contains(r'\bGreen bean')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bGreen bean')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bGreen bean')==False))) |
          ((temp['ABSTRACT'].str.contains(r'\bpeanut\b') | temp['PROJECT_TERMS'].str.contains(r'\bpeanut\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bpeanut\b') |temp['ABSTRACT'].str.contains(r'\bPeanut\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bPeaut\b')| temp['PROJECT_TITLE'].str.contains(r'\bPeanut\b'))|
           (temp['ABSTRACT'].str.contains(r'\bpeanuts\b') | temp['PROJECT_TERMS'].str.contains(r'\bpeanuts\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bpeanuts\b') |temp['ABSTRACT'].str.contains(r'\bPeanuts\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bPeanuts\b')| temp['PROJECT_TITLE'].str.contains(r'\bPeanuts\b'))&
           ((temp['ABSTRACT'].str.contains(r'\bnut')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bnut')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bnut')==False) |(temp['ABSTRACT'].str.contains(r'\bNut')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bNut')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bNut')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bnuts')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bnuts')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bnuts')==False) |(temp['ABSTRACT'].str.contains(r'\bNuts')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bNuts')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bNuts')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bhazelnuts')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bhazelnuts')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bhazelnuts')==False) |(temp['ABSTRACT'].str.contains(r'\bHazelnuts')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bHazelnuts')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bHazelnuts')==False))&
           (temp['ABSTRACT'].str.contains(r'\bchickpea\b') | temp['PROJECT_TERMS'].str.contains(r'\bchickpea\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bchickpea\b') |temp['ABSTRACT'].str.contains(r'\bChickpea\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bChickpea\b')| temp['PROJECT_TITLE'].str.contains(r'\bChickpea\b'))|
           (temp['ABSTRACT'].str.contains(r'\bpea\b') | temp['PROJECT_TERMS'].str.contains(r'\bpea\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bpea\b') |temp['ABSTRACT'].str.contains(r'\bPea\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bPea\b')| temp['PROJECT_TITLE'].str.contains(r'\bPea\b')) &
           ((temp['ABSTRACT'].str.contains(r'\bgreen pea\b')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bgreen pea\b')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bgreen p\b')==False) |(temp['ABSTRACT'].str.contains(r'\bGreen pea\b')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bGreen pea\b')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bGreen pea\b')==False)))]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)


df_abs=pd.read_csv('abstract/PRJABS_2012.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2012.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[(temp['ABSTRACT'].str.contains(r'\blegume') | temp['PROJECT_TERMS'].str.contains(r'\blegume')| 
           temp['PROJECT_TITLE'].str.contains(r'\blegume') |temp['ABSTRACT'].str.contains(r'\bLegume') | 
           temp['PROJECT_TERMS'].str.contains(r'\bLegume')| temp['PROJECT_TITLE'].str.contains(r'\bLegume'))|
           (temp['ABSTRACT'].str.contains(r'\blentil') | temp['PROJECT_TERMS'].str.contains(r'\blentil')| 
           temp['PROJECT_TITLE'].str.contains(r'\blentil') |temp['ABSTRACT'].str.contains(r'\bLentil') | 
           temp['PROJECT_TERMS'].str.contains(r'\bLentil')| temp['PROJECT_TITLE'].str.contains(r'\bLentil')) |
           (temp['ABSTRACT'].str.contains(r'\bedamame\b') | temp['PROJECT_TERMS'].str.contains(r'\bedamame\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bedamame\b') |temp['ABSTRACT'].str.contains(r'\bEdamame\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bEdamame\b')| temp['PROJECT_TITLE'].str.contains(r'\bEdamame\b'))|
          ((temp['ABSTRACT'].str.contains(r'\bbean') | temp['PROJECT_TERMS'].str.contains(r'\bbean')| 
           temp['PROJECT_TITLE'].str.contains(r'\bbean') |temp['ABSTRACT'].str.contains(r'\bbean') | 
           temp['PROJECT_TERMS'].str.contains(r'\bbean')| temp['PROJECT_TITLE'].str.contains(r'\bbean'))&
           ((temp['ABSTRACT'].str.contains(r'\bsoybean')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bsoybean')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bsoybean')==False) |(temp['ABSTRACT'].str.contains(r'\bSoybean')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bSoybean')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bSoybean')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bsoy')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bsoy')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bsoy')==False) |(temp['ABSTRACT'].str.contains(r'\bSoy')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bSoy')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bSoy')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bgreen bean')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bgreen bean')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bgreen bean')==False) |(temp['ABSTRACT'].str.contains(r'\bGreen bean')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bGreen bean')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bGreen bean')==False))) |
          ((temp['ABSTRACT'].str.contains(r'\bpeanut\b') | temp['PROJECT_TERMS'].str.contains(r'\bpeanut\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bpeanut\b') |temp['ABSTRACT'].str.contains(r'\bPeanut\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bPeaut\b')| temp['PROJECT_TITLE'].str.contains(r'\bPeanut\b'))|
           (temp['ABSTRACT'].str.contains(r'\bpeanuts\b') | temp['PROJECT_TERMS'].str.contains(r'\bpeanuts\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bpeanuts\b') |temp['ABSTRACT'].str.contains(r'\bPeanuts\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bPeanuts\b')| temp['PROJECT_TITLE'].str.contains(r'\bPeanuts\b'))&
           ((temp['ABSTRACT'].str.contains(r'\bnut')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bnut')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bnut')==False) |(temp['ABSTRACT'].str.contains(r'\bNut')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bNut')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bNut')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bnuts')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bnuts')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bnuts')==False) |(temp['ABSTRACT'].str.contains(r'\bNuts')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bNuts')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bNuts')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bhazelnuts')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bhazelnuts')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bhazelnuts')==False) |(temp['ABSTRACT'].str.contains(r'\bHazelnuts')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bHazelnuts')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bHazelnuts')==False))&
           (temp['ABSTRACT'].str.contains(r'\bchickpea\b') | temp['PROJECT_TERMS'].str.contains(r'\bchickpea\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bchickpea\b') |temp['ABSTRACT'].str.contains(r'\bChickpea\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bChickpea\b')| temp['PROJECT_TITLE'].str.contains(r'\bChickpea\b'))|
           (temp['ABSTRACT'].str.contains(r'\bpea\b') | temp['PROJECT_TERMS'].str.contains(r'\bpea\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bpea\b') |temp['ABSTRACT'].str.contains(r'\bPea\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bPea\b')| temp['PROJECT_TITLE'].str.contains(r'\bPea\b')) &
           ((temp['ABSTRACT'].str.contains(r'\bgreen pea\b')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bgreen pea\b')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bgreen p\b')==False) |(temp['ABSTRACT'].str.contains(r'\bGreen pea\b')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bGreen pea\b')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bGreen pea\b')==False)))]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2013.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2013.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[(temp['ABSTRACT'].str.contains(r'\blegume') | temp['PROJECT_TERMS'].str.contains(r'\blegume')| 
           temp['PROJECT_TITLE'].str.contains(r'\blegume') |temp['ABSTRACT'].str.contains(r'\bLegume') | 
           temp['PROJECT_TERMS'].str.contains(r'\bLegume')| temp['PROJECT_TITLE'].str.contains(r'\bLegume'))|
           (temp['ABSTRACT'].str.contains(r'\blentil') | temp['PROJECT_TERMS'].str.contains(r'\blentil')| 
           temp['PROJECT_TITLE'].str.contains(r'\blentil') |temp['ABSTRACT'].str.contains(r'\bLentil') | 
           temp['PROJECT_TERMS'].str.contains(r'\bLentil')| temp['PROJECT_TITLE'].str.contains(r'\bLentil')) |
           (temp['ABSTRACT'].str.contains(r'\bedamame\b') | temp['PROJECT_TERMS'].str.contains(r'\bedamame\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bedamame\b') |temp['ABSTRACT'].str.contains(r'\bEdamame\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bEdamame\b')| temp['PROJECT_TITLE'].str.contains(r'\bEdamame\b'))|
          ((temp['ABSTRACT'].str.contains(r'\bbean') | temp['PROJECT_TERMS'].str.contains(r'\bbean')| 
           temp['PROJECT_TITLE'].str.contains(r'\bbean') |temp['ABSTRACT'].str.contains(r'\bbean') | 
           temp['PROJECT_TERMS'].str.contains(r'\bbean')| temp['PROJECT_TITLE'].str.contains(r'\bbean'))&
           ((temp['ABSTRACT'].str.contains(r'\bsoybean')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bsoybean')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bsoybean')==False) |(temp['ABSTRACT'].str.contains(r'\bSoybean')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bSoybean')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bSoybean')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bsoy')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bsoy')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bsoy')==False) |(temp['ABSTRACT'].str.contains(r'\bSoy')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bSoy')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bSoy')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bgreen bean')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bgreen bean')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bgreen bean')==False) |(temp['ABSTRACT'].str.contains(r'\bGreen bean')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bGreen bean')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bGreen bean')==False))) |
          ((temp['ABSTRACT'].str.contains(r'\bpeanut\b') | temp['PROJECT_TERMS'].str.contains(r'\bpeanut\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bpeanut\b') |temp['ABSTRACT'].str.contains(r'\bPeanut\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bPeaut\b')| temp['PROJECT_TITLE'].str.contains(r'\bPeanut\b'))|
           (temp['ABSTRACT'].str.contains(r'\bpeanuts\b') | temp['PROJECT_TERMS'].str.contains(r'\bpeanuts\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bpeanuts\b') |temp['ABSTRACT'].str.contains(r'\bPeanuts\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bPeanuts\b')| temp['PROJECT_TITLE'].str.contains(r'\bPeanuts\b'))&
           ((temp['ABSTRACT'].str.contains(r'\bnut')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bnut')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bnut')==False) |(temp['ABSTRACT'].str.contains(r'\bNut')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bNut')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bNut')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bnuts')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bnuts')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bnuts')==False) |(temp['ABSTRACT'].str.contains(r'\bNuts')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bNuts')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bNuts')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bhazelnuts')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bhazelnuts')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bhazelnuts')==False) |(temp['ABSTRACT'].str.contains(r'\bHazelnuts')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bHazelnuts')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bHazelnuts')==False))&
           (temp['ABSTRACT'].str.contains(r'\bchickpea\b') | temp['PROJECT_TERMS'].str.contains(r'\bchickpea\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bchickpea\b') |temp['ABSTRACT'].str.contains(r'\bChickpea\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bChickpea\b')| temp['PROJECT_TITLE'].str.contains(r'\bChickpea\b'))|
           (temp['ABSTRACT'].str.contains(r'\bpea\b') | temp['PROJECT_TERMS'].str.contains(r'\bpea\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bpea\b') |temp['ABSTRACT'].str.contains(r'\bPea\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bPea\b')| temp['PROJECT_TITLE'].str.contains(r'\bPea\b')) &
           ((temp['ABSTRACT'].str.contains(r'\bgreen pea\b')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bgreen pea\b')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bgreen p\b')==False) |(temp['ABSTRACT'].str.contains(r'\bGreen pea\b')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bGreen pea\b')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bGreen pea\b')==False)))]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)


df_abs=pd.read_csv('abstract/PRJABS_2014.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2014.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[(temp['ABSTRACT'].str.contains(r'\blegume') | temp['PROJECT_TERMS'].str.contains(r'\blegume')| 
           temp['PROJECT_TITLE'].str.contains(r'\blegume') |temp['ABSTRACT'].str.contains(r'\bLegume') | 
           temp['PROJECT_TERMS'].str.contains(r'\bLegume')| temp['PROJECT_TITLE'].str.contains(r'\bLegume'))|
           (temp['ABSTRACT'].str.contains(r'\blentil') | temp['PROJECT_TERMS'].str.contains(r'\blentil')| 
           temp['PROJECT_TITLE'].str.contains(r'\blentil') |temp['ABSTRACT'].str.contains(r'\bLentil') | 
           temp['PROJECT_TERMS'].str.contains(r'\bLentil')| temp['PROJECT_TITLE'].str.contains(r'\bLentil')) |
           (temp['ABSTRACT'].str.contains(r'\bedamame\b') | temp['PROJECT_TERMS'].str.contains(r'\bedamame\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bedamame\b') |temp['ABSTRACT'].str.contains(r'\bEdamame\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bEdamame\b')| temp['PROJECT_TITLE'].str.contains(r'\bEdamame\b'))|
          ((temp['ABSTRACT'].str.contains(r'\bbean') | temp['PROJECT_TERMS'].str.contains(r'\bbean')| 
           temp['PROJECT_TITLE'].str.contains(r'\bbean') |temp['ABSTRACT'].str.contains(r'\bbean') | 
           temp['PROJECT_TERMS'].str.contains(r'\bbean')| temp['PROJECT_TITLE'].str.contains(r'\bbean'))&
           ((temp['ABSTRACT'].str.contains(r'\bsoybean')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bsoybean')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bsoybean')==False) |(temp['ABSTRACT'].str.contains(r'\bSoybean')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bSoybean')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bSoybean')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bsoy')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bsoy')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bsoy')==False) |(temp['ABSTRACT'].str.contains(r'\bSoy')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bSoy')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bSoy')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bgreen bean')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bgreen bean')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bgreen bean')==False) |(temp['ABSTRACT'].str.contains(r'\bGreen bean')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bGreen bean')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bGreen bean')==False))) |
          ((temp['ABSTRACT'].str.contains(r'\bpeanut\b') | temp['PROJECT_TERMS'].str.contains(r'\bpeanut\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bpeanut\b') |temp['ABSTRACT'].str.contains(r'\bPeanut\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bPeaut\b')| temp['PROJECT_TITLE'].str.contains(r'\bPeanut\b'))|
           (temp['ABSTRACT'].str.contains(r'\bpeanuts\b') | temp['PROJECT_TERMS'].str.contains(r'\bpeanuts\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bpeanuts\b') |temp['ABSTRACT'].str.contains(r'\bPeanuts\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bPeanuts\b')| temp['PROJECT_TITLE'].str.contains(r'\bPeanuts\b'))&
           ((temp['ABSTRACT'].str.contains(r'\bnut')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bnut')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bnut')==False) |(temp['ABSTRACT'].str.contains(r'\bNut')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bNut')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bNut')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bnuts')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bnuts')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bnuts')==False) |(temp['ABSTRACT'].str.contains(r'\bNuts')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bNuts')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bNuts')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bhazelnuts')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bhazelnuts')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bhazelnuts')==False) |(temp['ABSTRACT'].str.contains(r'\bHazelnuts')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bHazelnuts')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bHazelnuts')==False))&
           (temp['ABSTRACT'].str.contains(r'\bchickpea\b') | temp['PROJECT_TERMS'].str.contains(r'\bchickpea\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bchickpea\b') |temp['ABSTRACT'].str.contains(r'\bChickpea\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bChickpea\b')| temp['PROJECT_TITLE'].str.contains(r'\bChickpea\b'))|
           (temp['ABSTRACT'].str.contains(r'\bpea\b') | temp['PROJECT_TERMS'].str.contains(r'\bpea\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bpea\b') |temp['ABSTRACT'].str.contains(r'\bPea\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bPea\b')| temp['PROJECT_TITLE'].str.contains(r'\bPea\b')) &
           ((temp['ABSTRACT'].str.contains(r'\bgreen pea\b')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bgreen pea\b')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bgreen p\b')==False) |(temp['ABSTRACT'].str.contains(r'\bGreen pea\b')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bGreen pea\b')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bGreen pea\b')==False)))]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2015.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2015.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[(temp['ABSTRACT'].str.contains(r'\blegume') | temp['PROJECT_TERMS'].str.contains(r'\blegume')| 
           temp['PROJECT_TITLE'].str.contains(r'\blegume') |temp['ABSTRACT'].str.contains(r'\bLegume') | 
           temp['PROJECT_TERMS'].str.contains(r'\bLegume')| temp['PROJECT_TITLE'].str.contains(r'\bLegume'))|
           (temp['ABSTRACT'].str.contains(r'\blentil') | temp['PROJECT_TERMS'].str.contains(r'\blentil')| 
           temp['PROJECT_TITLE'].str.contains(r'\blentil') |temp['ABSTRACT'].str.contains(r'\bLentil') | 
           temp['PROJECT_TERMS'].str.contains(r'\bLentil')| temp['PROJECT_TITLE'].str.contains(r'\bLentil')) |
           (temp['ABSTRACT'].str.contains(r'\bedamame\b') | temp['PROJECT_TERMS'].str.contains(r'\bedamame\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bedamame\b') |temp['ABSTRACT'].str.contains(r'\bEdamame\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bEdamame\b')| temp['PROJECT_TITLE'].str.contains(r'\bEdamame\b'))|
          ((temp['ABSTRACT'].str.contains(r'\bbean') | temp['PROJECT_TERMS'].str.contains(r'\bbean')| 
           temp['PROJECT_TITLE'].str.contains(r'\bbean') |temp['ABSTRACT'].str.contains(r'\bbean') | 
           temp['PROJECT_TERMS'].str.contains(r'\bbean')| temp['PROJECT_TITLE'].str.contains(r'\bbean'))&
           ((temp['ABSTRACT'].str.contains(r'\bsoybean')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bsoybean')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bsoybean')==False) |(temp['ABSTRACT'].str.contains(r'\bSoybean')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bSoybean')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bSoybean')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bsoy')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bsoy')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bsoy')==False) |(temp['ABSTRACT'].str.contains(r'\bSoy')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bSoy')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bSoy')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bgreen bean')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bgreen bean')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bgreen bean')==False) |(temp['ABSTRACT'].str.contains(r'\bGreen bean')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bGreen bean')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bGreen bean')==False))) |
          ((temp['ABSTRACT'].str.contains(r'\bpeanut\b') | temp['PROJECT_TERMS'].str.contains(r'\bpeanut\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bpeanut\b') |temp['ABSTRACT'].str.contains(r'\bPeanut\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bPeaut\b')| temp['PROJECT_TITLE'].str.contains(r'\bPeanut\b'))|
           (temp['ABSTRACT'].str.contains(r'\bpeanuts\b') | temp['PROJECT_TERMS'].str.contains(r'\bpeanuts\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bpeanuts\b') |temp['ABSTRACT'].str.contains(r'\bPeanuts\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bPeanuts\b')| temp['PROJECT_TITLE'].str.contains(r'\bPeanuts\b'))&
           ((temp['ABSTRACT'].str.contains(r'\bnut')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bnut')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bnut')==False) |(temp['ABSTRACT'].str.contains(r'\bNut')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bNut')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bNut')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bnuts')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bnuts')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bnuts')==False) |(temp['ABSTRACT'].str.contains(r'\bNuts')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bNuts')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bNuts')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bhazelnuts')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bhazelnuts')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bhazelnuts')==False) |(temp['ABSTRACT'].str.contains(r'\bHazelnuts')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bHazelnuts')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bHazelnuts')==False))&
           (temp['ABSTRACT'].str.contains(r'\bchickpea\b') | temp['PROJECT_TERMS'].str.contains(r'\bchickpea\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bchickpea\b') |temp['ABSTRACT'].str.contains(r'\bChickpea\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bChickpea\b')| temp['PROJECT_TITLE'].str.contains(r'\bChickpea\b'))|
           (temp['ABSTRACT'].str.contains(r'\bpea\b') | temp['PROJECT_TERMS'].str.contains(r'\bpea\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bpea\b') |temp['ABSTRACT'].str.contains(r'\bPea\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bPea\b')| temp['PROJECT_TITLE'].str.contains(r'\bPea\b')) &
           ((temp['ABSTRACT'].str.contains(r'\bgreen pea\b')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bgreen pea\b')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bgreen p\b')==False) |(temp['ABSTRACT'].str.contains(r'\bGreen pea\b')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bGreen pea\b')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bGreen pea\b')==False)))]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2016.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2016.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[(temp['ABSTRACT'].str.contains(r'\blegume') | temp['PROJECT_TERMS'].str.contains(r'\blegume')| 
           temp['PROJECT_TITLE'].str.contains(r'\blegume') |temp['ABSTRACT'].str.contains(r'\bLegume') | 
           temp['PROJECT_TERMS'].str.contains(r'\bLegume')| temp['PROJECT_TITLE'].str.contains(r'\bLegume'))|
           (temp['ABSTRACT'].str.contains(r'\blentil') | temp['PROJECT_TERMS'].str.contains(r'\blentil')| 
           temp['PROJECT_TITLE'].str.contains(r'\blentil') |temp['ABSTRACT'].str.contains(r'\bLentil') | 
           temp['PROJECT_TERMS'].str.contains(r'\bLentil')| temp['PROJECT_TITLE'].str.contains(r'\bLentil')) |
           (temp['ABSTRACT'].str.contains(r'\bedamame\b') | temp['PROJECT_TERMS'].str.contains(r'\bedamame\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bedamame\b') |temp['ABSTRACT'].str.contains(r'\bEdamame\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bEdamame\b')| temp['PROJECT_TITLE'].str.contains(r'\bEdamame\b'))|
          ((temp['ABSTRACT'].str.contains(r'\bbean') | temp['PROJECT_TERMS'].str.contains(r'\bbean')| 
           temp['PROJECT_TITLE'].str.contains(r'\bbean') |temp['ABSTRACT'].str.contains(r'\bbean') | 
           temp['PROJECT_TERMS'].str.contains(r'\bbean')| temp['PROJECT_TITLE'].str.contains(r'\bbean'))&
           ((temp['ABSTRACT'].str.contains(r'\bsoybean')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bsoybean')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bsoybean')==False) |(temp['ABSTRACT'].str.contains(r'\bSoybean')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bSoybean')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bSoybean')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bsoy')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bsoy')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bsoy')==False) |(temp['ABSTRACT'].str.contains(r'\bSoy')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bSoy')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bSoy')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bgreen bean')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bgreen bean')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bgreen bean')==False) |(temp['ABSTRACT'].str.contains(r'\bGreen bean')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bGreen bean')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bGreen bean')==False))) |
          ((temp['ABSTRACT'].str.contains(r'\bpeanut\b') | temp['PROJECT_TERMS'].str.contains(r'\bpeanut\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bpeanut\b') |temp['ABSTRACT'].str.contains(r'\bPeanut\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bPeaut\b')| temp['PROJECT_TITLE'].str.contains(r'\bPeanut\b'))|
           (temp['ABSTRACT'].str.contains(r'\bpeanuts\b') | temp['PROJECT_TERMS'].str.contains(r'\bpeanuts\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bpeanuts\b') |temp['ABSTRACT'].str.contains(r'\bPeanuts\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bPeanuts\b')| temp['PROJECT_TITLE'].str.contains(r'\bPeanuts\b'))&
           ((temp['ABSTRACT'].str.contains(r'\bnut')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bnut')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bnut')==False) |(temp['ABSTRACT'].str.contains(r'\bNut')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bNut')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bNut')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bnuts')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bnuts')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bnuts')==False) |(temp['ABSTRACT'].str.contains(r'\bNuts')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bNuts')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bNuts')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bhazelnuts')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bhazelnuts')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bhazelnuts')==False) |(temp['ABSTRACT'].str.contains(r'\bHazelnuts')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bHazelnuts')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bHazelnuts')==False))&
           (temp['ABSTRACT'].str.contains(r'\bchickpea\b') | temp['PROJECT_TERMS'].str.contains(r'\bchickpea\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bchickpea\b') |temp['ABSTRACT'].str.contains(r'\bChickpea\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bChickpea\b')| temp['PROJECT_TITLE'].str.contains(r'\bChickpea\b'))|
           (temp['ABSTRACT'].str.contains(r'\bpea\b') | temp['PROJECT_TERMS'].str.contains(r'\bpea\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bpea\b') |temp['ABSTRACT'].str.contains(r'\bPea\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bPea\b')| temp['PROJECT_TITLE'].str.contains(r'\bPea\b')) &
           ((temp['ABSTRACT'].str.contains(r'\bgreen pea\b')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bgreen pea\b')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bgreen p\b')==False) |(temp['ABSTRACT'].str.contains(r'\bGreen pea\b')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bGreen pea\b')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bGreen pea\b')==False)))]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2017.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2017.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[(temp['ABSTRACT'].str.contains(r'\blegume') | temp['PROJECT_TERMS'].str.contains(r'\blegume')| 
           temp['PROJECT_TITLE'].str.contains(r'\blegume') |temp['ABSTRACT'].str.contains(r'\bLegume') | 
           temp['PROJECT_TERMS'].str.contains(r'\bLegume')| temp['PROJECT_TITLE'].str.contains(r'\bLegume'))|
           (temp['ABSTRACT'].str.contains(r'\blentil') | temp['PROJECT_TERMS'].str.contains(r'\blentil')| 
           temp['PROJECT_TITLE'].str.contains(r'\blentil') |temp['ABSTRACT'].str.contains(r'\bLentil') | 
           temp['PROJECT_TERMS'].str.contains(r'\bLentil')| temp['PROJECT_TITLE'].str.contains(r'\bLentil')) |
           (temp['ABSTRACT'].str.contains(r'\bedamame\b') | temp['PROJECT_TERMS'].str.contains(r'\bedamame\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bedamame\b') |temp['ABSTRACT'].str.contains(r'\bEdamame\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bEdamame\b')| temp['PROJECT_TITLE'].str.contains(r'\bEdamame\b'))|
          ((temp['ABSTRACT'].str.contains(r'\bbean') | temp['PROJECT_TERMS'].str.contains(r'\bbean')| 
           temp['PROJECT_TITLE'].str.contains(r'\bbean') |temp['ABSTRACT'].str.contains(r'\bbean') | 
           temp['PROJECT_TERMS'].str.contains(r'\bbean')| temp['PROJECT_TITLE'].str.contains(r'\bbean'))&
           ((temp['ABSTRACT'].str.contains(r'\bsoybean')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bsoybean')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bsoybean')==False) |(temp['ABSTRACT'].str.contains(r'\bSoybean')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bSoybean')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bSoybean')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bsoy')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bsoy')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bsoy')==False) |(temp['ABSTRACT'].str.contains(r'\bSoy')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bSoy')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bSoy')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bgreen bean')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bgreen bean')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bgreen bean')==False) |(temp['ABSTRACT'].str.contains(r'\bGreen bean')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bGreen bean')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bGreen bean')==False))) |
          ((temp['ABSTRACT'].str.contains(r'\bpeanut\b') | temp['PROJECT_TERMS'].str.contains(r'\bpeanut\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bpeanut\b') |temp['ABSTRACT'].str.contains(r'\bPeanut\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bPeaut\b')| temp['PROJECT_TITLE'].str.contains(r'\bPeanut\b'))|
           (temp['ABSTRACT'].str.contains(r'\bpeanuts\b') | temp['PROJECT_TERMS'].str.contains(r'\bpeanuts\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bpeanuts\b') |temp['ABSTRACT'].str.contains(r'\bPeanuts\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bPeanuts\b')| temp['PROJECT_TITLE'].str.contains(r'\bPeanuts\b'))&
           ((temp['ABSTRACT'].str.contains(r'\bnut')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bnut')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bnut')==False) |(temp['ABSTRACT'].str.contains(r'\bNut')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bNut')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bNut')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bnuts')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bnuts')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bnuts')==False) |(temp['ABSTRACT'].str.contains(r'\bNuts')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bNuts')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bNuts')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bhazelnuts')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bhazelnuts')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bhazelnuts')==False) |(temp['ABSTRACT'].str.contains(r'\bHazelnuts')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bHazelnuts')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bHazelnuts')==False))&
           (temp['ABSTRACT'].str.contains(r'\bchickpea\b') | temp['PROJECT_TERMS'].str.contains(r'\bchickpea\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bchickpea\b') |temp['ABSTRACT'].str.contains(r'\bChickpea\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bChickpea\b')| temp['PROJECT_TITLE'].str.contains(r'\bChickpea\b'))|
           (temp['ABSTRACT'].str.contains(r'\bpea\b') | temp['PROJECT_TERMS'].str.contains(r'\bpea\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bpea\b') |temp['ABSTRACT'].str.contains(r'\bPea\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bPea\b')| temp['PROJECT_TITLE'].str.contains(r'\bPea\b')) &
           ((temp['ABSTRACT'].str.contains(r'\bgreen pea\b')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bgreen pea\b')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bgreen p\b')==False) |(temp['ABSTRACT'].str.contains(r'\bGreen pea\b')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bGreen pea\b')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bGreen pea\b')==False)))]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2018.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2018.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[(temp['ABSTRACT'].str.contains(r'\blegume') | temp['PROJECT_TERMS'].str.contains(r'\blegume')| 
           temp['PROJECT_TITLE'].str.contains(r'\blegume') |temp['ABSTRACT'].str.contains(r'\bLegume') | 
           temp['PROJECT_TERMS'].str.contains(r'\bLegume')| temp['PROJECT_TITLE'].str.contains(r'\bLegume'))|
           (temp['ABSTRACT'].str.contains(r'\blentil') | temp['PROJECT_TERMS'].str.contains(r'\blentil')| 
           temp['PROJECT_TITLE'].str.contains(r'\blentil') |temp['ABSTRACT'].str.contains(r'\bLentil') | 
           temp['PROJECT_TERMS'].str.contains(r'\bLentil')| temp['PROJECT_TITLE'].str.contains(r'\bLentil')) |
           (temp['ABSTRACT'].str.contains(r'\bedamame\b') | temp['PROJECT_TERMS'].str.contains(r'\bedamame\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bedamame\b') |temp['ABSTRACT'].str.contains(r'\bEdamame\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bEdamame\b')| temp['PROJECT_TITLE'].str.contains(r'\bEdamame\b'))|
          ((temp['ABSTRACT'].str.contains(r'\bbean') | temp['PROJECT_TERMS'].str.contains(r'\bbean')| 
           temp['PROJECT_TITLE'].str.contains(r'\bbean') |temp['ABSTRACT'].str.contains(r'\bbean') | 
           temp['PROJECT_TERMS'].str.contains(r'\bbean')| temp['PROJECT_TITLE'].str.contains(r'\bbean'))&
           ((temp['ABSTRACT'].str.contains(r'\bsoybean')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bsoybean')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bsoybean')==False) |(temp['ABSTRACT'].str.contains(r'\bSoybean')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bSoybean')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bSoybean')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bsoy')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bsoy')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bsoy')==False) |(temp['ABSTRACT'].str.contains(r'\bSoy')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bSoy')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bSoy')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bgreen bean')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bgreen bean')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bgreen bean')==False) |(temp['ABSTRACT'].str.contains(r'\bGreen bean')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bGreen bean')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bGreen bean')==False))) |
          ((temp['ABSTRACT'].str.contains(r'\bpeanut\b') | temp['PROJECT_TERMS'].str.contains(r'\bpeanut\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bpeanut\b') |temp['ABSTRACT'].str.contains(r'\bPeanut\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bPeaut\b')| temp['PROJECT_TITLE'].str.contains(r'\bPeanut\b'))|
           (temp['ABSTRACT'].str.contains(r'\bpeanuts\b') | temp['PROJECT_TERMS'].str.contains(r'\bpeanuts\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bpeanuts\b') |temp['ABSTRACT'].str.contains(r'\bPeanuts\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bPeanuts\b')| temp['PROJECT_TITLE'].str.contains(r'\bPeanuts\b'))&
           ((temp['ABSTRACT'].str.contains(r'\bnut')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bnut')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bnut')==False) |(temp['ABSTRACT'].str.contains(r'\bNut')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bNut')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bNut')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bnuts')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bnuts')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bnuts')==False) |(temp['ABSTRACT'].str.contains(r'\bNuts')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bNuts')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bNuts')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bhazelnuts')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bhazelnuts')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bhazelnuts')==False) |(temp['ABSTRACT'].str.contains(r'\bHazelnuts')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bHazelnuts')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bHazelnuts')==False))&
           (temp['ABSTRACT'].str.contains(r'\bchickpea\b') | temp['PROJECT_TERMS'].str.contains(r'\bchickpea\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bchickpea\b') |temp['ABSTRACT'].str.contains(r'\bChickpea\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bChickpea\b')| temp['PROJECT_TITLE'].str.contains(r'\bChickpea\b'))|
           (temp['ABSTRACT'].str.contains(r'\bpea\b') | temp['PROJECT_TERMS'].str.contains(r'\bpea\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bpea\b') |temp['ABSTRACT'].str.contains(r'\bPea\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bPea\b')| temp['PROJECT_TITLE'].str.contains(r'\bPea\b')) &
           ((temp['ABSTRACT'].str.contains(r'\bgreen pea\b')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bgreen pea\b')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bgreen p\b')==False) |(temp['ABSTRACT'].str.contains(r'\bGreen pea\b')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bGreen pea\b')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bGreen pea\b')==False)))]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2019.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2019.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[(temp['ABSTRACT'].str.contains(r'\blegume') | temp['PROJECT_TERMS'].str.contains(r'\blegume')| 
           temp['PROJECT_TITLE'].str.contains(r'\blegume') |temp['ABSTRACT'].str.contains(r'\bLegume') | 
           temp['PROJECT_TERMS'].str.contains(r'\bLegume')| temp['PROJECT_TITLE'].str.contains(r'\bLegume'))|
           (temp['ABSTRACT'].str.contains(r'\blentil') | temp['PROJECT_TERMS'].str.contains(r'\blentil')| 
           temp['PROJECT_TITLE'].str.contains(r'\blentil') |temp['ABSTRACT'].str.contains(r'\bLentil') | 
           temp['PROJECT_TERMS'].str.contains(r'\bLentil')| temp['PROJECT_TITLE'].str.contains(r'\bLentil')) |
           (temp['ABSTRACT'].str.contains(r'\bedamame\b') | temp['PROJECT_TERMS'].str.contains(r'\bedamame\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bedamame\b') |temp['ABSTRACT'].str.contains(r'\bEdamame\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bEdamame\b')| temp['PROJECT_TITLE'].str.contains(r'\bEdamame\b'))|
          ((temp['ABSTRACT'].str.contains(r'\bbean') | temp['PROJECT_TERMS'].str.contains(r'\bbean')| 
           temp['PROJECT_TITLE'].str.contains(r'\bbean') |temp['ABSTRACT'].str.contains(r'\bbean') | 
           temp['PROJECT_TERMS'].str.contains(r'\bbean')| temp['PROJECT_TITLE'].str.contains(r'\bbean'))&
           ((temp['ABSTRACT'].str.contains(r'\bsoybean')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bsoybean')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bsoybean')==False) |(temp['ABSTRACT'].str.contains(r'\bSoybean')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bSoybean')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bSoybean')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bsoy')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bsoy')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bsoy')==False) |(temp['ABSTRACT'].str.contains(r'\bSoy')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bSoy')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bSoy')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bgreen bean')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bgreen bean')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bgreen bean')==False) |(temp['ABSTRACT'].str.contains(r'\bGreen bean')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bGreen bean')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bGreen bean')==False))) |
          ((temp['ABSTRACT'].str.contains(r'\bpeanut\b') | temp['PROJECT_TERMS'].str.contains(r'\bpeanut\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bpeanut\b') |temp['ABSTRACT'].str.contains(r'\bPeanut\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bPeaut\b')| temp['PROJECT_TITLE'].str.contains(r'\bPeanut\b'))|
           (temp['ABSTRACT'].str.contains(r'\bpeanuts\b') | temp['PROJECT_TERMS'].str.contains(r'\bpeanuts\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bpeanuts\b') |temp['ABSTRACT'].str.contains(r'\bPeanuts\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bPeanuts\b')| temp['PROJECT_TITLE'].str.contains(r'\bPeanuts\b'))&
           ((temp['ABSTRACT'].str.contains(r'\bnut')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bnut')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bnut')==False) |(temp['ABSTRACT'].str.contains(r'\bNut')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bNut')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bNut')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bnuts')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bnuts')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bnuts')==False) |(temp['ABSTRACT'].str.contains(r'\bNuts')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bNuts')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bNuts')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bhazelnuts')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bhazelnuts')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bhazelnuts')==False) |(temp['ABSTRACT'].str.contains(r'\bHazelnuts')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bHazelnuts')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bHazelnuts')==False))&
           (temp['ABSTRACT'].str.contains(r'\bchickpea\b') | temp['PROJECT_TERMS'].str.contains(r'\bchickpea\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bchickpea\b') |temp['ABSTRACT'].str.contains(r'\bChickpea\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bChickpea\b')| temp['PROJECT_TITLE'].str.contains(r'\bChickpea\b'))|
           (temp['ABSTRACT'].str.contains(r'\bpea\b') | temp['PROJECT_TERMS'].str.contains(r'\bpea\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bpea\b') |temp['ABSTRACT'].str.contains(r'\bPea\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bPea\b')| temp['PROJECT_TITLE'].str.contains(r'\bPea\b')) &
           ((temp['ABSTRACT'].str.contains(r'\bgreen pea\b')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bgreen pea\b')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bgreen p\b')==False) |(temp['ABSTRACT'].str.contains(r'\bGreen pea\b')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bGreen pea\b')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bGreen pea\b')==False)))]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)
# Out:
# (668, 24) (0, 25)
# (340, 24) (0, 25)
# (351, 24) (1, 25)
# (310, 24) (3, 25)
# (641, 24) (11, 25)
# (618, 24) (21, 25)
# (640, 24) (32, 25)
# (598, 24) (45, 25)
# (104076, 24) (274, 25)
# (118557, 24) (530, 25)
# (111400, 24) (776, 25)
# (98064, 24) (992, 25)
# (93367, 24) (1145, 25)
# (91637, 24) (1346, 25)
# (90944, 24) (1530, 25)
# (92265, 24) (1723, 25)
# (91126, 24) (1921, 25)
# b'Skipping line 87965: expected 24 fields, saw 25\nSkipping line 87967: expected 24 fields, saw 25\n'
# (88420, 24) (2115, 25)
# b'Skipping line 95568: expected 24 fields, saw 25\nSkipping line 95570: expected 24 fields, saw 25\n'
# (96209, 24) (2374, 25)
# b'Skipping line 74736: expected 24 fields, saw 25\nSkipping line 79976: expected 24 fields, saw 25\n'
# (80066, 24) (2645, 25)

# %%
df = df[df.AGENCY != 'NASA']
df = df[df.AGENCY != 'NIH']
print(df.shape)
df.to_csv('legume_peanuts.csv')
# Out:
# (1414, 25)

# %% [markdown]
# # Legume-Other

# %%
df=pd.DataFrame()
df_abs=pd.read_csv('abstract/PRJABS_2000.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2000.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[(temp['ABSTRACT'].str.contains(r'\blegume') | temp['PROJECT_TERMS'].str.contains(r'\blegume')| 
           temp['PROJECT_TITLE'].str.contains(r'\blegume') |temp['ABSTRACT'].str.contains(r'\bLegume') | 
           temp['PROJECT_TERMS'].str.contains(r'\bLegume')| temp['PROJECT_TITLE'].str.contains(r'\bLegume'))|
           (temp['ABSTRACT'].str.contains(r'\blentil') | temp['PROJECT_TERMS'].str.contains(r'\blentil')| 
           temp['PROJECT_TITLE'].str.contains(r'\blentil') |temp['ABSTRACT'].str.contains(r'\bLentil') | 
           temp['PROJECT_TERMS'].str.contains(r'\bLentil')| temp['PROJECT_TITLE'].str.contains(r'\bLentil')) |
           (temp['ABSTRACT'].str.contains(r'\bedamame\b') | temp['PROJECT_TERMS'].str.contains(r'\bedamame\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bedamame\b') |temp['ABSTRACT'].str.contains(r'\bEdamame\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bEdamame\b')| temp['PROJECT_TITLE'].str.contains(r'\bEdamame\b'))|
           ((temp['ABSTRACT'].str.contains(r'\bbean') | temp['PROJECT_TERMS'].str.contains(r'\bbean')| 
           temp['PROJECT_TITLE'].str.contains(r'\bbean') |temp['ABSTRACT'].str.contains(r'\bbean') | 
           temp['PROJECT_TERMS'].str.contains(r'\bbean')| temp['PROJECT_TITLE'].str.contains(r'\bbean'))&
           ((temp['ABSTRACT'].str.contains(r'\bsoybean')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bsoybean')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bsoybean')==False) |(temp['ABSTRACT'].str.contains(r'\bSoybean')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bSoybean')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bSoybean')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bsoy')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bsoy')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bsoy')==False) |(temp['ABSTRACT'].str.contains(r'\bSoy')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bSoy')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bSoy')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bgreen bean')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bgreen bean')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bgreen bean')==False) |(temp['ABSTRACT'].str.contains(r'\bGreen bean')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bGreen bean')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bGreen bean')==False)))&
           ((temp['ABSTRACT'].str.contains(r'\bnut')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bnut')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bnut')==False) |(temp['ABSTRACT'].str.contains(r'\bNut')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bNut')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bNut')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bnuts')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bnuts')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bnuts')==False) |(temp['ABSTRACT'].str.contains(r'\bNuts')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bNuts')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bNuts')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bpeanut')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bpeanut')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bpeanut')==False) |(temp['ABSTRACT'].str.contains(r'\bPeanut')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bPeanut')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bPeanut')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bpeanuts')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bpeanuts')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bpeanuts')==False) |(temp['ABSTRACT'].str.contains(r'\bPeanuts')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bPeanuts')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bPeanuts')==False))|
           (temp['ABSTRACT'].str.contains(r'\bhazelnuts\b') | temp['PROJECT_TERMS'].str.contains(r'\bhazelnuts\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bHazelnuts\b') |temp['ABSTRACT'].str.contains(r'\bhazelnuts\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bHazelnuts\b')| temp['PROJECT_TITLE'].str.contains(r'\bHazelnuts\b'))|
           (temp['ABSTRACT'].str.contains(r'\bchickpea\b') | temp['PROJECT_TERMS'].str.contains(r'\bchickpea\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bchickpea\b') |temp['ABSTRACT'].str.contains(r'\bChickpea\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bChickpea\b')| temp['PROJECT_TITLE'].str.contains(r'\bChickpea\b'))|
           (temp['ABSTRACT'].str.contains(r'\bpea\b') | temp['PROJECT_TERMS'].str.contains(r'\bpea\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bpea\b') |temp['ABSTRACT'].str.contains(r'\bPea\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bPea\b')| temp['PROJECT_TITLE'].str.contains(r'\bPea\b')) &
           ((temp['ABSTRACT'].str.contains(r'\bgreen pea\b')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bgreen pea\b')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bgreen p\b')==False) |(temp['ABSTRACT'].str.contains(r'\bGreen pea\b')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bGreen pea\b')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bGreen pea\b')==False))]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)


df_abs=pd.read_csv('abstract/PRJABS_2001.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2001.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[(temp['ABSTRACT'].str.contains(r'\blegume') | temp['PROJECT_TERMS'].str.contains(r'\blegume')| 
           temp['PROJECT_TITLE'].str.contains(r'\blegume') |temp['ABSTRACT'].str.contains(r'\bLegume') | 
           temp['PROJECT_TERMS'].str.contains(r'\bLegume')| temp['PROJECT_TITLE'].str.contains(r'\bLegume'))|
           (temp['ABSTRACT'].str.contains(r'\blentil') | temp['PROJECT_TERMS'].str.contains(r'\blentil')| 
           temp['PROJECT_TITLE'].str.contains(r'\blentil') |temp['ABSTRACT'].str.contains(r'\bLentil') | 
           temp['PROJECT_TERMS'].str.contains(r'\bLentil')| temp['PROJECT_TITLE'].str.contains(r'\bLentil')) |
           (temp['ABSTRACT'].str.contains(r'\bedamame\b') | temp['PROJECT_TERMS'].str.contains(r'\bedamame\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bedamame\b') |temp['ABSTRACT'].str.contains(r'\bEdamame\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bEdamame\b')| temp['PROJECT_TITLE'].str.contains(r'\bEdamame\b'))|
           ((temp['ABSTRACT'].str.contains(r'\bbean') | temp['PROJECT_TERMS'].str.contains(r'\bbean')| 
           temp['PROJECT_TITLE'].str.contains(r'\bbean') |temp['ABSTRACT'].str.contains(r'\bbean') | 
           temp['PROJECT_TERMS'].str.contains(r'\bbean')| temp['PROJECT_TITLE'].str.contains(r'\bbean'))&
           ((temp['ABSTRACT'].str.contains(r'\bsoybean')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bsoybean')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bsoybean')==False) |(temp['ABSTRACT'].str.contains(r'\bSoybean')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bSoybean')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bSoybean')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bsoy')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bsoy')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bsoy')==False) |(temp['ABSTRACT'].str.contains(r'\bSoy')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bSoy')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bSoy')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bgreen bean')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bgreen bean')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bgreen bean')==False) |(temp['ABSTRACT'].str.contains(r'\bGreen bean')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bGreen bean')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bGreen bean')==False)))&
           ((temp['ABSTRACT'].str.contains(r'\bnut')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bnut')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bnut')==False) |(temp['ABSTRACT'].str.contains(r'\bNut')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bNut')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bNut')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bnuts')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bnuts')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bnuts')==False) |(temp['ABSTRACT'].str.contains(r'\bNuts')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bNuts')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bNuts')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bpeanut')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bpeanut')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bpeanut')==False) |(temp['ABSTRACT'].str.contains(r'\bPeanut')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bPeanut')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bPeanut')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bpeanuts')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bpeanuts')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bpeanuts')==False) |(temp['ABSTRACT'].str.contains(r'\bPeanuts')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bPeanuts')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bPeanuts')==False))|
           (temp['ABSTRACT'].str.contains(r'\bhazelnuts\b') | temp['PROJECT_TERMS'].str.contains(r'\bhazelnuts\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bHazelnuts\b') |temp['ABSTRACT'].str.contains(r'\bhazelnuts\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bHazelnuts\b')| temp['PROJECT_TITLE'].str.contains(r'\bHazelnuts\b'))|
           (temp['ABSTRACT'].str.contains(r'\bchickpea\b') | temp['PROJECT_TERMS'].str.contains(r'\bchickpea\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bchickpea\b') |temp['ABSTRACT'].str.contains(r'\bChickpea\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bChickpea\b')| temp['PROJECT_TITLE'].str.contains(r'\bChickpea\b'))|
           (temp['ABSTRACT'].str.contains(r'\bpea\b') | temp['PROJECT_TERMS'].str.contains(r'\bpea\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bpea\b') |temp['ABSTRACT'].str.contains(r'\bPea\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bPea\b')| temp['PROJECT_TITLE'].str.contains(r'\bPea\b')) &
           ((temp['ABSTRACT'].str.contains(r'\bgreen pea\b')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bgreen pea\b')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bgreen p\b')==False) |(temp['ABSTRACT'].str.contains(r'\bGreen pea\b')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bGreen pea\b')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bGreen pea\b')==False))]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)


df_abs=pd.read_csv('abstract/PRJABS_2002.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2002.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[(temp['ABSTRACT'].str.contains(r'\blegume') | temp['PROJECT_TERMS'].str.contains(r'\blegume')| 
           temp['PROJECT_TITLE'].str.contains(r'\blegume') |temp['ABSTRACT'].str.contains(r'\bLegume') | 
           temp['PROJECT_TERMS'].str.contains(r'\bLegume')| temp['PROJECT_TITLE'].str.contains(r'\bLegume'))|
           (temp['ABSTRACT'].str.contains(r'\blentil') | temp['PROJECT_TERMS'].str.contains(r'\blentil')| 
           temp['PROJECT_TITLE'].str.contains(r'\blentil') |temp['ABSTRACT'].str.contains(r'\bLentil') | 
           temp['PROJECT_TERMS'].str.contains(r'\bLentil')| temp['PROJECT_TITLE'].str.contains(r'\bLentil')) |
           (temp['ABSTRACT'].str.contains(r'\bedamame\b') | temp['PROJECT_TERMS'].str.contains(r'\bedamame\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bedamame\b') |temp['ABSTRACT'].str.contains(r'\bEdamame\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bEdamame\b')| temp['PROJECT_TITLE'].str.contains(r'\bEdamame\b'))|
           ((temp['ABSTRACT'].str.contains(r'\bbean') | temp['PROJECT_TERMS'].str.contains(r'\bbean')| 
           temp['PROJECT_TITLE'].str.contains(r'\bbean') |temp['ABSTRACT'].str.contains(r'\bbean') | 
           temp['PROJECT_TERMS'].str.contains(r'\bbean')| temp['PROJECT_TITLE'].str.contains(r'\bbean'))&
           ((temp['ABSTRACT'].str.contains(r'\bsoybean')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bsoybean')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bsoybean')==False) |(temp['ABSTRACT'].str.contains(r'\bSoybean')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bSoybean')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bSoybean')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bsoy')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bsoy')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bsoy')==False) |(temp['ABSTRACT'].str.contains(r'\bSoy')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bSoy')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bSoy')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bgreen bean')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bgreen bean')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bgreen bean')==False) |(temp['ABSTRACT'].str.contains(r'\bGreen bean')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bGreen bean')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bGreen bean')==False)))&
           ((temp['ABSTRACT'].str.contains(r'\bnut')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bnut')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bnut')==False) |(temp['ABSTRACT'].str.contains(r'\bNut')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bNut')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bNut')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bnuts')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bnuts')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bnuts')==False) |(temp['ABSTRACT'].str.contains(r'\bNuts')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bNuts')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bNuts')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bpeanut')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bpeanut')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bpeanut')==False) |(temp['ABSTRACT'].str.contains(r'\bPeanut')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bPeanut')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bPeanut')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bpeanuts')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bpeanuts')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bpeanuts')==False) |(temp['ABSTRACT'].str.contains(r'\bPeanuts')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bPeanuts')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bPeanuts')==False))|
           (temp['ABSTRACT'].str.contains(r'\bhazelnuts\b') | temp['PROJECT_TERMS'].str.contains(r'\bhazelnuts\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bHazelnuts\b') |temp['ABSTRACT'].str.contains(r'\bhazelnuts\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bHazelnuts\b')| temp['PROJECT_TITLE'].str.contains(r'\bHazelnuts\b'))|
           (temp['ABSTRACT'].str.contains(r'\bchickpea\b') | temp['PROJECT_TERMS'].str.contains(r'\bchickpea\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bchickpea\b') |temp['ABSTRACT'].str.contains(r'\bChickpea\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bChickpea\b')| temp['PROJECT_TITLE'].str.contains(r'\bChickpea\b'))|
           (temp['ABSTRACT'].str.contains(r'\bpea\b') | temp['PROJECT_TERMS'].str.contains(r'\bpea\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bpea\b') |temp['ABSTRACT'].str.contains(r'\bPea\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bPea\b')| temp['PROJECT_TITLE'].str.contains(r'\bPea\b')) &
           ((temp['ABSTRACT'].str.contains(r'\bgreen pea\b')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bgreen pea\b')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bgreen p\b')==False) |(temp['ABSTRACT'].str.contains(r'\bGreen pea\b')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bGreen pea\b')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bGreen pea\b')==False))]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)


df_abs=pd.read_csv('abstract/PRJABS_2003.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2003.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[(temp['ABSTRACT'].str.contains(r'\blegume') | temp['PROJECT_TERMS'].str.contains(r'\blegume')| 
           temp['PROJECT_TITLE'].str.contains(r'\blegume') |temp['ABSTRACT'].str.contains(r'\bLegume') | 
           temp['PROJECT_TERMS'].str.contains(r'\bLegume')| temp['PROJECT_TITLE'].str.contains(r'\bLegume'))|
           (temp['ABSTRACT'].str.contains(r'\blentil') | temp['PROJECT_TERMS'].str.contains(r'\blentil')| 
           temp['PROJECT_TITLE'].str.contains(r'\blentil') |temp['ABSTRACT'].str.contains(r'\bLentil') | 
           temp['PROJECT_TERMS'].str.contains(r'\bLentil')| temp['PROJECT_TITLE'].str.contains(r'\bLentil')) |
           (temp['ABSTRACT'].str.contains(r'\bedamame\b') | temp['PROJECT_TERMS'].str.contains(r'\bedamame\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bedamame\b') |temp['ABSTRACT'].str.contains(r'\bEdamame\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bEdamame\b')| temp['PROJECT_TITLE'].str.contains(r'\bEdamame\b'))|
           ((temp['ABSTRACT'].str.contains(r'\bbean') | temp['PROJECT_TERMS'].str.contains(r'\bbean')| 
           temp['PROJECT_TITLE'].str.contains(r'\bbean') |temp['ABSTRACT'].str.contains(r'\bbean') | 
           temp['PROJECT_TERMS'].str.contains(r'\bbean')| temp['PROJECT_TITLE'].str.contains(r'\bbean'))&
           ((temp['ABSTRACT'].str.contains(r'\bsoybean')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bsoybean')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bsoybean')==False) |(temp['ABSTRACT'].str.contains(r'\bSoybean')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bSoybean')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bSoybean')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bsoy')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bsoy')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bsoy')==False) |(temp['ABSTRACT'].str.contains(r'\bSoy')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bSoy')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bSoy')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bgreen bean')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bgreen bean')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bgreen bean')==False) |(temp['ABSTRACT'].str.contains(r'\bGreen bean')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bGreen bean')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bGreen bean')==False)))&
           ((temp['ABSTRACT'].str.contains(r'\bnut')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bnut')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bnut')==False) |(temp['ABSTRACT'].str.contains(r'\bNut')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bNut')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bNut')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bnuts')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bnuts')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bnuts')==False) |(temp['ABSTRACT'].str.contains(r'\bNuts')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bNuts')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bNuts')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bpeanut')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bpeanut')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bpeanut')==False) |(temp['ABSTRACT'].str.contains(r'\bPeanut')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bPeanut')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bPeanut')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bpeanuts')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bpeanuts')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bpeanuts')==False) |(temp['ABSTRACT'].str.contains(r'\bPeanuts')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bPeanuts')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bPeanuts')==False))|
           (temp['ABSTRACT'].str.contains(r'\bhazelnuts\b') | temp['PROJECT_TERMS'].str.contains(r'\bhazelnuts\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bHazelnuts\b') |temp['ABSTRACT'].str.contains(r'\bhazelnuts\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bHazelnuts\b')| temp['PROJECT_TITLE'].str.contains(r'\bHazelnuts\b'))|
           (temp['ABSTRACT'].str.contains(r'\bchickpea\b') | temp['PROJECT_TERMS'].str.contains(r'\bchickpea\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bchickpea\b') |temp['ABSTRACT'].str.contains(r'\bChickpea\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bChickpea\b')| temp['PROJECT_TITLE'].str.contains(r'\bChickpea\b'))|
           (temp['ABSTRACT'].str.contains(r'\bpea\b') | temp['PROJECT_TERMS'].str.contains(r'\bpea\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bpea\b') |temp['ABSTRACT'].str.contains(r'\bPea\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bPea\b')| temp['PROJECT_TITLE'].str.contains(r'\bPea\b')) &
           ((temp['ABSTRACT'].str.contains(r'\bgreen pea\b')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bgreen pea\b')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bgreen p\b')==False) |(temp['ABSTRACT'].str.contains(r'\bGreen pea\b')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bGreen pea\b')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bGreen pea\b')==False))]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)


df_abs=pd.read_csv('abstract/PRJABS_2004.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2004.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[(temp['ABSTRACT'].str.contains(r'\blegume') | temp['PROJECT_TERMS'].str.contains(r'\blegume')| 
           temp['PROJECT_TITLE'].str.contains(r'\blegume') |temp['ABSTRACT'].str.contains(r'\bLegume') | 
           temp['PROJECT_TERMS'].str.contains(r'\bLegume')| temp['PROJECT_TITLE'].str.contains(r'\bLegume'))|
           (temp['ABSTRACT'].str.contains(r'\blentil') | temp['PROJECT_TERMS'].str.contains(r'\blentil')| 
           temp['PROJECT_TITLE'].str.contains(r'\blentil') |temp['ABSTRACT'].str.contains(r'\bLentil') | 
           temp['PROJECT_TERMS'].str.contains(r'\bLentil')| temp['PROJECT_TITLE'].str.contains(r'\bLentil')) |
           (temp['ABSTRACT'].str.contains(r'\bedamame\b') | temp['PROJECT_TERMS'].str.contains(r'\bedamame\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bedamame\b') |temp['ABSTRACT'].str.contains(r'\bEdamame\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bEdamame\b')| temp['PROJECT_TITLE'].str.contains(r'\bEdamame\b'))|
           ((temp['ABSTRACT'].str.contains(r'\bbean') | temp['PROJECT_TERMS'].str.contains(r'\bbean')| 
           temp['PROJECT_TITLE'].str.contains(r'\bbean') |temp['ABSTRACT'].str.contains(r'\bbean') | 
           temp['PROJECT_TERMS'].str.contains(r'\bbean')| temp['PROJECT_TITLE'].str.contains(r'\bbean'))&
           ((temp['ABSTRACT'].str.contains(r'\bsoybean')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bsoybean')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bsoybean')==False) |(temp['ABSTRACT'].str.contains(r'\bSoybean')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bSoybean')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bSoybean')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bsoy')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bsoy')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bsoy')==False) |(temp['ABSTRACT'].str.contains(r'\bSoy')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bSoy')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bSoy')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bgreen bean')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bgreen bean')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bgreen bean')==False) |(temp['ABSTRACT'].str.contains(r'\bGreen bean')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bGreen bean')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bGreen bean')==False)))&
           ((temp['ABSTRACT'].str.contains(r'\bnut')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bnut')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bnut')==False) |(temp['ABSTRACT'].str.contains(r'\bNut')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bNut')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bNut')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bnuts')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bnuts')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bnuts')==False) |(temp['ABSTRACT'].str.contains(r'\bNuts')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bNuts')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bNuts')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bpeanut')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bpeanut')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bpeanut')==False) |(temp['ABSTRACT'].str.contains(r'\bPeanut')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bPeanut')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bPeanut')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bpeanuts')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bpeanuts')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bpeanuts')==False) |(temp['ABSTRACT'].str.contains(r'\bPeanuts')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bPeanuts')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bPeanuts')==False))|
           (temp['ABSTRACT'].str.contains(r'\bhazelnuts\b') | temp['PROJECT_TERMS'].str.contains(r'\bhazelnuts\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bHazelnuts\b') |temp['ABSTRACT'].str.contains(r'\bhazelnuts\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bHazelnuts\b')| temp['PROJECT_TITLE'].str.contains(r'\bHazelnuts\b'))|
           (temp['ABSTRACT'].str.contains(r'\bchickpea\b') | temp['PROJECT_TERMS'].str.contains(r'\bchickpea\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bchickpea\b') |temp['ABSTRACT'].str.contains(r'\bChickpea\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bChickpea\b')| temp['PROJECT_TITLE'].str.contains(r'\bChickpea\b'))|
           (temp['ABSTRACT'].str.contains(r'\bpea\b') | temp['PROJECT_TERMS'].str.contains(r'\bpea\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bpea\b') |temp['ABSTRACT'].str.contains(r'\bPea\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bPea\b')| temp['PROJECT_TITLE'].str.contains(r'\bPea\b')) &
           ((temp['ABSTRACT'].str.contains(r'\bgreen pea\b')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bgreen pea\b')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bgreen p\b')==False) |(temp['ABSTRACT'].str.contains(r'\bGreen pea\b')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bGreen pea\b')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bGreen pea\b')==False))]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)


df_abs=pd.read_csv('abstract/PRJABS_2005.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2005.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[(temp['ABSTRACT'].str.contains(r'\blegume') | temp['PROJECT_TERMS'].str.contains(r'\blegume')| 
           temp['PROJECT_TITLE'].str.contains(r'\blegume') |temp['ABSTRACT'].str.contains(r'\bLegume') | 
           temp['PROJECT_TERMS'].str.contains(r'\bLegume')| temp['PROJECT_TITLE'].str.contains(r'\bLegume'))|
           (temp['ABSTRACT'].str.contains(r'\blentil') | temp['PROJECT_TERMS'].str.contains(r'\blentil')| 
           temp['PROJECT_TITLE'].str.contains(r'\blentil') |temp['ABSTRACT'].str.contains(r'\bLentil') | 
           temp['PROJECT_TERMS'].str.contains(r'\bLentil')| temp['PROJECT_TITLE'].str.contains(r'\bLentil')) |
           (temp['ABSTRACT'].str.contains(r'\bedamame\b') | temp['PROJECT_TERMS'].str.contains(r'\bedamame\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bedamame\b') |temp['ABSTRACT'].str.contains(r'\bEdamame\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bEdamame\b')| temp['PROJECT_TITLE'].str.contains(r'\bEdamame\b'))|
           ((temp['ABSTRACT'].str.contains(r'\bbean') | temp['PROJECT_TERMS'].str.contains(r'\bbean')| 
           temp['PROJECT_TITLE'].str.contains(r'\bbean') |temp['ABSTRACT'].str.contains(r'\bbean') | 
           temp['PROJECT_TERMS'].str.contains(r'\bbean')| temp['PROJECT_TITLE'].str.contains(r'\bbean'))&
           ((temp['ABSTRACT'].str.contains(r'\bsoybean')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bsoybean')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bsoybean')==False) |(temp['ABSTRACT'].str.contains(r'\bSoybean')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bSoybean')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bSoybean')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bsoy')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bsoy')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bsoy')==False) |(temp['ABSTRACT'].str.contains(r'\bSoy')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bSoy')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bSoy')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bgreen bean')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bgreen bean')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bgreen bean')==False) |(temp['ABSTRACT'].str.contains(r'\bGreen bean')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bGreen bean')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bGreen bean')==False)))&
           ((temp['ABSTRACT'].str.contains(r'\bnut')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bnut')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bnut')==False) |(temp['ABSTRACT'].str.contains(r'\bNut')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bNut')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bNut')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bnuts')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bnuts')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bnuts')==False) |(temp['ABSTRACT'].str.contains(r'\bNuts')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bNuts')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bNuts')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bpeanut')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bpeanut')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bpeanut')==False) |(temp['ABSTRACT'].str.contains(r'\bPeanut')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bPeanut')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bPeanut')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bpeanuts')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bpeanuts')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bpeanuts')==False) |(temp['ABSTRACT'].str.contains(r'\bPeanuts')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bPeanuts')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bPeanuts')==False))|
           (temp['ABSTRACT'].str.contains(r'\bhazelnuts\b') | temp['PROJECT_TERMS'].str.contains(r'\bhazelnuts\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bHazelnuts\b') |temp['ABSTRACT'].str.contains(r'\bhazelnuts\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bHazelnuts\b')| temp['PROJECT_TITLE'].str.contains(r'\bHazelnuts\b'))|
           (temp['ABSTRACT'].str.contains(r'\bchickpea\b') | temp['PROJECT_TERMS'].str.contains(r'\bchickpea\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bchickpea\b') |temp['ABSTRACT'].str.contains(r'\bChickpea\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bChickpea\b')| temp['PROJECT_TITLE'].str.contains(r'\bChickpea\b'))|
           (temp['ABSTRACT'].str.contains(r'\bpea\b') | temp['PROJECT_TERMS'].str.contains(r'\bpea\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bpea\b') |temp['ABSTRACT'].str.contains(r'\bPea\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bPea\b')| temp['PROJECT_TITLE'].str.contains(r'\bPea\b')) &
           ((temp['ABSTRACT'].str.contains(r'\bgreen pea\b')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bgreen pea\b')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bgreen p\b')==False) |(temp['ABSTRACT'].str.contains(r'\bGreen pea\b')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bGreen pea\b')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bGreen pea\b')==False))]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)


df_abs=pd.read_csv('abstract/PRJABS_2006.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2006.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[(temp['ABSTRACT'].str.contains(r'\blegume') | temp['PROJECT_TERMS'].str.contains(r'\blegume')| 
           temp['PROJECT_TITLE'].str.contains(r'\blegume') |temp['ABSTRACT'].str.contains(r'\bLegume') | 
           temp['PROJECT_TERMS'].str.contains(r'\bLegume')| temp['PROJECT_TITLE'].str.contains(r'\bLegume'))|
           (temp['ABSTRACT'].str.contains(r'\blentil') | temp['PROJECT_TERMS'].str.contains(r'\blentil')| 
           temp['PROJECT_TITLE'].str.contains(r'\blentil') |temp['ABSTRACT'].str.contains(r'\bLentil') | 
           temp['PROJECT_TERMS'].str.contains(r'\bLentil')| temp['PROJECT_TITLE'].str.contains(r'\bLentil')) |
           (temp['ABSTRACT'].str.contains(r'\bedamame\b') | temp['PROJECT_TERMS'].str.contains(r'\bedamame\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bedamame\b') |temp['ABSTRACT'].str.contains(r'\bEdamame\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bEdamame\b')| temp['PROJECT_TITLE'].str.contains(r'\bEdamame\b'))|
           ((temp['ABSTRACT'].str.contains(r'\bbean') | temp['PROJECT_TERMS'].str.contains(r'\bbean')| 
           temp['PROJECT_TITLE'].str.contains(r'\bbean') |temp['ABSTRACT'].str.contains(r'\bbean') | 
           temp['PROJECT_TERMS'].str.contains(r'\bbean')| temp['PROJECT_TITLE'].str.contains(r'\bbean'))&
           ((temp['ABSTRACT'].str.contains(r'\bsoybean')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bsoybean')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bsoybean')==False) |(temp['ABSTRACT'].str.contains(r'\bSoybean')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bSoybean')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bSoybean')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bsoy')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bsoy')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bsoy')==False) |(temp['ABSTRACT'].str.contains(r'\bSoy')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bSoy')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bSoy')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bgreen bean')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bgreen bean')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bgreen bean')==False) |(temp['ABSTRACT'].str.contains(r'\bGreen bean')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bGreen bean')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bGreen bean')==False)))&
           ((temp['ABSTRACT'].str.contains(r'\bnut')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bnut')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bnut')==False) |(temp['ABSTRACT'].str.contains(r'\bNut')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bNut')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bNut')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bnuts')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bnuts')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bnuts')==False) |(temp['ABSTRACT'].str.contains(r'\bNuts')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bNuts')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bNuts')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bpeanut')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bpeanut')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bpeanut')==False) |(temp['ABSTRACT'].str.contains(r'\bPeanut')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bPeanut')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bPeanut')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bpeanuts')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bpeanuts')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bpeanuts')==False) |(temp['ABSTRACT'].str.contains(r'\bPeanuts')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bPeanuts')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bPeanuts')==False))|
           (temp['ABSTRACT'].str.contains(r'\bhazelnuts\b') | temp['PROJECT_TERMS'].str.contains(r'\bhazelnuts\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bHazelnuts\b') |temp['ABSTRACT'].str.contains(r'\bhazelnuts\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bHazelnuts\b')| temp['PROJECT_TITLE'].str.contains(r'\bHazelnuts\b'))|
           (temp['ABSTRACT'].str.contains(r'\bchickpea\b') | temp['PROJECT_TERMS'].str.contains(r'\bchickpea\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bchickpea\b') |temp['ABSTRACT'].str.contains(r'\bChickpea\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bChickpea\b')| temp['PROJECT_TITLE'].str.contains(r'\bChickpea\b'))|
           (temp['ABSTRACT'].str.contains(r'\bpea\b') | temp['PROJECT_TERMS'].str.contains(r'\bpea\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bpea\b') |temp['ABSTRACT'].str.contains(r'\bPea\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bPea\b')| temp['PROJECT_TITLE'].str.contains(r'\bPea\b')) &
           ((temp['ABSTRACT'].str.contains(r'\bgreen pea\b')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bgreen pea\b')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bgreen p\b')==False) |(temp['ABSTRACT'].str.contains(r'\bGreen pea\b')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bGreen pea\b')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bGreen pea\b')==False))]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2007.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2007.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[(temp['ABSTRACT'].str.contains(r'\blegume') | temp['PROJECT_TERMS'].str.contains(r'\blegume')| 
           temp['PROJECT_TITLE'].str.contains(r'\blegume') |temp['ABSTRACT'].str.contains(r'\bLegume') | 
           temp['PROJECT_TERMS'].str.contains(r'\bLegume')| temp['PROJECT_TITLE'].str.contains(r'\bLegume'))|
           (temp['ABSTRACT'].str.contains(r'\blentil') | temp['PROJECT_TERMS'].str.contains(r'\blentil')| 
           temp['PROJECT_TITLE'].str.contains(r'\blentil') |temp['ABSTRACT'].str.contains(r'\bLentil') | 
           temp['PROJECT_TERMS'].str.contains(r'\bLentil')| temp['PROJECT_TITLE'].str.contains(r'\bLentil')) |
           (temp['ABSTRACT'].str.contains(r'\bedamame\b') | temp['PROJECT_TERMS'].str.contains(r'\bedamame\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bedamame\b') |temp['ABSTRACT'].str.contains(r'\bEdamame\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bEdamame\b')| temp['PROJECT_TITLE'].str.contains(r'\bEdamame\b'))|
           ((temp['ABSTRACT'].str.contains(r'\bbean') | temp['PROJECT_TERMS'].str.contains(r'\bbean')| 
           temp['PROJECT_TITLE'].str.contains(r'\bbean') |temp['ABSTRACT'].str.contains(r'\bbean') | 
           temp['PROJECT_TERMS'].str.contains(r'\bbean')| temp['PROJECT_TITLE'].str.contains(r'\bbean'))&
           ((temp['ABSTRACT'].str.contains(r'\bsoybean')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bsoybean')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bsoybean')==False) |(temp['ABSTRACT'].str.contains(r'\bSoybean')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bSoybean')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bSoybean')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bsoy')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bsoy')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bsoy')==False) |(temp['ABSTRACT'].str.contains(r'\bSoy')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bSoy')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bSoy')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bgreen bean')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bgreen bean')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bgreen bean')==False) |(temp['ABSTRACT'].str.contains(r'\bGreen bean')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bGreen bean')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bGreen bean')==False)))&
           ((temp['ABSTRACT'].str.contains(r'\bnut')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bnut')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bnut')==False) |(temp['ABSTRACT'].str.contains(r'\bNut')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bNut')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bNut')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bnuts')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bnuts')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bnuts')==False) |(temp['ABSTRACT'].str.contains(r'\bNuts')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bNuts')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bNuts')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bpeanut')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bpeanut')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bpeanut')==False) |(temp['ABSTRACT'].str.contains(r'\bPeanut')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bPeanut')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bPeanut')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bpeanuts')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bpeanuts')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bpeanuts')==False) |(temp['ABSTRACT'].str.contains(r'\bPeanuts')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bPeanuts')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bPeanuts')==False))|
           (temp['ABSTRACT'].str.contains(r'\bhazelnuts\b') | temp['PROJECT_TERMS'].str.contains(r'\bhazelnuts\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bHazelnuts\b') |temp['ABSTRACT'].str.contains(r'\bhazelnuts\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bHazelnuts\b')| temp['PROJECT_TITLE'].str.contains(r'\bHazelnuts\b'))|
           (temp['ABSTRACT'].str.contains(r'\bchickpea\b') | temp['PROJECT_TERMS'].str.contains(r'\bchickpea\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bchickpea\b') |temp['ABSTRACT'].str.contains(r'\bChickpea\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bChickpea\b')| temp['PROJECT_TITLE'].str.contains(r'\bChickpea\b'))|
           (temp['ABSTRACT'].str.contains(r'\bpea\b') | temp['PROJECT_TERMS'].str.contains(r'\bpea\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bpea\b') |temp['ABSTRACT'].str.contains(r'\bPea\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bPea\b')| temp['PROJECT_TITLE'].str.contains(r'\bPea\b')) &
           ((temp['ABSTRACT'].str.contains(r'\bgreen pea\b')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bgreen pea\b')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bgreen p\b')==False) |(temp['ABSTRACT'].str.contains(r'\bGreen pea\b')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bGreen pea\b')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bGreen pea\b')==False))]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2008.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2008.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[(temp['ABSTRACT'].str.contains(r'\blegume') | temp['PROJECT_TERMS'].str.contains(r'\blegume')| 
           temp['PROJECT_TITLE'].str.contains(r'\blegume') |temp['ABSTRACT'].str.contains(r'\bLegume') | 
           temp['PROJECT_TERMS'].str.contains(r'\bLegume')| temp['PROJECT_TITLE'].str.contains(r'\bLegume'))|
           (temp['ABSTRACT'].str.contains(r'\blentil') | temp['PROJECT_TERMS'].str.contains(r'\blentil')| 
           temp['PROJECT_TITLE'].str.contains(r'\blentil') |temp['ABSTRACT'].str.contains(r'\bLentil') | 
           temp['PROJECT_TERMS'].str.contains(r'\bLentil')| temp['PROJECT_TITLE'].str.contains(r'\bLentil')) |
           (temp['ABSTRACT'].str.contains(r'\bedamame\b') | temp['PROJECT_TERMS'].str.contains(r'\bedamame\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bedamame\b') |temp['ABSTRACT'].str.contains(r'\bEdamame\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bEdamame\b')| temp['PROJECT_TITLE'].str.contains(r'\bEdamame\b'))|
           ((temp['ABSTRACT'].str.contains(r'\bbean') | temp['PROJECT_TERMS'].str.contains(r'\bbean')| 
           temp['PROJECT_TITLE'].str.contains(r'\bbean') |temp['ABSTRACT'].str.contains(r'\bbean') | 
           temp['PROJECT_TERMS'].str.contains(r'\bbean')| temp['PROJECT_TITLE'].str.contains(r'\bbean'))&
           ((temp['ABSTRACT'].str.contains(r'\bsoybean')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bsoybean')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bsoybean')==False) |(temp['ABSTRACT'].str.contains(r'\bSoybean')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bSoybean')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bSoybean')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bsoy')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bsoy')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bsoy')==False) |(temp['ABSTRACT'].str.contains(r'\bSoy')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bSoy')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bSoy')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bgreen bean')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bgreen bean')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bgreen bean')==False) |(temp['ABSTRACT'].str.contains(r'\bGreen bean')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bGreen bean')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bGreen bean')==False)))&
           ((temp['ABSTRACT'].str.contains(r'\bnut')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bnut')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bnut')==False) |(temp['ABSTRACT'].str.contains(r'\bNut')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bNut')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bNut')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bnuts')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bnuts')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bnuts')==False) |(temp['ABSTRACT'].str.contains(r'\bNuts')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bNuts')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bNuts')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bpeanut')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bpeanut')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bpeanut')==False) |(temp['ABSTRACT'].str.contains(r'\bPeanut')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bPeanut')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bPeanut')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bpeanuts')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bpeanuts')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bpeanuts')==False) |(temp['ABSTRACT'].str.contains(r'\bPeanuts')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bPeanuts')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bPeanuts')==False))|
           (temp['ABSTRACT'].str.contains(r'\bhazelnuts\b') | temp['PROJECT_TERMS'].str.contains(r'\bhazelnuts\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bHazelnuts\b') |temp['ABSTRACT'].str.contains(r'\bhazelnuts\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bHazelnuts\b')| temp['PROJECT_TITLE'].str.contains(r'\bHazelnuts\b'))|
           (temp['ABSTRACT'].str.contains(r'\bchickpea\b') | temp['PROJECT_TERMS'].str.contains(r'\bchickpea\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bchickpea\b') |temp['ABSTRACT'].str.contains(r'\bChickpea\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bChickpea\b')| temp['PROJECT_TITLE'].str.contains(r'\bChickpea\b'))|
           (temp['ABSTRACT'].str.contains(r'\bpea\b') | temp['PROJECT_TERMS'].str.contains(r'\bpea\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bpea\b') |temp['ABSTRACT'].str.contains(r'\bPea\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bPea\b')| temp['PROJECT_TITLE'].str.contains(r'\bPea\b')) &
           ((temp['ABSTRACT'].str.contains(r'\bgreen pea\b')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bgreen pea\b')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bgreen p\b')==False) |(temp['ABSTRACT'].str.contains(r'\bGreen pea\b')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bGreen pea\b')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bGreen pea\b')==False))]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2009.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2009.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[(temp['ABSTRACT'].str.contains(r'\blegume') | temp['PROJECT_TERMS'].str.contains(r'\blegume')| 
           temp['PROJECT_TITLE'].str.contains(r'\blegume') |temp['ABSTRACT'].str.contains(r'\bLegume') | 
           temp['PROJECT_TERMS'].str.contains(r'\bLegume')| temp['PROJECT_TITLE'].str.contains(r'\bLegume'))|
           (temp['ABSTRACT'].str.contains(r'\blentil') | temp['PROJECT_TERMS'].str.contains(r'\blentil')| 
           temp['PROJECT_TITLE'].str.contains(r'\blentil') |temp['ABSTRACT'].str.contains(r'\bLentil') | 
           temp['PROJECT_TERMS'].str.contains(r'\bLentil')| temp['PROJECT_TITLE'].str.contains(r'\bLentil')) |
           (temp['ABSTRACT'].str.contains(r'\bedamame\b') | temp['PROJECT_TERMS'].str.contains(r'\bedamame\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bedamame\b') |temp['ABSTRACT'].str.contains(r'\bEdamame\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bEdamame\b')| temp['PROJECT_TITLE'].str.contains(r'\bEdamame\b'))|
           ((temp['ABSTRACT'].str.contains(r'\bbean') | temp['PROJECT_TERMS'].str.contains(r'\bbean')| 
           temp['PROJECT_TITLE'].str.contains(r'\bbean') |temp['ABSTRACT'].str.contains(r'\bbean') | 
           temp['PROJECT_TERMS'].str.contains(r'\bbean')| temp['PROJECT_TITLE'].str.contains(r'\bbean'))&
           ((temp['ABSTRACT'].str.contains(r'\bsoybean')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bsoybean')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bsoybean')==False) |(temp['ABSTRACT'].str.contains(r'\bSoybean')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bSoybean')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bSoybean')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bsoy')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bsoy')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bsoy')==False) |(temp['ABSTRACT'].str.contains(r'\bSoy')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bSoy')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bSoy')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bgreen bean')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bgreen bean')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bgreen bean')==False) |(temp['ABSTRACT'].str.contains(r'\bGreen bean')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bGreen bean')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bGreen bean')==False)))&
           ((temp['ABSTRACT'].str.contains(r'\bnut')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bnut')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bnut')==False) |(temp['ABSTRACT'].str.contains(r'\bNut')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bNut')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bNut')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bnuts')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bnuts')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bnuts')==False) |(temp['ABSTRACT'].str.contains(r'\bNuts')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bNuts')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bNuts')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bpeanut')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bpeanut')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bpeanut')==False) |(temp['ABSTRACT'].str.contains(r'\bPeanut')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bPeanut')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bPeanut')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bpeanuts')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bpeanuts')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bpeanuts')==False) |(temp['ABSTRACT'].str.contains(r'\bPeanuts')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bPeanuts')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bPeanuts')==False))|
           (temp['ABSTRACT'].str.contains(r'\bhazelnuts\b') | temp['PROJECT_TERMS'].str.contains(r'\bhazelnuts\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bHazelnuts\b') |temp['ABSTRACT'].str.contains(r'\bhazelnuts\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bHazelnuts\b')| temp['PROJECT_TITLE'].str.contains(r'\bHazelnuts\b'))|
           (temp['ABSTRACT'].str.contains(r'\bchickpea\b') | temp['PROJECT_TERMS'].str.contains(r'\bchickpea\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bchickpea\b') |temp['ABSTRACT'].str.contains(r'\bChickpea\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bChickpea\b')| temp['PROJECT_TITLE'].str.contains(r'\bChickpea\b'))|
           (temp['ABSTRACT'].str.contains(r'\bpea\b') | temp['PROJECT_TERMS'].str.contains(r'\bpea\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bpea\b') |temp['ABSTRACT'].str.contains(r'\bPea\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bPea\b')| temp['PROJECT_TITLE'].str.contains(r'\bPea\b')) &
           ((temp['ABSTRACT'].str.contains(r'\bgreen pea\b')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bgreen pea\b')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bgreen p\b')==False) |(temp['ABSTRACT'].str.contains(r'\bGreen pea\b')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bGreen pea\b')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bGreen pea\b')==False))]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2010.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2010.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[(temp['ABSTRACT'].str.contains(r'\blegume') | temp['PROJECT_TERMS'].str.contains(r'\blegume')| 
           temp['PROJECT_TITLE'].str.contains(r'\blegume') |temp['ABSTRACT'].str.contains(r'\bLegume') | 
           temp['PROJECT_TERMS'].str.contains(r'\bLegume')| temp['PROJECT_TITLE'].str.contains(r'\bLegume'))|
           (temp['ABSTRACT'].str.contains(r'\blentil') | temp['PROJECT_TERMS'].str.contains(r'\blentil')| 
           temp['PROJECT_TITLE'].str.contains(r'\blentil') |temp['ABSTRACT'].str.contains(r'\bLentil') | 
           temp['PROJECT_TERMS'].str.contains(r'\bLentil')| temp['PROJECT_TITLE'].str.contains(r'\bLentil')) |
           (temp['ABSTRACT'].str.contains(r'\bedamame\b') | temp['PROJECT_TERMS'].str.contains(r'\bedamame\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bedamame\b') |temp['ABSTRACT'].str.contains(r'\bEdamame\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bEdamame\b')| temp['PROJECT_TITLE'].str.contains(r'\bEdamame\b'))|
           ((temp['ABSTRACT'].str.contains(r'\bbean') | temp['PROJECT_TERMS'].str.contains(r'\bbean')| 
           temp['PROJECT_TITLE'].str.contains(r'\bbean') |temp['ABSTRACT'].str.contains(r'\bbean') | 
           temp['PROJECT_TERMS'].str.contains(r'\bbean')| temp['PROJECT_TITLE'].str.contains(r'\bbean'))&
           ((temp['ABSTRACT'].str.contains(r'\bsoybean')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bsoybean')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bsoybean')==False) |(temp['ABSTRACT'].str.contains(r'\bSoybean')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bSoybean')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bSoybean')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bsoy')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bsoy')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bsoy')==False) |(temp['ABSTRACT'].str.contains(r'\bSoy')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bSoy')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bSoy')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bgreen bean')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bgreen bean')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bgreen bean')==False) |(temp['ABSTRACT'].str.contains(r'\bGreen bean')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bGreen bean')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bGreen bean')==False)))&
           ((temp['ABSTRACT'].str.contains(r'\bnut')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bnut')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bnut')==False) |(temp['ABSTRACT'].str.contains(r'\bNut')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bNut')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bNut')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bnuts')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bnuts')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bnuts')==False) |(temp['ABSTRACT'].str.contains(r'\bNuts')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bNuts')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bNuts')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bpeanut')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bpeanut')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bpeanut')==False) |(temp['ABSTRACT'].str.contains(r'\bPeanut')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bPeanut')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bPeanut')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bpeanuts')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bpeanuts')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bpeanuts')==False) |(temp['ABSTRACT'].str.contains(r'\bPeanuts')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bPeanuts')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bPeanuts')==False))|
           (temp['ABSTRACT'].str.contains(r'\bhazelnuts\b') | temp['PROJECT_TERMS'].str.contains(r'\bhazelnuts\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bHazelnuts\b') |temp['ABSTRACT'].str.contains(r'\bhazelnuts\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bHazelnuts\b')| temp['PROJECT_TITLE'].str.contains(r'\bHazelnuts\b'))|
           (temp['ABSTRACT'].str.contains(r'\bchickpea\b') | temp['PROJECT_TERMS'].str.contains(r'\bchickpea\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bchickpea\b') |temp['ABSTRACT'].str.contains(r'\bChickpea\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bChickpea\b')| temp['PROJECT_TITLE'].str.contains(r'\bChickpea\b'))|
           (temp['ABSTRACT'].str.contains(r'\bpea\b') | temp['PROJECT_TERMS'].str.contains(r'\bpea\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bpea\b') |temp['ABSTRACT'].str.contains(r'\bPea\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bPea\b')| temp['PROJECT_TITLE'].str.contains(r'\bPea\b')) &
           ((temp['ABSTRACT'].str.contains(r'\bgreen pea\b')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bgreen pea\b')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bgreen p\b')==False) |(temp['ABSTRACT'].str.contains(r'\bGreen pea\b')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bGreen pea\b')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bGreen pea\b')==False))]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2011.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2011.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[(temp['ABSTRACT'].str.contains(r'\blegume') | temp['PROJECT_TERMS'].str.contains(r'\blegume')| 
           temp['PROJECT_TITLE'].str.contains(r'\blegume') |temp['ABSTRACT'].str.contains(r'\bLegume') | 
           temp['PROJECT_TERMS'].str.contains(r'\bLegume')| temp['PROJECT_TITLE'].str.contains(r'\bLegume'))|
           (temp['ABSTRACT'].str.contains(r'\blentil') | temp['PROJECT_TERMS'].str.contains(r'\blentil')| 
           temp['PROJECT_TITLE'].str.contains(r'\blentil') |temp['ABSTRACT'].str.contains(r'\bLentil') | 
           temp['PROJECT_TERMS'].str.contains(r'\bLentil')| temp['PROJECT_TITLE'].str.contains(r'\bLentil')) |
           (temp['ABSTRACT'].str.contains(r'\bedamame\b') | temp['PROJECT_TERMS'].str.contains(r'\bedamame\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bedamame\b') |temp['ABSTRACT'].str.contains(r'\bEdamame\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bEdamame\b')| temp['PROJECT_TITLE'].str.contains(r'\bEdamame\b'))|
           ((temp['ABSTRACT'].str.contains(r'\bbean') | temp['PROJECT_TERMS'].str.contains(r'\bbean')| 
           temp['PROJECT_TITLE'].str.contains(r'\bbean') |temp['ABSTRACT'].str.contains(r'\bbean') | 
           temp['PROJECT_TERMS'].str.contains(r'\bbean')| temp['PROJECT_TITLE'].str.contains(r'\bbean'))&
           ((temp['ABSTRACT'].str.contains(r'\bsoybean')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bsoybean')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bsoybean')==False) |(temp['ABSTRACT'].str.contains(r'\bSoybean')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bSoybean')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bSoybean')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bsoy')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bsoy')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bsoy')==False) |(temp['ABSTRACT'].str.contains(r'\bSoy')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bSoy')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bSoy')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bgreen bean')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bgreen bean')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bgreen bean')==False) |(temp['ABSTRACT'].str.contains(r'\bGreen bean')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bGreen bean')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bGreen bean')==False)))&
           ((temp['ABSTRACT'].str.contains(r'\bnut')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bnut')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bnut')==False) |(temp['ABSTRACT'].str.contains(r'\bNut')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bNut')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bNut')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bnuts')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bnuts')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bnuts')==False) |(temp['ABSTRACT'].str.contains(r'\bNuts')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bNuts')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bNuts')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bpeanut')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bpeanut')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bpeanut')==False) |(temp['ABSTRACT'].str.contains(r'\bPeanut')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bPeanut')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bPeanut')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bpeanuts')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bpeanuts')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bpeanuts')==False) |(temp['ABSTRACT'].str.contains(r'\bPeanuts')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bPeanuts')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bPeanuts')==False))|
           (temp['ABSTRACT'].str.contains(r'\bhazelnuts\b') | temp['PROJECT_TERMS'].str.contains(r'\bhazelnuts\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bHazelnuts\b') |temp['ABSTRACT'].str.contains(r'\bhazelnuts\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bHazelnuts\b')| temp['PROJECT_TITLE'].str.contains(r'\bHazelnuts\b'))|
           (temp['ABSTRACT'].str.contains(r'\bchickpea\b') | temp['PROJECT_TERMS'].str.contains(r'\bchickpea\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bchickpea\b') |temp['ABSTRACT'].str.contains(r'\bChickpea\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bChickpea\b')| temp['PROJECT_TITLE'].str.contains(r'\bChickpea\b'))|
           (temp['ABSTRACT'].str.contains(r'\bpea\b') | temp['PROJECT_TERMS'].str.contains(r'\bpea\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bpea\b') |temp['ABSTRACT'].str.contains(r'\bPea\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bPea\b')| temp['PROJECT_TITLE'].str.contains(r'\bPea\b')) &
           ((temp['ABSTRACT'].str.contains(r'\bgreen pea\b')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bgreen pea\b')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bgreen p\b')==False) |(temp['ABSTRACT'].str.contains(r'\bGreen pea\b')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bGreen pea\b')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bGreen pea\b')==False))]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2012.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2012.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[(temp['ABSTRACT'].str.contains(r'\blegume') | temp['PROJECT_TERMS'].str.contains(r'\blegume')| 
           temp['PROJECT_TITLE'].str.contains(r'\blegume') |temp['ABSTRACT'].str.contains(r'\bLegume') | 
           temp['PROJECT_TERMS'].str.contains(r'\bLegume')| temp['PROJECT_TITLE'].str.contains(r'\bLegume'))|
           (temp['ABSTRACT'].str.contains(r'\blentil') | temp['PROJECT_TERMS'].str.contains(r'\blentil')| 
           temp['PROJECT_TITLE'].str.contains(r'\blentil') |temp['ABSTRACT'].str.contains(r'\bLentil') | 
           temp['PROJECT_TERMS'].str.contains(r'\bLentil')| temp['PROJECT_TITLE'].str.contains(r'\bLentil')) |
           (temp['ABSTRACT'].str.contains(r'\bedamame\b') | temp['PROJECT_TERMS'].str.contains(r'\bedamame\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bedamame\b') |temp['ABSTRACT'].str.contains(r'\bEdamame\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bEdamame\b')| temp['PROJECT_TITLE'].str.contains(r'\bEdamame\b'))|
           ((temp['ABSTRACT'].str.contains(r'\bbean') | temp['PROJECT_TERMS'].str.contains(r'\bbean')| 
           temp['PROJECT_TITLE'].str.contains(r'\bbean') |temp['ABSTRACT'].str.contains(r'\bbean') | 
           temp['PROJECT_TERMS'].str.contains(r'\bbean')| temp['PROJECT_TITLE'].str.contains(r'\bbean'))&
           ((temp['ABSTRACT'].str.contains(r'\bsoybean')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bsoybean')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bsoybean')==False) |(temp['ABSTRACT'].str.contains(r'\bSoybean')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bSoybean')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bSoybean')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bsoy')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bsoy')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bsoy')==False) |(temp['ABSTRACT'].str.contains(r'\bSoy')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bSoy')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bSoy')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bgreen bean')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bgreen bean')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bgreen bean')==False) |(temp['ABSTRACT'].str.contains(r'\bGreen bean')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bGreen bean')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bGreen bean')==False)))&
           ((temp['ABSTRACT'].str.contains(r'\bnut')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bnut')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bnut')==False) |(temp['ABSTRACT'].str.contains(r'\bNut')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bNut')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bNut')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bnuts')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bnuts')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bnuts')==False) |(temp['ABSTRACT'].str.contains(r'\bNuts')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bNuts')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bNuts')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bpeanut')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bpeanut')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bpeanut')==False) |(temp['ABSTRACT'].str.contains(r'\bPeanut')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bPeanut')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bPeanut')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bpeanuts')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bpeanuts')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bpeanuts')==False) |(temp['ABSTRACT'].str.contains(r'\bPeanuts')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bPeanuts')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bPeanuts')==False))|
           (temp['ABSTRACT'].str.contains(r'\bhazelnuts\b') | temp['PROJECT_TERMS'].str.contains(r'\bhazelnuts\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bHazelnuts\b') |temp['ABSTRACT'].str.contains(r'\bhazelnuts\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bHazelnuts\b')| temp['PROJECT_TITLE'].str.contains(r'\bHazelnuts\b'))|
           (temp['ABSTRACT'].str.contains(r'\bchickpea\b') | temp['PROJECT_TERMS'].str.contains(r'\bchickpea\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bchickpea\b') |temp['ABSTRACT'].str.contains(r'\bChickpea\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bChickpea\b')| temp['PROJECT_TITLE'].str.contains(r'\bChickpea\b'))|
           (temp['ABSTRACT'].str.contains(r'\bpea\b') | temp['PROJECT_TERMS'].str.contains(r'\bpea\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bpea\b') |temp['ABSTRACT'].str.contains(r'\bPea\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bPea\b')| temp['PROJECT_TITLE'].str.contains(r'\bPea\b')) &
           ((temp['ABSTRACT'].str.contains(r'\bgreen pea\b')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bgreen pea\b')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bgreen p\b')==False) |(temp['ABSTRACT'].str.contains(r'\bGreen pea\b')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bGreen pea\b')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bGreen pea\b')==False))]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2013.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2013.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[(temp['ABSTRACT'].str.contains(r'\blegume') | temp['PROJECT_TERMS'].str.contains(r'\blegume')| 
           temp['PROJECT_TITLE'].str.contains(r'\blegume') |temp['ABSTRACT'].str.contains(r'\bLegume') | 
           temp['PROJECT_TERMS'].str.contains(r'\bLegume')| temp['PROJECT_TITLE'].str.contains(r'\bLegume'))|
           (temp['ABSTRACT'].str.contains(r'\blentil') | temp['PROJECT_TERMS'].str.contains(r'\blentil')| 
           temp['PROJECT_TITLE'].str.contains(r'\blentil') |temp['ABSTRACT'].str.contains(r'\bLentil') | 
           temp['PROJECT_TERMS'].str.contains(r'\bLentil')| temp['PROJECT_TITLE'].str.contains(r'\bLentil')) |
           (temp['ABSTRACT'].str.contains(r'\bedamame\b') | temp['PROJECT_TERMS'].str.contains(r'\bedamame\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bedamame\b') |temp['ABSTRACT'].str.contains(r'\bEdamame\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bEdamame\b')| temp['PROJECT_TITLE'].str.contains(r'\bEdamame\b'))|
           ((temp['ABSTRACT'].str.contains(r'\bbean') | temp['PROJECT_TERMS'].str.contains(r'\bbean')| 
           temp['PROJECT_TITLE'].str.contains(r'\bbean') |temp['ABSTRACT'].str.contains(r'\bbean') | 
           temp['PROJECT_TERMS'].str.contains(r'\bbean')| temp['PROJECT_TITLE'].str.contains(r'\bbean'))&
           ((temp['ABSTRACT'].str.contains(r'\bsoybean')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bsoybean')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bsoybean')==False) |(temp['ABSTRACT'].str.contains(r'\bSoybean')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bSoybean')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bSoybean')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bsoy')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bsoy')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bsoy')==False) |(temp['ABSTRACT'].str.contains(r'\bSoy')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bSoy')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bSoy')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bgreen bean')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bgreen bean')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bgreen bean')==False) |(temp['ABSTRACT'].str.contains(r'\bGreen bean')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bGreen bean')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bGreen bean')==False)))&
           ((temp['ABSTRACT'].str.contains(r'\bnut')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bnut')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bnut')==False) |(temp['ABSTRACT'].str.contains(r'\bNut')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bNut')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bNut')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bnuts')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bnuts')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bnuts')==False) |(temp['ABSTRACT'].str.contains(r'\bNuts')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bNuts')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bNuts')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bpeanut')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bpeanut')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bpeanut')==False) |(temp['ABSTRACT'].str.contains(r'\bPeanut')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bPeanut')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bPeanut')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bpeanuts')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bpeanuts')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bpeanuts')==False) |(temp['ABSTRACT'].str.contains(r'\bPeanuts')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bPeanuts')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bPeanuts')==False))|
           (temp['ABSTRACT'].str.contains(r'\bhazelnuts\b') | temp['PROJECT_TERMS'].str.contains(r'\bhazelnuts\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bHazelnuts\b') |temp['ABSTRACT'].str.contains(r'\bhazelnuts\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bHazelnuts\b')| temp['PROJECT_TITLE'].str.contains(r'\bHazelnuts\b'))|
           (temp['ABSTRACT'].str.contains(r'\bchickpea\b') | temp['PROJECT_TERMS'].str.contains(r'\bchickpea\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bchickpea\b') |temp['ABSTRACT'].str.contains(r'\bChickpea\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bChickpea\b')| temp['PROJECT_TITLE'].str.contains(r'\bChickpea\b'))|
           (temp['ABSTRACT'].str.contains(r'\bpea\b') | temp['PROJECT_TERMS'].str.contains(r'\bpea\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bpea\b') |temp['ABSTRACT'].str.contains(r'\bPea\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bPea\b')| temp['PROJECT_TITLE'].str.contains(r'\bPea\b')) &
           ((temp['ABSTRACT'].str.contains(r'\bgreen pea\b')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bgreen pea\b')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bgreen p\b')==False) |(temp['ABSTRACT'].str.contains(r'\bGreen pea\b')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bGreen pea\b')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bGreen pea\b')==False))]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2014.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2014.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[(temp['ABSTRACT'].str.contains(r'\blegume') | temp['PROJECT_TERMS'].str.contains(r'\blegume')| 
           temp['PROJECT_TITLE'].str.contains(r'\blegume') |temp['ABSTRACT'].str.contains(r'\bLegume') | 
           temp['PROJECT_TERMS'].str.contains(r'\bLegume')| temp['PROJECT_TITLE'].str.contains(r'\bLegume'))|
           (temp['ABSTRACT'].str.contains(r'\blentil') | temp['PROJECT_TERMS'].str.contains(r'\blentil')| 
           temp['PROJECT_TITLE'].str.contains(r'\blentil') |temp['ABSTRACT'].str.contains(r'\bLentil') | 
           temp['PROJECT_TERMS'].str.contains(r'\bLentil')| temp['PROJECT_TITLE'].str.contains(r'\bLentil')) |
           (temp['ABSTRACT'].str.contains(r'\bedamame\b') | temp['PROJECT_TERMS'].str.contains(r'\bedamame\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bedamame\b') |temp['ABSTRACT'].str.contains(r'\bEdamame\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bEdamame\b')| temp['PROJECT_TITLE'].str.contains(r'\bEdamame\b'))|
           ((temp['ABSTRACT'].str.contains(r'\bbean') | temp['PROJECT_TERMS'].str.contains(r'\bbean')| 
           temp['PROJECT_TITLE'].str.contains(r'\bbean') |temp['ABSTRACT'].str.contains(r'\bbean') | 
           temp['PROJECT_TERMS'].str.contains(r'\bbean')| temp['PROJECT_TITLE'].str.contains(r'\bbean'))&
           ((temp['ABSTRACT'].str.contains(r'\bsoybean')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bsoybean')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bsoybean')==False) |(temp['ABSTRACT'].str.contains(r'\bSoybean')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bSoybean')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bSoybean')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bsoy')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bsoy')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bsoy')==False) |(temp['ABSTRACT'].str.contains(r'\bSoy')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bSoy')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bSoy')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bgreen bean')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bgreen bean')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bgreen bean')==False) |(temp['ABSTRACT'].str.contains(r'\bGreen bean')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bGreen bean')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bGreen bean')==False)))&
           ((temp['ABSTRACT'].str.contains(r'\bnut')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bnut')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bnut')==False) |(temp['ABSTRACT'].str.contains(r'\bNut')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bNut')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bNut')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bnuts')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bnuts')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bnuts')==False) |(temp['ABSTRACT'].str.contains(r'\bNuts')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bNuts')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bNuts')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bpeanut')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bpeanut')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bpeanut')==False) |(temp['ABSTRACT'].str.contains(r'\bPeanut')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bPeanut')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bPeanut')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bpeanuts')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bpeanuts')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bpeanuts')==False) |(temp['ABSTRACT'].str.contains(r'\bPeanuts')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bPeanuts')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bPeanuts')==False))|
           (temp['ABSTRACT'].str.contains(r'\bhazelnuts\b') | temp['PROJECT_TERMS'].str.contains(r'\bhazelnuts\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bHazelnuts\b') |temp['ABSTRACT'].str.contains(r'\bhazelnuts\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bHazelnuts\b')| temp['PROJECT_TITLE'].str.contains(r'\bHazelnuts\b'))|
           (temp['ABSTRACT'].str.contains(r'\bchickpea\b') | temp['PROJECT_TERMS'].str.contains(r'\bchickpea\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bchickpea\b') |temp['ABSTRACT'].str.contains(r'\bChickpea\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bChickpea\b')| temp['PROJECT_TITLE'].str.contains(r'\bChickpea\b'))|
           (temp['ABSTRACT'].str.contains(r'\bpea\b') | temp['PROJECT_TERMS'].str.contains(r'\bpea\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bpea\b') |temp['ABSTRACT'].str.contains(r'\bPea\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bPea\b')| temp['PROJECT_TITLE'].str.contains(r'\bPea\b')) &
           ((temp['ABSTRACT'].str.contains(r'\bgreen pea\b')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bgreen pea\b')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bgreen p\b')==False) |(temp['ABSTRACT'].str.contains(r'\bGreen pea\b')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bGreen pea\b')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bGreen pea\b')==False))]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2015.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2015.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[(temp['ABSTRACT'].str.contains(r'\blegume') | temp['PROJECT_TERMS'].str.contains(r'\blegume')| 
           temp['PROJECT_TITLE'].str.contains(r'\blegume') |temp['ABSTRACT'].str.contains(r'\bLegume') | 
           temp['PROJECT_TERMS'].str.contains(r'\bLegume')| temp['PROJECT_TITLE'].str.contains(r'\bLegume'))|
           (temp['ABSTRACT'].str.contains(r'\blentil') | temp['PROJECT_TERMS'].str.contains(r'\blentil')| 
           temp['PROJECT_TITLE'].str.contains(r'\blentil') |temp['ABSTRACT'].str.contains(r'\bLentil') | 
           temp['PROJECT_TERMS'].str.contains(r'\bLentil')| temp['PROJECT_TITLE'].str.contains(r'\bLentil')) |
           (temp['ABSTRACT'].str.contains(r'\bedamame\b') | temp['PROJECT_TERMS'].str.contains(r'\bedamame\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bedamame\b') |temp['ABSTRACT'].str.contains(r'\bEdamame\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bEdamame\b')| temp['PROJECT_TITLE'].str.contains(r'\bEdamame\b'))|
           ((temp['ABSTRACT'].str.contains(r'\bbean') | temp['PROJECT_TERMS'].str.contains(r'\bbean')| 
           temp['PROJECT_TITLE'].str.contains(r'\bbean') |temp['ABSTRACT'].str.contains(r'\bbean') | 
           temp['PROJECT_TERMS'].str.contains(r'\bbean')| temp['PROJECT_TITLE'].str.contains(r'\bbean'))&
           ((temp['ABSTRACT'].str.contains(r'\bsoybean')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bsoybean')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bsoybean')==False) |(temp['ABSTRACT'].str.contains(r'\bSoybean')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bSoybean')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bSoybean')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bsoy')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bsoy')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bsoy')==False) |(temp['ABSTRACT'].str.contains(r'\bSoy')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bSoy')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bSoy')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bgreen bean')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bgreen bean')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bgreen bean')==False) |(temp['ABSTRACT'].str.contains(r'\bGreen bean')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bGreen bean')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bGreen bean')==False)))&
           ((temp['ABSTRACT'].str.contains(r'\bnut')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bnut')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bnut')==False) |(temp['ABSTRACT'].str.contains(r'\bNut')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bNut')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bNut')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bnuts')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bnuts')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bnuts')==False) |(temp['ABSTRACT'].str.contains(r'\bNuts')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bNuts')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bNuts')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bpeanut')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bpeanut')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bpeanut')==False) |(temp['ABSTRACT'].str.contains(r'\bPeanut')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bPeanut')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bPeanut')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bpeanuts')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bpeanuts')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bpeanuts')==False) |(temp['ABSTRACT'].str.contains(r'\bPeanuts')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bPeanuts')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bPeanuts')==False))|
           (temp['ABSTRACT'].str.contains(r'\bhazelnuts\b') | temp['PROJECT_TERMS'].str.contains(r'\bhazelnuts\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bHazelnuts\b') |temp['ABSTRACT'].str.contains(r'\bhazelnuts\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bHazelnuts\b')| temp['PROJECT_TITLE'].str.contains(r'\bHazelnuts\b'))|
           (temp['ABSTRACT'].str.contains(r'\bchickpea\b') | temp['PROJECT_TERMS'].str.contains(r'\bchickpea\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bchickpea\b') |temp['ABSTRACT'].str.contains(r'\bChickpea\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bChickpea\b')| temp['PROJECT_TITLE'].str.contains(r'\bChickpea\b'))|
           (temp['ABSTRACT'].str.contains(r'\bpea\b') | temp['PROJECT_TERMS'].str.contains(r'\bpea\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bpea\b') |temp['ABSTRACT'].str.contains(r'\bPea\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bPea\b')| temp['PROJECT_TITLE'].str.contains(r'\bPea\b')) &
           ((temp['ABSTRACT'].str.contains(r'\bgreen pea\b')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bgreen pea\b')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bgreen p\b')==False) |(temp['ABSTRACT'].str.contains(r'\bGreen pea\b')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bGreen pea\b')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bGreen pea\b')==False))]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2016.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2016.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[(temp['ABSTRACT'].str.contains(r'\blegume') | temp['PROJECT_TERMS'].str.contains(r'\blegume')| 
           temp['PROJECT_TITLE'].str.contains(r'\blegume') |temp['ABSTRACT'].str.contains(r'\bLegume') | 
           temp['PROJECT_TERMS'].str.contains(r'\bLegume')| temp['PROJECT_TITLE'].str.contains(r'\bLegume'))|
           (temp['ABSTRACT'].str.contains(r'\blentil') | temp['PROJECT_TERMS'].str.contains(r'\blentil')| 
           temp['PROJECT_TITLE'].str.contains(r'\blentil') |temp['ABSTRACT'].str.contains(r'\bLentil') | 
           temp['PROJECT_TERMS'].str.contains(r'\bLentil')| temp['PROJECT_TITLE'].str.contains(r'\bLentil')) |
           (temp['ABSTRACT'].str.contains(r'\bedamame\b') | temp['PROJECT_TERMS'].str.contains(r'\bedamame\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bedamame\b') |temp['ABSTRACT'].str.contains(r'\bEdamame\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bEdamame\b')| temp['PROJECT_TITLE'].str.contains(r'\bEdamame\b'))|
           ((temp['ABSTRACT'].str.contains(r'\bbean') | temp['PROJECT_TERMS'].str.contains(r'\bbean')| 
           temp['PROJECT_TITLE'].str.contains(r'\bbean') |temp['ABSTRACT'].str.contains(r'\bbean') | 
           temp['PROJECT_TERMS'].str.contains(r'\bbean')| temp['PROJECT_TITLE'].str.contains(r'\bbean'))&
           ((temp['ABSTRACT'].str.contains(r'\bsoybean')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bsoybean')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bsoybean')==False) |(temp['ABSTRACT'].str.contains(r'\bSoybean')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bSoybean')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bSoybean')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bsoy')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bsoy')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bsoy')==False) |(temp['ABSTRACT'].str.contains(r'\bSoy')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bSoy')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bSoy')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bgreen bean')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bgreen bean')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bgreen bean')==False) |(temp['ABSTRACT'].str.contains(r'\bGreen bean')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bGreen bean')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bGreen bean')==False)))&
           ((temp['ABSTRACT'].str.contains(r'\bnut')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bnut')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bnut')==False) |(temp['ABSTRACT'].str.contains(r'\bNut')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bNut')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bNut')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bnuts')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bnuts')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bnuts')==False) |(temp['ABSTRACT'].str.contains(r'\bNuts')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bNuts')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bNuts')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bpeanut')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bpeanut')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bpeanut')==False) |(temp['ABSTRACT'].str.contains(r'\bPeanut')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bPeanut')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bPeanut')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bpeanuts')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bpeanuts')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bpeanuts')==False) |(temp['ABSTRACT'].str.contains(r'\bPeanuts')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bPeanuts')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bPeanuts')==False))|
           (temp['ABSTRACT'].str.contains(r'\bhazelnuts\b') | temp['PROJECT_TERMS'].str.contains(r'\bhazelnuts\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bHazelnuts\b') |temp['ABSTRACT'].str.contains(r'\bhazelnuts\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bHazelnuts\b')| temp['PROJECT_TITLE'].str.contains(r'\bHazelnuts\b'))|
           (temp['ABSTRACT'].str.contains(r'\bchickpea\b') | temp['PROJECT_TERMS'].str.contains(r'\bchickpea\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bchickpea\b') |temp['ABSTRACT'].str.contains(r'\bChickpea\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bChickpea\b')| temp['PROJECT_TITLE'].str.contains(r'\bChickpea\b'))|
           (temp['ABSTRACT'].str.contains(r'\bpea\b') | temp['PROJECT_TERMS'].str.contains(r'\bpea\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bpea\b') |temp['ABSTRACT'].str.contains(r'\bPea\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bPea\b')| temp['PROJECT_TITLE'].str.contains(r'\bPea\b')) &
           ((temp['ABSTRACT'].str.contains(r'\bgreen pea\b')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bgreen pea\b')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bgreen p\b')==False) |(temp['ABSTRACT'].str.contains(r'\bGreen pea\b')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bGreen pea\b')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bGreen pea\b')==False))]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2017.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2017.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[(temp['ABSTRACT'].str.contains(r'\blegume') | temp['PROJECT_TERMS'].str.contains(r'\blegume')| 
           temp['PROJECT_TITLE'].str.contains(r'\blegume') |temp['ABSTRACT'].str.contains(r'\bLegume') | 
           temp['PROJECT_TERMS'].str.contains(r'\bLegume')| temp['PROJECT_TITLE'].str.contains(r'\bLegume'))|
           (temp['ABSTRACT'].str.contains(r'\blentil') | temp['PROJECT_TERMS'].str.contains(r'\blentil')| 
           temp['PROJECT_TITLE'].str.contains(r'\blentil') |temp['ABSTRACT'].str.contains(r'\bLentil') | 
           temp['PROJECT_TERMS'].str.contains(r'\bLentil')| temp['PROJECT_TITLE'].str.contains(r'\bLentil')) |
           (temp['ABSTRACT'].str.contains(r'\bedamame\b') | temp['PROJECT_TERMS'].str.contains(r'\bedamame\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bedamame\b') |temp['ABSTRACT'].str.contains(r'\bEdamame\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bEdamame\b')| temp['PROJECT_TITLE'].str.contains(r'\bEdamame\b'))|
           ((temp['ABSTRACT'].str.contains(r'\bbean') | temp['PROJECT_TERMS'].str.contains(r'\bbean')| 
           temp['PROJECT_TITLE'].str.contains(r'\bbean') |temp['ABSTRACT'].str.contains(r'\bbean') | 
           temp['PROJECT_TERMS'].str.contains(r'\bbean')| temp['PROJECT_TITLE'].str.contains(r'\bbean'))&
           ((temp['ABSTRACT'].str.contains(r'\bsoybean')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bsoybean')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bsoybean')==False) |(temp['ABSTRACT'].str.contains(r'\bSoybean')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bSoybean')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bSoybean')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bsoy')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bsoy')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bsoy')==False) |(temp['ABSTRACT'].str.contains(r'\bSoy')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bSoy')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bSoy')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bgreen bean')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bgreen bean')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bgreen bean')==False) |(temp['ABSTRACT'].str.contains(r'\bGreen bean')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bGreen bean')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bGreen bean')==False)))&
           ((temp['ABSTRACT'].str.contains(r'\bnut')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bnut')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bnut')==False) |(temp['ABSTRACT'].str.contains(r'\bNut')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bNut')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bNut')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bnuts')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bnuts')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bnuts')==False) |(temp['ABSTRACT'].str.contains(r'\bNuts')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bNuts')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bNuts')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bpeanut')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bpeanut')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bpeanut')==False) |(temp['ABSTRACT'].str.contains(r'\bPeanut')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bPeanut')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bPeanut')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bpeanuts')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bpeanuts')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bpeanuts')==False) |(temp['ABSTRACT'].str.contains(r'\bPeanuts')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bPeanuts')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bPeanuts')==False))|
           (temp['ABSTRACT'].str.contains(r'\bhazelnuts\b') | temp['PROJECT_TERMS'].str.contains(r'\bhazelnuts\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bHazelnuts\b') |temp['ABSTRACT'].str.contains(r'\bhazelnuts\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bHazelnuts\b')| temp['PROJECT_TITLE'].str.contains(r'\bHazelnuts\b'))|
           (temp['ABSTRACT'].str.contains(r'\bchickpea\b') | temp['PROJECT_TERMS'].str.contains(r'\bchickpea\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bchickpea\b') |temp['ABSTRACT'].str.contains(r'\bChickpea\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bChickpea\b')| temp['PROJECT_TITLE'].str.contains(r'\bChickpea\b'))|
           (temp['ABSTRACT'].str.contains(r'\bpea\b') | temp['PROJECT_TERMS'].str.contains(r'\bpea\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bpea\b') |temp['ABSTRACT'].str.contains(r'\bPea\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bPea\b')| temp['PROJECT_TITLE'].str.contains(r'\bPea\b')) &
           ((temp['ABSTRACT'].str.contains(r'\bgreen pea\b')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bgreen pea\b')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bgreen p\b')==False) |(temp['ABSTRACT'].str.contains(r'\bGreen pea\b')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bGreen pea\b')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bGreen pea\b')==False))]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)


df_abs=pd.read_csv('abstract/PRJABS_2018.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2018.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[(temp['ABSTRACT'].str.contains(r'\blegume') | temp['PROJECT_TERMS'].str.contains(r'\blegume')| 
           temp['PROJECT_TITLE'].str.contains(r'\blegume') |temp['ABSTRACT'].str.contains(r'\bLegume') | 
           temp['PROJECT_TERMS'].str.contains(r'\bLegume')| temp['PROJECT_TITLE'].str.contains(r'\bLegume'))|
           (temp['ABSTRACT'].str.contains(r'\blentil') | temp['PROJECT_TERMS'].str.contains(r'\blentil')| 
           temp['PROJECT_TITLE'].str.contains(r'\blentil') |temp['ABSTRACT'].str.contains(r'\bLentil') | 
           temp['PROJECT_TERMS'].str.contains(r'\bLentil')| temp['PROJECT_TITLE'].str.contains(r'\bLentil')) |
           (temp['ABSTRACT'].str.contains(r'\bedamame\b') | temp['PROJECT_TERMS'].str.contains(r'\bedamame\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bedamame\b') |temp['ABSTRACT'].str.contains(r'\bEdamame\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bEdamame\b')| temp['PROJECT_TITLE'].str.contains(r'\bEdamame\b'))|
           ((temp['ABSTRACT'].str.contains(r'\bbean') | temp['PROJECT_TERMS'].str.contains(r'\bbean')| 
           temp['PROJECT_TITLE'].str.contains(r'\bbean') |temp['ABSTRACT'].str.contains(r'\bbean') | 
           temp['PROJECT_TERMS'].str.contains(r'\bbean')| temp['PROJECT_TITLE'].str.contains(r'\bbean'))&
           ((temp['ABSTRACT'].str.contains(r'\bsoybean')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bsoybean')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bsoybean')==False) |(temp['ABSTRACT'].str.contains(r'\bSoybean')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bSoybean')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bSoybean')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bsoy')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bsoy')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bsoy')==False) |(temp['ABSTRACT'].str.contains(r'\bSoy')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bSoy')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bSoy')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bgreen bean')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bgreen bean')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bgreen bean')==False) |(temp['ABSTRACT'].str.contains(r'\bGreen bean')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bGreen bean')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bGreen bean')==False)))&
           ((temp['ABSTRACT'].str.contains(r'\bnut')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bnut')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bnut')==False) |(temp['ABSTRACT'].str.contains(r'\bNut')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bNut')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bNut')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bnuts')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bnuts')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bnuts')==False) |(temp['ABSTRACT'].str.contains(r'\bNuts')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bNuts')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bNuts')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bpeanut')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bpeanut')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bpeanut')==False) |(temp['ABSTRACT'].str.contains(r'\bPeanut')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bPeanut')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bPeanut')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bpeanuts')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bpeanuts')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bpeanuts')==False) |(temp['ABSTRACT'].str.contains(r'\bPeanuts')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bPeanuts')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bPeanuts')==False))|
           (temp['ABSTRACT'].str.contains(r'\bhazelnuts\b') | temp['PROJECT_TERMS'].str.contains(r'\bhazelnuts\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bHazelnuts\b') |temp['ABSTRACT'].str.contains(r'\bhazelnuts\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bHazelnuts\b')| temp['PROJECT_TITLE'].str.contains(r'\bHazelnuts\b'))|
           (temp['ABSTRACT'].str.contains(r'\bchickpea\b') | temp['PROJECT_TERMS'].str.contains(r'\bchickpea\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bchickpea\b') |temp['ABSTRACT'].str.contains(r'\bChickpea\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bChickpea\b')| temp['PROJECT_TITLE'].str.contains(r'\bChickpea\b'))|
           (temp['ABSTRACT'].str.contains(r'\bpea\b') | temp['PROJECT_TERMS'].str.contains(r'\bpea\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bpea\b') |temp['ABSTRACT'].str.contains(r'\bPea\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bPea\b')| temp['PROJECT_TITLE'].str.contains(r'\bPea\b')) &
           ((temp['ABSTRACT'].str.contains(r'\bgreen pea\b')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bgreen pea\b')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bgreen p\b')==False) |(temp['ABSTRACT'].str.contains(r'\bGreen pea\b')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bGreen pea\b')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bGreen pea\b')==False))]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2019.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2019.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[(temp['ABSTRACT'].str.contains(r'\blegume') | temp['PROJECT_TERMS'].str.contains(r'\blegume')| 
           temp['PROJECT_TITLE'].str.contains(r'\blegume') |temp['ABSTRACT'].str.contains(r'\bLegume') | 
           temp['PROJECT_TERMS'].str.contains(r'\bLegume')| temp['PROJECT_TITLE'].str.contains(r'\bLegume'))|
           (temp['ABSTRACT'].str.contains(r'\blentil') | temp['PROJECT_TERMS'].str.contains(r'\blentil')| 
           temp['PROJECT_TITLE'].str.contains(r'\blentil') |temp['ABSTRACT'].str.contains(r'\bLentil') | 
           temp['PROJECT_TERMS'].str.contains(r'\bLentil')| temp['PROJECT_TITLE'].str.contains(r'\bLentil')) |
           (temp['ABSTRACT'].str.contains(r'\bedamame\b') | temp['PROJECT_TERMS'].str.contains(r'\bedamame\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bedamame\b') |temp['ABSTRACT'].str.contains(r'\bEdamame\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bEdamame\b')| temp['PROJECT_TITLE'].str.contains(r'\bEdamame\b'))|
           ((temp['ABSTRACT'].str.contains(r'\bbean') | temp['PROJECT_TERMS'].str.contains(r'\bbean')| 
           temp['PROJECT_TITLE'].str.contains(r'\bbean') |temp['ABSTRACT'].str.contains(r'\bbean') | 
           temp['PROJECT_TERMS'].str.contains(r'\bbean')| temp['PROJECT_TITLE'].str.contains(r'\bbean'))&
           ((temp['ABSTRACT'].str.contains(r'\bsoybean')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bsoybean')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bsoybean')==False) |(temp['ABSTRACT'].str.contains(r'\bSoybean')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bSoybean')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bSoybean')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bsoy')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bsoy')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bsoy')==False) |(temp['ABSTRACT'].str.contains(r'\bSoy')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bSoy')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bSoy')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bgreen bean')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bgreen bean')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bgreen bean')==False) |(temp['ABSTRACT'].str.contains(r'\bGreen bean')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bGreen bean')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bGreen bean')==False)))&
           ((temp['ABSTRACT'].str.contains(r'\bnut')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bnut')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bnut')==False) |(temp['ABSTRACT'].str.contains(r'\bNut')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bNut')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bNut')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bnuts')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bnuts')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bnuts')==False) |(temp['ABSTRACT'].str.contains(r'\bNuts')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bNuts')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bNuts')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bpeanut')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bpeanut')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bpeanut')==False) |(temp['ABSTRACT'].str.contains(r'\bPeanut')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bPeanut')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bPeanut')==False))&
           ((temp['ABSTRACT'].str.contains(r'\bpeanuts')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bpeanuts')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bpeanuts')==False) |(temp['ABSTRACT'].str.contains(r'\bPeanuts')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bPeanuts')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bPeanuts')==False))|
           (temp['ABSTRACT'].str.contains(r'\bhazelnuts\b') | temp['PROJECT_TERMS'].str.contains(r'\bhazelnuts\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bHazelnuts\b') |temp['ABSTRACT'].str.contains(r'\bhazelnuts\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bHazelnuts\b')| temp['PROJECT_TITLE'].str.contains(r'\bHazelnuts\b'))|
           (temp['ABSTRACT'].str.contains(r'\bchickpea\b') | temp['PROJECT_TERMS'].str.contains(r'\bchickpea\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bchickpea\b') |temp['ABSTRACT'].str.contains(r'\bChickpea\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bChickpea\b')| temp['PROJECT_TITLE'].str.contains(r'\bChickpea\b'))|
           (temp['ABSTRACT'].str.contains(r'\bpea\b') | temp['PROJECT_TERMS'].str.contains(r'\bpea\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bpea\b') |temp['ABSTRACT'].str.contains(r'\bPea\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bPea\b')| temp['PROJECT_TITLE'].str.contains(r'\bPea\b')) &
           ((temp['ABSTRACT'].str.contains(r'\bgreen pea\b')==False) | (temp['PROJECT_TERMS'].str.contains(r'\bgreen pea\b')==False)| 
           (temp['PROJECT_TITLE'].str.contains(r'\bgreen p\b')==False) |(temp['ABSTRACT'].str.contains(r'\bGreen pea\b')==False) | 
           (temp['PROJECT_TERMS'].str.contains(r'\bGreen pea\b')==False)| (temp['PROJECT_TITLE'].str.contains(r'\bGreen pea\b')==False))]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)
# Out:
# (668, 24) (0, 25)
# (340, 24) (0, 25)
# (351, 24) (1, 25)
# (310, 24) (2, 25)
# (641, 24) (9, 25)
# (618, 24) (15, 25)
# (640, 24) (23, 25)
# (598, 24) (31, 25)
# (104076, 24) (213, 25)
# (118557, 24) (408, 25)
# (111400, 24) (606, 25)
# (98064, 24) (780, 25)
# (93367, 24) (895, 25)
# (91637, 24) (1046, 25)
# (90944, 24) (1175, 25)
# (92265, 24) (1319, 25)
# (91126, 24) (1459, 25)
# b'Skipping line 87965: expected 24 fields, saw 25\nSkipping line 87967: expected 24 fields, saw 25\n'
# (88420, 24) (1600, 25)
# b'Skipping line 95568: expected 24 fields, saw 25\nSkipping line 95570: expected 24 fields, saw 25\n'
# (96209, 24) (1798, 25)
# b'Skipping line 74736: expected 24 fields, saw 25\nSkipping line 79976: expected 24 fields, saw 25\n'
# (80066, 24) (1995, 25)

# %%
df = df[df.AGENCY != 'NASA']
df = df[df.AGENCY != 'NIH']
print(df.shape)
df.to_csv('legume_other.csv')
# Out:
# (1169, 25)

# %% [markdown]
# # Rice

# %%
df=pd.DataFrame()
df_abs=pd.read_csv('abstract/PRJABS_2000.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2000.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\brice\b') | temp['PROJECT_TERMS'].str.contains(r'\brice\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\brice\b') |temp['ABSTRACT'].str.contains(r'\bRice\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bRice\b')| temp['PROJECT_TITLE'].str.contains(r'\bRice\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2001.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2001.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\brice\b') | temp['PROJECT_TERMS'].str.contains(r'\brice\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\brice\b') |temp['ABSTRACT'].str.contains(r'\bRice\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bRice\b')| temp['PROJECT_TITLE'].str.contains(r'\bRice\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)


df_abs=pd.read_csv('abstract/PRJABS_2002.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2002.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\brice\b') | temp['PROJECT_TERMS'].str.contains(r'\brice\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\brice\b') |temp['ABSTRACT'].str.contains(r'\bRice\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bRice\b')| temp['PROJECT_TITLE'].str.contains(r'\bRice\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)


df_abs=pd.read_csv('abstract/PRJABS_2003.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2003.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\brice\b') | temp['PROJECT_TERMS'].str.contains(r'\brice\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\brice\b') |temp['ABSTRACT'].str.contains(r'\bRice\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bRice\b')| temp['PROJECT_TITLE'].str.contains(r'\bRice\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2004.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2004.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\brice\b') | temp['PROJECT_TERMS'].str.contains(r'\brice\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\brice\b') |temp['ABSTRACT'].str.contains(r'\bRice\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bRice\b')| temp['PROJECT_TITLE'].str.contains(r'\bRice\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)


df_abs=pd.read_csv('abstract/PRJABS_2005.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2005.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\brice\b') | temp['PROJECT_TERMS'].str.contains(r'\brice\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\brice\b') |temp['ABSTRACT'].str.contains(r'\bRice\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bRice\b')| temp['PROJECT_TITLE'].str.contains(r'\bRice\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2006.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2006.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\brice\b') | temp['PROJECT_TERMS'].str.contains(r'\brice\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\brice\b') |temp['ABSTRACT'].str.contains(r'\bRice\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bRice\b')| temp['PROJECT_TITLE'].str.contains(r'\bRice\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2007.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2007.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\brice\b') | temp['PROJECT_TERMS'].str.contains(r'\brice\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\brice\b') |temp['ABSTRACT'].str.contains(r'\bRice\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bRice\b')| temp['PROJECT_TITLE'].str.contains(r'\bRice\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2008.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2008.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\brice\b') | temp['PROJECT_TERMS'].str.contains(r'\brice\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\brice\b') |temp['ABSTRACT'].str.contains(r'\bRice\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bRice\b')| temp['PROJECT_TITLE'].str.contains(r'\bRice\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2009.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2009.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\brice\b') | temp['PROJECT_TERMS'].str.contains(r'\brice\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\brice\b') |temp['ABSTRACT'].str.contains(r'\bRice\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bRice\b')| temp['PROJECT_TITLE'].str.contains(r'\bRice\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2010.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2010.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\brice\b') | temp['PROJECT_TERMS'].str.contains(r'\brice\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\brice\b') |temp['ABSTRACT'].str.contains(r'\bRice\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bRice\b')| temp['PROJECT_TITLE'].str.contains(r'\bRice\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2011.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2011.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\brice\b') | temp['PROJECT_TERMS'].str.contains(r'\brice\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\brice\b') |temp['ABSTRACT'].str.contains(r'\bRice\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bRice\b')| temp['PROJECT_TITLE'].str.contains(r'\bRice\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2012.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2012.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\brice\b') | temp['PROJECT_TERMS'].str.contains(r'\brice\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\brice\b') |temp['ABSTRACT'].str.contains(r'\bRice\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bRice\b')| temp['PROJECT_TITLE'].str.contains(r'\bRice\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2013.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2013.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\brice\b') | temp['PROJECT_TERMS'].str.contains(r'\brice\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\brice\b') |temp['ABSTRACT'].str.contains(r'\bRice\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bRice\b')| temp['PROJECT_TITLE'].str.contains(r'\bRice\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2014.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2014.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\brice\b') | temp['PROJECT_TERMS'].str.contains(r'\brice\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\brice\b') |temp['ABSTRACT'].str.contains(r'\bRice\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bRice\b')| temp['PROJECT_TITLE'].str.contains(r'\bRice\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2015.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2015.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\brice\b') | temp['PROJECT_TERMS'].str.contains(r'\brice\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\brice\b') |temp['ABSTRACT'].str.contains(r'\bRice\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bRice\b')| temp['PROJECT_TITLE'].str.contains(r'\bRice\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2016.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2016.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\brice\b') | temp['PROJECT_TERMS'].str.contains(r'\brice\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\brice\b') |temp['ABSTRACT'].str.contains(r'\bRice\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bRice\b')| temp['PROJECT_TITLE'].str.contains(r'\bRice\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2017.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2017.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\brice\b') | temp['PROJECT_TERMS'].str.contains(r'\brice\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\brice\b') |temp['ABSTRACT'].str.contains(r'\bRice\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bRice\b')| temp['PROJECT_TITLE'].str.contains(r'\bRice\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2018.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2018.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\brice\b') | temp['PROJECT_TERMS'].str.contains(r'\brice\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\brice\b') |temp['ABSTRACT'].str.contains(r'\bRice\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bRice\b')| temp['PROJECT_TITLE'].str.contains(r'\bRice\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2019.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2019.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\brice\b') | temp['PROJECT_TERMS'].str.contains(r'\brice\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\brice\b') |temp['ABSTRACT'].str.contains(r'\bRice\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bRice\b')| temp['PROJECT_TITLE'].str.contains(r'\bRice\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)
# Out:
# (668, 24) (0, 25)
# (340, 24) (0, 25)
# (351, 24) (2, 25)
# (310, 24) (3, 25)
# (641, 24) (9, 25)
# (618, 24) (16, 25)
# (640, 24) (22, 25)
# (598, 24) (24, 25)
# (104076, 24) (313, 25)
# (118557, 24) (664, 25)
# (111400, 24) (976, 25)
# (98064, 24) (1257, 25)
# (93367, 24) (1489, 25)
# (91637, 24) (1745, 25)
# (90944, 24) (1981, 25)
# (92265, 24) (2204, 25)
# (91126, 24) (2435, 25)
# b'Skipping line 87965: expected 24 fields, saw 25\nSkipping line 87967: expected 24 fields, saw 25\n'
# (88420, 24) (2625, 25)
# b'Skipping line 95568: expected 24 fields, saw 25\nSkipping line 95570: expected 24 fields, saw 25\n'
# (96209, 24) (2829, 25)
# b'Skipping line 74736: expected 24 fields, saw 25\nSkipping line 79976: expected 24 fields, saw 25\n'
# (80066, 24) (2967, 25)

# %%
df.AGENCY.unique()
# Out:
# array(['EPA', 'ARS', 'NSF', 'NASA', 'NIH', 'AHRQ', 'ALLCDC', 'NIFA',
#        'CDMRP', 'DVBIC', 'FDA', 'VA'], dtype=object)

# %%
df = df[df.AGENCY != 'NASA']
df = df[df.AGENCY != 'NIH']
df.shape
# Out:
# (1330, 25)

# %%
df.to_csv('rice.csv')

# %% [markdown]
# # Potato

# %%
df=pd.DataFrame()
df_abs=pd.read_csv('abstract/PRJABS_2000.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2000.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bpotato') | temp['PROJECT_TERMS'].str.contains(r'\bpotato')| 
           temp['PROJECT_TITLE'].str.contains(r'\bpotato') |temp['ABSTRACT'].str.contains(r'\bPotato') | 
           temp['PROJECT_TERMS'].str.contains(r'\bPotato')| temp['PROJECT_TITLE'].str.contains(r'\bPotato')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2001.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2001.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bpotato') | temp['PROJECT_TERMS'].str.contains(r'\bpotato')| 
           temp['PROJECT_TITLE'].str.contains(r'\bpotato') |temp['ABSTRACT'].str.contains(r'\bPotato') | 
           temp['PROJECT_TERMS'].str.contains(r'\bPotato')| temp['PROJECT_TITLE'].str.contains(r'\bPotato')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)


df_abs=pd.read_csv('abstract/PRJABS_2002.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2002.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bpotato') | temp['PROJECT_TERMS'].str.contains(r'\bpotato')| 
           temp['PROJECT_TITLE'].str.contains(r'\bpotato') |temp['ABSTRACT'].str.contains(r'\bPotato') | 
           temp['PROJECT_TERMS'].str.contains(r'\bPotato')| temp['PROJECT_TITLE'].str.contains(r'\bPotato')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)


df_abs=pd.read_csv('abstract/PRJABS_2003.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2003.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bpotato') | temp['PROJECT_TERMS'].str.contains(r'\bpotato')| 
           temp['PROJECT_TITLE'].str.contains(r'\bpotato') |temp['ABSTRACT'].str.contains(r'\bPotato') | 
           temp['PROJECT_TERMS'].str.contains(r'\bPotato')| temp['PROJECT_TITLE'].str.contains(r'\bPotato')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2004.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2004.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bpotato') | temp['PROJECT_TERMS'].str.contains(r'\bpotato')| 
           temp['PROJECT_TITLE'].str.contains(r'\bpotato') |temp['ABSTRACT'].str.contains(r'\bPotato') | 
           temp['PROJECT_TERMS'].str.contains(r'\bPotato')| temp['PROJECT_TITLE'].str.contains(r'\bPotato')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)


df_abs=pd.read_csv('abstract/PRJABS_2005.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2005.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bpotato') | temp['PROJECT_TERMS'].str.contains(r'\bpotato')| 
           temp['PROJECT_TITLE'].str.contains(r'\bpotato') |temp['ABSTRACT'].str.contains(r'\bPotato') | 
           temp['PROJECT_TERMS'].str.contains(r'\bPotato')| temp['PROJECT_TITLE'].str.contains(r'\bPotato')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2006.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2006.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bpotato') | temp['PROJECT_TERMS'].str.contains(r'\bpotato')| 
           temp['PROJECT_TITLE'].str.contains(r'\bpotato') |temp['ABSTRACT'].str.contains(r'\bPotato') | 
           temp['PROJECT_TERMS'].str.contains(r'\bPotato')| temp['PROJECT_TITLE'].str.contains(r'\bPotato')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2007.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2007.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bpotato') | temp['PROJECT_TERMS'].str.contains(r'\bpotato')| 
           temp['PROJECT_TITLE'].str.contains(r'\bpotato') |temp['ABSTRACT'].str.contains(r'\bPotato') | 
           temp['PROJECT_TERMS'].str.contains(r'\bPotato')| temp['PROJECT_TITLE'].str.contains(r'\bPotato')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2008.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2008.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bpotato') | temp['PROJECT_TERMS'].str.contains(r'\bpotato')| 
           temp['PROJECT_TITLE'].str.contains(r'\bpotato') |temp['ABSTRACT'].str.contains(r'\bPotato') | 
           temp['PROJECT_TERMS'].str.contains(r'\bPotato')| temp['PROJECT_TITLE'].str.contains(r'\bPotato')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2009.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2009.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bpotato') | temp['PROJECT_TERMS'].str.contains(r'\bpotato')| 
           temp['PROJECT_TITLE'].str.contains(r'\bpotato') |temp['ABSTRACT'].str.contains(r'\bPotato') | 
           temp['PROJECT_TERMS'].str.contains(r'\bPotato')| temp['PROJECT_TITLE'].str.contains(r'\bPotato')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2010.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2010.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bpotato') | temp['PROJECT_TERMS'].str.contains(r'\bpotato')| 
           temp['PROJECT_TITLE'].str.contains(r'\bpotato') |temp['ABSTRACT'].str.contains(r'\bPotato') | 
           temp['PROJECT_TERMS'].str.contains(r'\bPotato')| temp['PROJECT_TITLE'].str.contains(r'\bPotato')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2011.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2011.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bpotato') | temp['PROJECT_TERMS'].str.contains(r'\bpotato')| 
           temp['PROJECT_TITLE'].str.contains(r'\bpotato') |temp['ABSTRACT'].str.contains(r'\bPotato') | 
           temp['PROJECT_TERMS'].str.contains(r'\bPotato')| temp['PROJECT_TITLE'].str.contains(r'\bPotato')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2012.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2012.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bpotato') | temp['PROJECT_TERMS'].str.contains(r'\bpotato')| 
           temp['PROJECT_TITLE'].str.contains(r'\bpotato') |temp['ABSTRACT'].str.contains(r'\bPotato') | 
           temp['PROJECT_TERMS'].str.contains(r'\bPotato')| temp['PROJECT_TITLE'].str.contains(r'\bPotato')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2013.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2013.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bpotato') | temp['PROJECT_TERMS'].str.contains(r'\bpotato')| 
           temp['PROJECT_TITLE'].str.contains(r'\bpotato') |temp['ABSTRACT'].str.contains(r'\bPotato') | 
           temp['PROJECT_TERMS'].str.contains(r'\bPotato')| temp['PROJECT_TITLE'].str.contains(r'\bPotato')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2014.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2014.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bpotato') | temp['PROJECT_TERMS'].str.contains(r'\bpotato')| 
           temp['PROJECT_TITLE'].str.contains(r'\bpotato') |temp['ABSTRACT'].str.contains(r'\bPotato') | 
           temp['PROJECT_TERMS'].str.contains(r'\bPotato')| temp['PROJECT_TITLE'].str.contains(r'\bPotato')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2015.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2015.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bpotato') | temp['PROJECT_TERMS'].str.contains(r'\bpotato')| 
           temp['PROJECT_TITLE'].str.contains(r'\bpotato') |temp['ABSTRACT'].str.contains(r'\bPotato') | 
           temp['PROJECT_TERMS'].str.contains(r'\bPotato')| temp['PROJECT_TITLE'].str.contains(r'\bPotato')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2016.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2016.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bpotato') | temp['PROJECT_TERMS'].str.contains(r'\bpotato')| 
           temp['PROJECT_TITLE'].str.contains(r'\bpotato') |temp['ABSTRACT'].str.contains(r'\bPotato') | 
           temp['PROJECT_TERMS'].str.contains(r'\bPotato')| temp['PROJECT_TITLE'].str.contains(r'\bPotato')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2017.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2017.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bpotato') | temp['PROJECT_TERMS'].str.contains(r'\bpotato')| 
           temp['PROJECT_TITLE'].str.contains(r'\bpotato') |temp['ABSTRACT'].str.contains(r'\bPotato') | 
           temp['PROJECT_TERMS'].str.contains(r'\bPotato')| temp['PROJECT_TITLE'].str.contains(r'\bPotato')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2018.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2018.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bpotato') | temp['PROJECT_TERMS'].str.contains(r'\bpotato')| 
           temp['PROJECT_TITLE'].str.contains(r'\bpotato') |temp['ABSTRACT'].str.contains(r'\bPotato') | 
           temp['PROJECT_TERMS'].str.contains(r'\bPotato')| temp['PROJECT_TITLE'].str.contains(r'\bPotato')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2019.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2019.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bpotato') | temp['PROJECT_TERMS'].str.contains(r'\bpotato')| 
           temp['PROJECT_TITLE'].str.contains(r'\bpotato') |temp['ABSTRACT'].str.contains(r'\bPotato') | 
           temp['PROJECT_TERMS'].str.contains(r'\bPotato')| temp['PROJECT_TITLE'].str.contains(r'\bPotato')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)
# Out:
# (668, 24) (1, 25)
# (340, 24) (1, 25)
# (351, 24) (1, 25)
# (310, 24) (1, 25)
# (641, 24) (3, 25)
# (618, 24) (8, 25)
# (640, 24) (13, 25)
# (598, 24) (22, 25)
# (104076, 24) (98, 25)
# (118557, 24) (207, 25)
# (111400, 24) (293, 25)
# (98064, 24) (371, 25)
# (93367, 24) (421, 25)
# (91637, 24) (506, 25)
# (90944, 24) (574, 25)
# (92265, 24) (648, 25)
# (91126, 24) (727, 25)
# b'Skipping line 87965: expected 24 fields, saw 25\nSkipping line 87967: expected 24 fields, saw 25\n'
# (88420, 24) (767, 25)
# b'Skipping line 95568: expected 24 fields, saw 25\nSkipping line 95570: expected 24 fields, saw 25\n'
# (96209, 24) (817, 25)
# b'Skipping line 74736: expected 24 fields, saw 25\nSkipping line 79976: expected 24 fields, saw 25\n'
# (80066, 24) (863, 25)

# %%
df.AGENCY.unique()
# Out:
# array(['EPA', 'ARS', 'NSF', 'NIH', 'NIFA', 'FDA'], dtype=object)

# %%
df = df[df.AGENCY != 'NASA']
df = df[df.AGENCY != 'NIH']
df.shape
# Out:
# (736, 25)

# %%
df.to_csv('potato.csv')

# %% [markdown]
# # Millet

# %%
df=pd.DataFrame()
df_abs=pd.read_csv('abstract/PRJABS_2000.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2000.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bmillet\b') | temp['PROJECT_TERMS'].str.contains(r'\bmillet\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bmillet\b') |temp['ABSTRACT'].str.contains(r'\bMillet\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bMillet\b')| temp['PROJECT_TITLE'].str.contains(r'\bMillet\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2001.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2001.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bmillet\b') | temp['PROJECT_TERMS'].str.contains(r'\bmillet\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bmillet\b') |temp['ABSTRACT'].str.contains(r'\bMillet\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bMillet\b')| temp['PROJECT_TITLE'].str.contains(r'\bMillet\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)


df_abs=pd.read_csv('abstract/PRJABS_2002.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2002.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bmillet\b') | temp['PROJECT_TERMS'].str.contains(r'\bmillet\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bmillet\b') |temp['ABSTRACT'].str.contains(r'\bMillet\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bMillet\b')| temp['PROJECT_TITLE'].str.contains(r'\bMillet\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)


df_abs=pd.read_csv('abstract/PRJABS_2003.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2003.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bmillet\b') | temp['PROJECT_TERMS'].str.contains(r'\bmillet\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bmillet\b') |temp['ABSTRACT'].str.contains(r'\bMillet\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bMillet\b')| temp['PROJECT_TITLE'].str.contains(r'\bMillet\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2004.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2004.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bmillet\b') | temp['PROJECT_TERMS'].str.contains(r'\bmillet\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bmillet\b') |temp['ABSTRACT'].str.contains(r'\bMillet\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bMillet\b')| temp['PROJECT_TITLE'].str.contains(r'\bMillet\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)


df_abs=pd.read_csv('abstract/PRJABS_2005.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2005.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bmillet\b') | temp['PROJECT_TERMS'].str.contains(r'\bmillet\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bmillet\b') |temp['ABSTRACT'].str.contains(r'\bMillet\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bMillet\b')| temp['PROJECT_TITLE'].str.contains(r'\bMillet\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2006.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2006.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bmillet\b') | temp['PROJECT_TERMS'].str.contains(r'\bmillet\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bmillet\b') |temp['ABSTRACT'].str.contains(r'\bMillet\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bMillet\b')| temp['PROJECT_TITLE'].str.contains(r'\bMillet\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2007.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2007.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bmillet\b') | temp['PROJECT_TERMS'].str.contains(r'\bmillet\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bmillet\b') |temp['ABSTRACT'].str.contains(r'\bMillet\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bMillet\b')| temp['PROJECT_TITLE'].str.contains(r'\bMillet\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2008.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2008.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bmillet\b') | temp['PROJECT_TERMS'].str.contains(r'\bmillet\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bmillet\b') |temp['ABSTRACT'].str.contains(r'\bMillet\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bMillet\b')| temp['PROJECT_TITLE'].str.contains(r'\bMillet\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2009.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2009.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bmillet\b') | temp['PROJECT_TERMS'].str.contains(r'\bmillet\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bmillet\b') |temp['ABSTRACT'].str.contains(r'\bMillet\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bMillet\b')| temp['PROJECT_TITLE'].str.contains(r'\bMillet\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2010.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2010.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bmillet\b') | temp['PROJECT_TERMS'].str.contains(r'\bmillet\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bmillet\b') |temp['ABSTRACT'].str.contains(r'\bMillet\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bMillet\b')| temp['PROJECT_TITLE'].str.contains(r'\bMillet\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2011.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2011.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bmillet\b') | temp['PROJECT_TERMS'].str.contains(r'\bmillet\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bmillet\b') |temp['ABSTRACT'].str.contains(r'\bMillet\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bMillet\b')| temp['PROJECT_TITLE'].str.contains(r'\bMillet\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2012.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2012.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bmillet\b') | temp['PROJECT_TERMS'].str.contains(r'\bmillet\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bmillet\b') |temp['ABSTRACT'].str.contains(r'\bMillet\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bMillet\b')| temp['PROJECT_TITLE'].str.contains(r'\bMillet\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2013.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2013.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bmillet\b') | temp['PROJECT_TERMS'].str.contains(r'\bmillet\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bmillet\b') |temp['ABSTRACT'].str.contains(r'\bMillet\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bMillet\b')| temp['PROJECT_TITLE'].str.contains(r'\bMillet\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2014.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2014.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bmillet\b') | temp['PROJECT_TERMS'].str.contains(r'\bmillet\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bmillet\b') |temp['ABSTRACT'].str.contains(r'\bMillet\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bMillet\b')| temp['PROJECT_TITLE'].str.contains(r'\bMillet\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2015.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2015.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bmillet\b') | temp['PROJECT_TERMS'].str.contains(r'\bmillet\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bmillet\b') |temp['ABSTRACT'].str.contains(r'\bMillet\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bMillet\b')| temp['PROJECT_TITLE'].str.contains(r'\bMillet\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2016.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2016.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bmillet\b') | temp['PROJECT_TERMS'].str.contains(r'\bmillet\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bmillet\b') |temp['ABSTRACT'].str.contains(r'\bMillet\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bMillet\b')| temp['PROJECT_TITLE'].str.contains(r'\bMillet\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2017.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2017.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bmillet\b') | temp['PROJECT_TERMS'].str.contains(r'\bmillet\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bmillet\b') |temp['ABSTRACT'].str.contains(r'\bMillet\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bMillet\b')| temp['PROJECT_TITLE'].str.contains(r'\bMillet\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2018.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2018.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bmillet\b') | temp['PROJECT_TERMS'].str.contains(r'\bmillet\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bmillet\b') |temp['ABSTRACT'].str.contains(r'\bMillet\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bMillet\b')| temp['PROJECT_TITLE'].str.contains(r'\bMillet\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2019.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2019.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bmillet\b') | temp['PROJECT_TERMS'].str.contains(r'\bmillet\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bmillet\b') |temp['ABSTRACT'].str.contains(r'\bMillet\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bMillet\b')| temp['PROJECT_TITLE'].str.contains(r'\bMillet\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)
# Out:
# (668, 24) (0, 25)
# (340, 24) (0, 25)
# (351, 24) (0, 25)
# (310, 24) (0, 25)
# (641, 24) (0, 25)
# (618, 24) (1, 25)
# (640, 24) (1, 25)
# (598, 24) (2, 25)
# (104076, 24) (12, 25)
# (118557, 24) (20, 25)
# (111400, 24) (28, 25)
# (98064, 24) (31, 25)
# (93367, 24) (37, 25)
# (91637, 24) (44, 25)
# (90944, 24) (52, 25)
# (92265, 24) (59, 25)
# (91126, 24) (67, 25)
# b'Skipping line 87965: expected 24 fields, saw 25\nSkipping line 87967: expected 24 fields, saw 25\n'
# (88420, 24) (74, 25)
# b'Skipping line 95568: expected 24 fields, saw 25\nSkipping line 95570: expected 24 fields, saw 25\n'
# (96209, 24) (81, 25)
# b'Skipping line 74736: expected 24 fields, saw 25\nSkipping line 79976: expected 24 fields, saw 25\n'
# (80066, 24) (88, 25)

# %%
df.AGENCY.unique()
# Out:
# array(['ARS', 'NSF', 'NIH', 'NIFA'], dtype=object)

# %%
df = df[df.AGENCY != 'NASA']
df = df[df.AGENCY != 'NIH']
df.shape
# Out:
# (58, 25)

# %%
df.to_csv('millet.csv')

# %% [markdown]
# # Sorghum

# %%
df=pd.DataFrame()
df_abs=pd.read_csv('abstract/PRJABS_2000.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2000.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bsorghum\b') | temp['PROJECT_TERMS'].str.contains(r'\bsorghum\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bsorghum\b') |temp['ABSTRACT'].str.contains(r'\bSorghum\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bSorghum\b')| temp['PROJECT_TITLE'].str.contains(r'\bSorghum\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)


df_abs=pd.read_csv('abstract/PRJABS_2001.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2001.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bsorghum\b') | temp['PROJECT_TERMS'].str.contains(r'\bsorghum\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bsorghum\b') |temp['ABSTRACT'].str.contains(r'\bSorghum\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bSorghum\b')| temp['PROJECT_TITLE'].str.contains(r'\bSorghum\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)


df_abs=pd.read_csv('abstract/PRJABS_2002.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2002.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bsorghum\b') | temp['PROJECT_TERMS'].str.contains(r'\bsorghum\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bsorghum\b') |temp['ABSTRACT'].str.contains(r'\bSorghum\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bSorghum\b')| temp['PROJECT_TITLE'].str.contains(r'\bSorghum\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)


df_abs=pd.read_csv('abstract/PRJABS_2003.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2003.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bsorghum\b') | temp['PROJECT_TERMS'].str.contains(r'\bsorghum\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bsorghum\b') |temp['ABSTRACT'].str.contains(r'\bSorghum\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bSorghum\b')| temp['PROJECT_TITLE'].str.contains(r'\bSorghum\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)


df_abs=pd.read_csv('abstract/PRJABS_2004.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2004.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bsorghum\b') | temp['PROJECT_TERMS'].str.contains(r'\bsorghum\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bsorghum\b') |temp['ABSTRACT'].str.contains(r'\bSorghum\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bSorghum\b')| temp['PROJECT_TITLE'].str.contains(r'\bSorghum\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)


df_abs=pd.read_csv('abstract/PRJABS_2005.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2005.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bsorghum\b') | temp['PROJECT_TERMS'].str.contains(r'\bsorghum\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bsorghum\b') |temp['ABSTRACT'].str.contains(r'\bSorghum\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bSorghum\b')| temp['PROJECT_TITLE'].str.contains(r'\bSorghum\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2006.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2006.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bsorghum\b') | temp['PROJECT_TERMS'].str.contains(r'\bsorghum\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bsorghum\b') |temp['ABSTRACT'].str.contains(r'\bSorghum\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bSorghum\b')| temp['PROJECT_TITLE'].str.contains(r'\bSorghum\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)


df_abs=pd.read_csv('abstract/PRJABS_2007.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2007.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bsorghum\b') | temp['PROJECT_TERMS'].str.contains(r'\bsorghum\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bsorghum\b') |temp['ABSTRACT'].str.contains(r'\bSorghum\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bSorghum\b')| temp['PROJECT_TITLE'].str.contains(r'\bSorghum\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)


df_abs=pd.read_csv('abstract/PRJABS_2008.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2008.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bsorghum\b') | temp['PROJECT_TERMS'].str.contains(r'\bsorghum\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bsorghum\b') |temp['ABSTRACT'].str.contains(r'\bSorghum\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bSorghum\b')| temp['PROJECT_TITLE'].str.contains(r'\bSorghum\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)


df_abs=pd.read_csv('abstract/PRJABS_2009.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2009.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bsorghum\b') | temp['PROJECT_TERMS'].str.contains(r'\bsorghum\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bsorghum\b') |temp['ABSTRACT'].str.contains(r'\bSorghum\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bSorghum\b')| temp['PROJECT_TITLE'].str.contains(r'\bSorghum\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)


df_abs=pd.read_csv('abstract/PRJABS_2010.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2010.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bsorghum\b') | temp['PROJECT_TERMS'].str.contains(r'\bsorghum\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bsorghum\b') |temp['ABSTRACT'].str.contains(r'\bSorghum\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bSorghum\b')| temp['PROJECT_TITLE'].str.contains(r'\bSorghum\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)


df_abs=pd.read_csv('abstract/PRJABS_2011.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2011.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bsorghum\b') | temp['PROJECT_TERMS'].str.contains(r'\bsorghum\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bsorghum\b') |temp['ABSTRACT'].str.contains(r'\bSorghum\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bSorghum\b')| temp['PROJECT_TITLE'].str.contains(r'\bSorghum\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)


df_abs=pd.read_csv('abstract/PRJABS_2012.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2012.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bsorghum\b') | temp['PROJECT_TERMS'].str.contains(r'\bsorghum\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bsorghum\b') |temp['ABSTRACT'].str.contains(r'\bSorghum\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bSorghum\b')| temp['PROJECT_TITLE'].str.contains(r'\bSorghum\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)


df_abs=pd.read_csv('abstract/PRJABS_2013.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2013.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bsorghum\b') | temp['PROJECT_TERMS'].str.contains(r'\bsorghum\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bsorghum\b') |temp['ABSTRACT'].str.contains(r'\bSorghum\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bSorghum\b')| temp['PROJECT_TITLE'].str.contains(r'\bSorghum\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)


df_abs=pd.read_csv('abstract/PRJABS_2014.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2014.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bsorghum\b') | temp['PROJECT_TERMS'].str.contains(r'\bsorghum\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bsorghum\b') |temp['ABSTRACT'].str.contains(r'\bSorghum\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bSorghum\b')| temp['PROJECT_TITLE'].str.contains(r'\bSorghum\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)


df_abs=pd.read_csv('abstract/PRJABS_2015.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2015.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bsorghum\b') | temp['PROJECT_TERMS'].str.contains(r'\bsorghum\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bsorghum\b') |temp['ABSTRACT'].str.contains(r'\bSorghum\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bSorghum\b')| temp['PROJECT_TITLE'].str.contains(r'\bSorghum\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)


df_abs=pd.read_csv('abstract/PRJABS_2016.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2016.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bsorghum\b') | temp['PROJECT_TERMS'].str.contains(r'\bsorghum\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bsorghum\b') |temp['ABSTRACT'].str.contains(r'\bSorghum\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bSorghum\b')| temp['PROJECT_TITLE'].str.contains(r'\bSorghum\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)


df_abs=pd.read_csv('abstract/PRJABS_2017.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2017.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bsorghum\b') | temp['PROJECT_TERMS'].str.contains(r'\bsorghum\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bsorghum\b') |temp['ABSTRACT'].str.contains(r'\bSorghum\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bSorghum\b')| temp['PROJECT_TITLE'].str.contains(r'\bSorghum\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)


df_abs=pd.read_csv('abstract/PRJABS_2018.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2018.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bsorghum\b') | temp['PROJECT_TERMS'].str.contains(r'\bsorghum\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bsorghum\b') |temp['ABSTRACT'].str.contains(r'\bSorghum\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bSorghum\b')| temp['PROJECT_TITLE'].str.contains(r'\bSorghum\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)


df_abs=pd.read_csv('abstract/PRJABS_2019.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2019.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bsorghum\b') | temp['PROJECT_TERMS'].str.contains(r'\bsorghum\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bsorghum\b') |temp['ABSTRACT'].str.contains(r'\bSorghum\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bSorghum\b')| temp['PROJECT_TITLE'].str.contains(r'\bSorghum\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)
# Out:
# (668, 24) (0, 25)
# (340, 24) (0, 25)
# (351, 24) (0, 25)
# (310, 24) (0, 25)
# (641, 24) (2, 25)
# (618, 24) (8, 25)
# (640, 24) (12, 25)
# (598, 24) (15, 25)
# (104076, 24) (54, 25)
# (118557, 24) (91, 25)
# (111400, 24) (146, 25)
# (98064, 24) (182, 25)
# (93367, 24) (212, 25)
# (91637, 24) (263, 25)
# (90944, 24) (299, 25)
# (92265, 24) (351, 25)
# (91126, 24) (387, 25)
# b'Skipping line 87965: expected 24 fields, saw 25\nSkipping line 87967: expected 24 fields, saw 25\n'
# (88420, 24) (422, 25)
# b'Skipping line 95568: expected 24 fields, saw 25\nSkipping line 95570: expected 24 fields, saw 25\n'
# (96209, 24) (475, 25)
# b'Skipping line 74736: expected 24 fields, saw 25\nSkipping line 79976: expected 24 fields, saw 25\n'
# (80066, 24) (525, 25)

# %%
df.AGENCY.unique()
# Out:
# array(['ARS', 'EPA', 'NSF', 'NIH', 'NIFA', 'FDA'], dtype=object)

# %%
df = df[df.AGENCY != 'NASA']
df = df[df.AGENCY != 'NIH']
df.shape
# Out:
# (495, 25)

# %%
df.to_csv('sorghum.csv')

# %% [markdown]
# # Barley

# %%
df=pd.DataFrame()
df_abs=pd.read_csv('abstract/PRJABS_2000.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2000.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bbarley\b') | temp['PROJECT_TERMS'].str.contains(r'\bbarley\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bbarley\b') |temp['ABSTRACT'].str.contains(r'\bBarley\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bBarley\b')| temp['PROJECT_TITLE'].str.contains(r'\bBarley\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)


df_abs=pd.read_csv('abstract/PRJABS_2001.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2001.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bbarley\b') | temp['PROJECT_TERMS'].str.contains(r'\bbarley\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bbarley\b') |temp['ABSTRACT'].str.contains(r'\bBarley\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bBarley\b')| temp['PROJECT_TITLE'].str.contains(r'\bBarley\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)


df_abs=pd.read_csv('abstract/PRJABS_2002.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2002.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bbarley\b') | temp['PROJECT_TERMS'].str.contains(r'\bbarley\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bbarley\b') |temp['ABSTRACT'].str.contains(r'\bBarley\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bBarley\b')| temp['PROJECT_TITLE'].str.contains(r'\bBarley\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)


df_abs=pd.read_csv('abstract/PRJABS_2003.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2003.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bbarley\b') | temp['PROJECT_TERMS'].str.contains(r'\bbarley\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bbarley\b') |temp['ABSTRACT'].str.contains(r'\bBarley\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bBarley\b')| temp['PROJECT_TITLE'].str.contains(r'\bBarley\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)


df_abs=pd.read_csv('abstract/PRJABS_2004.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2004.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bbarley\b') | temp['PROJECT_TERMS'].str.contains(r'\bbarley\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bbarley\b') |temp['ABSTRACT'].str.contains(r'\bBarley\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bBarley\b')| temp['PROJECT_TITLE'].str.contains(r'\bBarley\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)


df_abs=pd.read_csv('abstract/PRJABS_2005.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2005.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bbarley\b') | temp['PROJECT_TERMS'].str.contains(r'\bbarley\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bbarley\b') |temp['ABSTRACT'].str.contains(r'\bBarley\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bBarley\b')| temp['PROJECT_TITLE'].str.contains(r'\bBarley\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2006.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2006.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bbarley\b') | temp['PROJECT_TERMS'].str.contains(r'\bbarley\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bbarley\b') |temp['ABSTRACT'].str.contains(r'\bBarley\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bBarley\b')| temp['PROJECT_TITLE'].str.contains(r'\bBarley\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2007.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2007.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bbarley\b') | temp['PROJECT_TERMS'].str.contains(r'\bbarley\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bbarley\b') |temp['ABSTRACT'].str.contains(r'\bBarley\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bBarley\b')| temp['PROJECT_TITLE'].str.contains(r'\bBarley\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)


df_abs=pd.read_csv('abstract/PRJABS_2008.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2008.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bbarley\b') | temp['PROJECT_TERMS'].str.contains(r'\bbarley\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bbarley\b') |temp['ABSTRACT'].str.contains(r'\bBarley\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bBarley\b')| temp['PROJECT_TITLE'].str.contains(r'\bBarley\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)


df_abs=pd.read_csv('abstract/PRJABS_2009.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2009.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bbarley\b') | temp['PROJECT_TERMS'].str.contains(r'\bbarley\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bbarley\b') |temp['ABSTRACT'].str.contains(r'\bBarley\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bBarley\b')| temp['PROJECT_TITLE'].str.contains(r'\bBarley\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)


df_abs=pd.read_csv('abstract/PRJABS_2010.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2010.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bbarley\b') | temp['PROJECT_TERMS'].str.contains(r'\bbarley\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bbarley\b') |temp['ABSTRACT'].str.contains(r'\bBarley\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bBarley\b')| temp['PROJECT_TITLE'].str.contains(r'\bBarley\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)


df_abs=pd.read_csv('abstract/PRJABS_2011.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2011.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bbarley\b') | temp['PROJECT_TERMS'].str.contains(r'\bbarley\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bbarley\b') |temp['ABSTRACT'].str.contains(r'\bBarley\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bBarley\b')| temp['PROJECT_TITLE'].str.contains(r'\bBarley\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)


df_abs=pd.read_csv('abstract/PRJABS_2012.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2012.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bbarley\b') | temp['PROJECT_TERMS'].str.contains(r'\bbarley\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bbarley\b') |temp['ABSTRACT'].str.contains(r'\bBarley\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bBarley\b')| temp['PROJECT_TITLE'].str.contains(r'\bBarley\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2013.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2013.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bbarley\b') | temp['PROJECT_TERMS'].str.contains(r'\bbarley\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bbarley\b') |temp['ABSTRACT'].str.contains(r'\bBarley\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bBarley\b')| temp['PROJECT_TITLE'].str.contains(r'\bBarley\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)


df_abs=pd.read_csv('abstract/PRJABS_2014.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2014.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bbarley\b') | temp['PROJECT_TERMS'].str.contains(r'\bbarley\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bbarley\b') |temp['ABSTRACT'].str.contains(r'\bBarley\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bBarley\b')| temp['PROJECT_TITLE'].str.contains(r'\bBarley\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)


df_abs=pd.read_csv('abstract/PRJABS_2015.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2015.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bbarley\b') | temp['PROJECT_TERMS'].str.contains(r'\bbarley\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bbarley\b') |temp['ABSTRACT'].str.contains(r'\bBarley\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bBarley\b')| temp['PROJECT_TITLE'].str.contains(r'\bBarley\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2016.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2016.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bbarley\b') | temp['PROJECT_TERMS'].str.contains(r'\bbarley\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bbarley\b') |temp['ABSTRACT'].str.contains(r'\bBarley\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bBarley\b')| temp['PROJECT_TITLE'].str.contains(r'\bBarley\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2017.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2017.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bbarley\b') | temp['PROJECT_TERMS'].str.contains(r'\bbarley\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bbarley\b') |temp['ABSTRACT'].str.contains(r'\bBarley\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bBarley\b')| temp['PROJECT_TITLE'].str.contains(r'\bBarley\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)


df_abs=pd.read_csv('abstract/PRJABS_2018.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2018.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bbarley\b') | temp['PROJECT_TERMS'].str.contains(r'\bbarley\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bbarley\b') |temp['ABSTRACT'].str.contains(r'\bBarley\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bBarley\b')| temp['PROJECT_TITLE'].str.contains(r'\bBarley\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)


df_abs=pd.read_csv('abstract/PRJABS_2019.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2019.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bbarley\b') | temp['PROJECT_TERMS'].str.contains(r'\bbarley\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bbarley\b') |temp['ABSTRACT'].str.contains(r'\bBarley\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bBarley\b')| temp['PROJECT_TITLE'].str.contains(r'\bBarley\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)
# Out:
# (668, 24) (0, 25)
# (340, 24) (0, 25)
# (351, 24) (0, 25)
# (310, 24) (0, 25)
# (641, 24) (1, 25)
# (618, 24) (7, 25)
# (640, 24) (15, 25)
# (598, 24) (25, 25)
# (104076, 24) (65, 25)
# (118557, 24) (129, 25)
# (111400, 24) (189, 25)
# (98064, 24) (233, 25)
# (93367, 24) (267, 25)
# (91637, 24) (318, 25)
# (90944, 24) (348, 25)
# (92265, 24) (399, 25)
# (91126, 24) (437, 25)
# b'Skipping line 87965: expected 24 fields, saw 25\nSkipping line 87967: expected 24 fields, saw 25\n'
# (88420, 24) (487, 25)
# b'Skipping line 95568: expected 24 fields, saw 25\nSkipping line 95570: expected 24 fields, saw 25\n'
# (96209, 24) (546, 25)
# b'Skipping line 74736: expected 24 fields, saw 25\nSkipping line 79976: expected 24 fields, saw 25\n'
# (80066, 24) (603, 25)

# %%
df.AGENCY.unique()
# Out:
# array(['ARS', 'NSF', 'NIH', 'NIFA', 'FDA'], dtype=object)

# %%
df = df[df.AGENCY != 'NASA']
df = df[df.AGENCY != 'NIH']
df.shape
# Out:
# (497, 25)

# %%
df.to_csv('barley.csv')

# %% [markdown]
# # Quinoa

# %%
df=pd.DataFrame()
df_abs=pd.read_csv('abstract/PRJABS_2000.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2000.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bquinoa\b') | temp['PROJECT_TERMS'].str.contains(r'\bquinoa\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bquinoa\b') |temp['ABSTRACT'].str.contains(r'\bQuinoa\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bQuinoa\b')| temp['PROJECT_TITLE'].str.contains(r'\bQuinoa\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)


df_abs=pd.read_csv('abstract/PRJABS_2001.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2001.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bquinoa\b') | temp['PROJECT_TERMS'].str.contains(r'\bquinoa\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bquinoa\b') |temp['ABSTRACT'].str.contains(r'\bQuinoa\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bQuinoa\b')| temp['PROJECT_TITLE'].str.contains(r'\bQuinoa\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)


df_abs=pd.read_csv('abstract/PRJABS_2002.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2002.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bquinoa\b') | temp['PROJECT_TERMS'].str.contains(r'\bquinoa\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bquinoa\b') |temp['ABSTRACT'].str.contains(r'\bQuinoa\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bQuinoa\b')| temp['PROJECT_TITLE'].str.contains(r'\bQuinoa\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)


df_abs=pd.read_csv('abstract/PRJABS_2003.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2003.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bquinoa\b') | temp['PROJECT_TERMS'].str.contains(r'\bquinoa\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bquinoa\b') |temp['ABSTRACT'].str.contains(r'\bQuinoa\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bQuinoa\b')| temp['PROJECT_TITLE'].str.contains(r'\bQuinoa\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)


df_abs=pd.read_csv('abstract/PRJABS_2004.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2004.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bquinoa\b') | temp['PROJECT_TERMS'].str.contains(r'\bquinoa\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bquinoa\b') |temp['ABSTRACT'].str.contains(r'\bQuinoa\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bQuinoa\b')| temp['PROJECT_TITLE'].str.contains(r'\bQuinoa\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)


df_abs=pd.read_csv('abstract/PRJABS_2005.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2005.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bquinoa\b') | temp['PROJECT_TERMS'].str.contains(r'\bquinoa\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bquinoa\b') |temp['ABSTRACT'].str.contains(r'\bQuinoa\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bQuinoa\b')| temp['PROJECT_TITLE'].str.contains(r'\bQuinoa\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2006.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2006.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bquinoa\b') | temp['PROJECT_TERMS'].str.contains(r'\bquinoa\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bquinoa\b') |temp['ABSTRACT'].str.contains(r'\bQuinoa\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bQuinoa\b')| temp['PROJECT_TITLE'].str.contains(r'\bQuinoa\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2007.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2007.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bquinoa\b') | temp['PROJECT_TERMS'].str.contains(r'\bquinoa\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bquinoa\b') |temp['ABSTRACT'].str.contains(r'\bQuinoa\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bQuinoa\b')| temp['PROJECT_TITLE'].str.contains(r'\bQuinoa\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)


df_abs=pd.read_csv('abstract/PRJABS_2008.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2008.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bquinoa\b') | temp['PROJECT_TERMS'].str.contains(r'\bquinoa\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bquinoa\b') |temp['ABSTRACT'].str.contains(r'\bQuinoa\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bQuinoa\b')| temp['PROJECT_TITLE'].str.contains(r'\bQuinoa\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)


df_abs=pd.read_csv('abstract/PRJABS_2009.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2009.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bquinoa\b') | temp['PROJECT_TERMS'].str.contains(r'\bquinoa\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bquinoa\b') |temp['ABSTRACT'].str.contains(r'\bQuinoa\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bQuinoa\b')| temp['PROJECT_TITLE'].str.contains(r'\bQuinoa\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)


df_abs=pd.read_csv('abstract/PRJABS_2010.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2010.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bquinoa\b') | temp['PROJECT_TERMS'].str.contains(r'\bquinoa\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bquinoa\b') |temp['ABSTRACT'].str.contains(r'\bQuinoa\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bQuinoa\b')| temp['PROJECT_TITLE'].str.contains(r'\bQuinoa\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)


df_abs=pd.read_csv('abstract/PRJABS_2011.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2011.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bquinoa\b') | temp['PROJECT_TERMS'].str.contains(r'\bquinoa\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bquinoa\b') |temp['ABSTRACT'].str.contains(r'\bQuinoa\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bQuinoa\b')| temp['PROJECT_TITLE'].str.contains(r'\bQuinoa\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)


df_abs=pd.read_csv('abstract/PRJABS_2012.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2012.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bquinoa\b') | temp['PROJECT_TERMS'].str.contains(r'\bquinoa\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bquinoa\b') |temp['ABSTRACT'].str.contains(r'\bQuinoa\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bQuinoa\b')| temp['PROJECT_TITLE'].str.contains(r'\bQuinoa\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2013.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2013.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bquinoa\b') | temp['PROJECT_TERMS'].str.contains(r'\bquinoa\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bquinoa\b') |temp['ABSTRACT'].str.contains(r'\bQuinoa\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bQuinoa\b')| temp['PROJECT_TITLE'].str.contains(r'\bQuinoa\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)


df_abs=pd.read_csv('abstract/PRJABS_2014.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2014.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bquinoa\b') | temp['PROJECT_TERMS'].str.contains(r'\bquinoa\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bquinoa\b') |temp['ABSTRACT'].str.contains(r'\bQuinoa\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bQuinoa\b')| temp['PROJECT_TITLE'].str.contains(r'\bQuinoa\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)


df_abs=pd.read_csv('abstract/PRJABS_2015.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2015.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bquinoa\b') | temp['PROJECT_TERMS'].str.contains(r'\bquinoa\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bquinoa\b') |temp['ABSTRACT'].str.contains(r'\bQuinoa\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bQuinoa\b')| temp['PROJECT_TITLE'].str.contains(r'\bQuinoa\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2016.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2016.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bquinoa\b') | temp['PROJECT_TERMS'].str.contains(r'\bquinoa\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bquinoa\b') |temp['ABSTRACT'].str.contains(r'\bQuinoa\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bQuinoa\b')| temp['PROJECT_TITLE'].str.contains(r'\bQuinoa\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2017.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2017.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bquinoa\b') | temp['PROJECT_TERMS'].str.contains(r'\bquinoa\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bquinoa\b') |temp['ABSTRACT'].str.contains(r'\bQuinoa\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bQuinoa\b')| temp['PROJECT_TITLE'].str.contains(r'\bQuinoa\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)


df_abs=pd.read_csv('abstract/PRJABS_2018.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2018.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bquinoa\b') | temp['PROJECT_TERMS'].str.contains(r'\bquinoa\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bquinoa\b') |temp['ABSTRACT'].str.contains(r'\bQuinoa\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bQuinoa\b')| temp['PROJECT_TITLE'].str.contains(r'\bQuinoa\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)


df_abs=pd.read_csv('abstract/PRJABS_2019.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2019.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\bquinoa\b') | temp['PROJECT_TERMS'].str.contains(r'\bquinoa\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\bquinoa\b') |temp['ABSTRACT'].str.contains(r'\bQuinoa\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bQuinoa\b')| temp['PROJECT_TITLE'].str.contains(r'\bQuinoa\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)
# Out:
# (668, 24) (0, 25)
# (340, 24) (0, 25)
# (351, 24) (0, 25)
# (310, 24) (0, 25)
# (641, 24) (0, 25)
# (618, 24) (0, 25)
# (640, 24) (0, 25)
# (598, 24) (0, 25)
# (104076, 24) (1, 25)
# (118557, 24) (2, 25)
# (111400, 24) (2, 25)
# (98064, 24) (4, 25)
# (93367, 24) (5, 25)
# (91637, 24) (5, 25)
# (90944, 24) (8, 25)
# (92265, 24) (8, 25)
# (91126, 24) (10, 25)
# b'Skipping line 87965: expected 24 fields, saw 25\nSkipping line 87967: expected 24 fields, saw 25\n'
# (88420, 24) (11, 25)
# b'Skipping line 95568: expected 24 fields, saw 25\nSkipping line 95570: expected 24 fields, saw 25\n'
# (96209, 24) (15, 25)
# b'Skipping line 74736: expected 24 fields, saw 25\nSkipping line 79976: expected 24 fields, saw 25\n'
# (80066, 24) (15, 25)

# %%
df.AGENCY.unique()
# Out:
# array(['NIFA', 'NSF', 'ARS'], dtype=object)

# %%
df = df[df.AGENCY != 'NASA']
df = df[df.AGENCY != 'NIH']
df.shape
# Out:
# (15, 25)

# %%
df.to_csv('quinoa.csv')

# %% [markdown]
# # Oat*

# %%
df=pd.DataFrame()
df_abs=pd.read_csv('abstract/PRJABS_2000.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2000.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\boat') | temp['PROJECT_TERMS'].str.contains(r'\boat')| 
           temp['PROJECT_TITLE'].str.contains(r'\boat') |temp['ABSTRACT'].str.contains(r'\bOat') | 
           temp['PROJECT_TERMS'].str.contains(r'\bOat')| temp['PROJECT_TITLE'].str.contains(r'\bOat')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)


df_abs=pd.read_csv('abstract/PRJABS_2001.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2001.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\boat') | temp['PROJECT_TERMS'].str.contains(r'\boat')| 
           temp['PROJECT_TITLE'].str.contains(r'\boat') |temp['ABSTRACT'].str.contains(r'\bOat') | 
           temp['PROJECT_TERMS'].str.contains(r'\bOat')| temp['PROJECT_TITLE'].str.contains(r'\bOat')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)


df_abs=pd.read_csv('abstract/PRJABS_2002.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2002.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\boat') | temp['PROJECT_TERMS'].str.contains(r'\boat')| 
           temp['PROJECT_TITLE'].str.contains(r'\boat') |temp['ABSTRACT'].str.contains(r'\bOat') | 
           temp['PROJECT_TERMS'].str.contains(r'\bOat')| temp['PROJECT_TITLE'].str.contains(r'\bOat')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)


df_abs=pd.read_csv('abstract/PRJABS_2003.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2003.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\boat') | temp['PROJECT_TERMS'].str.contains(r'\boat')| 
           temp['PROJECT_TITLE'].str.contains(r'\boat') |temp['ABSTRACT'].str.contains(r'\bOat') | 
           temp['PROJECT_TERMS'].str.contains(r'\bOat')| temp['PROJECT_TITLE'].str.contains(r'\bOat')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)


df_abs=pd.read_csv('abstract/PRJABS_2004.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2004.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\boat') | temp['PROJECT_TERMS'].str.contains(r'\boat')| 
           temp['PROJECT_TITLE'].str.contains(r'\boat') |temp['ABSTRACT'].str.contains(r'\bOat') | 
           temp['PROJECT_TERMS'].str.contains(r'\bOat')| temp['PROJECT_TITLE'].str.contains(r'\bOat')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)


df_abs=pd.read_csv('abstract/PRJABS_2005.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2005.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\boat') | temp['PROJECT_TERMS'].str.contains(r'\boat')| 
           temp['PROJECT_TITLE'].str.contains(r'\boat') |temp['ABSTRACT'].str.contains(r'\bOat') | 
           temp['PROJECT_TERMS'].str.contains(r'\bOat')| temp['PROJECT_TITLE'].str.contains(r'\bOat')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2006.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2006.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\boat') | temp['PROJECT_TERMS'].str.contains(r'\boat')| 
           temp['PROJECT_TITLE'].str.contains(r'\boat') |temp['ABSTRACT'].str.contains(r'\bOat') | 
           temp['PROJECT_TERMS'].str.contains(r'\bOat')| temp['PROJECT_TITLE'].str.contains(r'\bOat')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2007.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2007.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\boat') | temp['PROJECT_TERMS'].str.contains(r'\boat')| 
           temp['PROJECT_TITLE'].str.contains(r'\boat') |temp['ABSTRACT'].str.contains(r'\bOat') | 
           temp['PROJECT_TERMS'].str.contains(r'\bOat')| temp['PROJECT_TITLE'].str.contains(r'\bOat')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2008.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2008.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\boat') | temp['PROJECT_TERMS'].str.contains(r'\boat')| 
           temp['PROJECT_TITLE'].str.contains(r'\boat') |temp['ABSTRACT'].str.contains(r'\bOat') | 
           temp['PROJECT_TERMS'].str.contains(r'\bOat')| temp['PROJECT_TITLE'].str.contains(r'\bOat')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)


df_abs=pd.read_csv('abstract/PRJABS_2009.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2009.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\boat') | temp['PROJECT_TERMS'].str.contains(r'\boat')| 
           temp['PROJECT_TITLE'].str.contains(r'\boat') |temp['ABSTRACT'].str.contains(r'\bOat') | 
           temp['PROJECT_TERMS'].str.contains(r'\bOat')| temp['PROJECT_TITLE'].str.contains(r'\bOat')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)


df_abs=pd.read_csv('abstract/PRJABS_2010.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2010.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\boat') | temp['PROJECT_TERMS'].str.contains(r'\boat')| 
           temp['PROJECT_TITLE'].str.contains(r'\boat') |temp['ABSTRACT'].str.contains(r'\bOat') | 
           temp['PROJECT_TERMS'].str.contains(r'\bOat')| temp['PROJECT_TITLE'].str.contains(r'\bOat')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)


df_abs=pd.read_csv('abstract/PRJABS_2011.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2011.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\boat') | temp['PROJECT_TERMS'].str.contains(r'\boat')| 
           temp['PROJECT_TITLE'].str.contains(r'\boat') |temp['ABSTRACT'].str.contains(r'\bOat') | 
           temp['PROJECT_TERMS'].str.contains(r'\bOat')| temp['PROJECT_TITLE'].str.contains(r'\bOat')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)


df_abs=pd.read_csv('abstract/PRJABS_2012.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2012.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\boat') | temp['PROJECT_TERMS'].str.contains(r'\boat')| 
           temp['PROJECT_TITLE'].str.contains(r'\boat') |temp['ABSTRACT'].str.contains(r'\bOat') | 
           temp['PROJECT_TERMS'].str.contains(r'\bOat')| temp['PROJECT_TITLE'].str.contains(r'\bOat')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2013.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2013.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\boat') | temp['PROJECT_TERMS'].str.contains(r'\boat')| 
           temp['PROJECT_TITLE'].str.contains(r'\boat') |temp['ABSTRACT'].str.contains(r'\bOat') | 
           temp['PROJECT_TERMS'].str.contains(r'\bOat')| temp['PROJECT_TITLE'].str.contains(r'\bOat')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)


df_abs=pd.read_csv('abstract/PRJABS_2014.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2014.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\boat') | temp['PROJECT_TERMS'].str.contains(r'\boat')| 
           temp['PROJECT_TITLE'].str.contains(r'\boat') |temp['ABSTRACT'].str.contains(r'\bOat') | 
           temp['PROJECT_TERMS'].str.contains(r'\bOat')| temp['PROJECT_TITLE'].str.contains(r'\bOat')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2015.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2015.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\boat') | temp['PROJECT_TERMS'].str.contains(r'\boat')| 
           temp['PROJECT_TITLE'].str.contains(r'\boat') |temp['ABSTRACT'].str.contains(r'\bOat') | 
           temp['PROJECT_TERMS'].str.contains(r'\bOat')| temp['PROJECT_TITLE'].str.contains(r'\bOat')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2016.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2016.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\boat') | temp['PROJECT_TERMS'].str.contains(r'\boat')| 
           temp['PROJECT_TITLE'].str.contains(r'\boat') |temp['ABSTRACT'].str.contains(r'\bOat') | 
           temp['PROJECT_TERMS'].str.contains(r'\bOat')| temp['PROJECT_TITLE'].str.contains(r'\bOat')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2017.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2017.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\boat') | temp['PROJECT_TERMS'].str.contains(r'\boat')| 
           temp['PROJECT_TITLE'].str.contains(r'\boat') |temp['ABSTRACT'].str.contains(r'\bOat') | 
           temp['PROJECT_TERMS'].str.contains(r'\bOat')| temp['PROJECT_TITLE'].str.contains(r'\bOat')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)


df_abs=pd.read_csv('abstract/PRJABS_2018.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2018.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\boat') | temp['PROJECT_TERMS'].str.contains(r'\boat')| 
           temp['PROJECT_TITLE'].str.contains(r'\boat') |temp['ABSTRACT'].str.contains(r'\bOat') | 
           temp['PROJECT_TERMS'].str.contains(r'\bOat')| temp['PROJECT_TITLE'].str.contains(r'\bOat')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)


df_abs=pd.read_csv('abstract/PRJABS_2019.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2019.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\boat') | temp['PROJECT_TERMS'].str.contains(r'\boat')| 
           temp['PROJECT_TITLE'].str.contains(r'\boat') |temp['ABSTRACT'].str.contains(r'\bOat') | 
           temp['PROJECT_TERMS'].str.contains(r'\bOat')| temp['PROJECT_TITLE'].str.contains(r'\bOat')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)
# Out:
# (668, 24) (0, 25)
# (340, 24) (0, 25)
# (351, 24) (0, 25)
# (310, 24) (0, 25)
# (641, 24) (6, 25)
# (618, 24) (10, 25)
# (640, 24) (11, 25)
# (598, 24) (18, 25)
# (104076, 24) (53, 25)
# (118557, 24) (100, 25)
# (111400, 24) (132, 25)
# (98064, 24) (173, 25)
# (93367, 24) (201, 25)
# (91637, 24) (237, 25)
# (90944, 24) (258, 25)
# (92265, 24) (290, 25)
# (91126, 24) (309, 25)
# b'Skipping line 87965: expected 24 fields, saw 25\nSkipping line 87967: expected 24 fields, saw 25\n'
# (88420, 24) (333, 25)
# b'Skipping line 95568: expected 24 fields, saw 25\nSkipping line 95570: expected 24 fields, saw 25\n'
# (96209, 24) (367, 25)
# b'Skipping line 74736: expected 24 fields, saw 25\nSkipping line 79976: expected 24 fields, saw 25\n'
# (80066, 24) (398, 25)

# %%
df.AGENCY.unique()
# Out:
# array(['ARS', 'NSF', 'NIH', 'NIFA', 'CDMRP', 'FDA'], dtype=object)

# %%
df = df[df.AGENCY != 'NASA']
df = df[df.AGENCY != 'NIH']
df.shape
# Out:
# (206, 25)

# %%
df.to_csv('oat.csv')

# %% [markdown]
# # Rye

# %%
df=pd.DataFrame()
df_abs=pd.read_csv('abstract/PRJABS_2000.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2000.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\brye\b') | temp['PROJECT_TERMS'].str.contains(r'\brye\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\brye\b') |temp['ABSTRACT'].str.contains(r'\bRye\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bRye\b')| temp['PROJECT_TITLE'].str.contains(r'\bRye\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)


df_abs=pd.read_csv('abstract/PRJABS_2001.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2001.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\brye\b') | temp['PROJECT_TERMS'].str.contains(r'\brye\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\brye\b') |temp['ABSTRACT'].str.contains(r'\bRye\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bRye\b')| temp['PROJECT_TITLE'].str.contains(r'\bRye\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)


df_abs=pd.read_csv('abstract/PRJABS_2002.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2002.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\brye\b') | temp['PROJECT_TERMS'].str.contains(r'\brye\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\brye\b') |temp['ABSTRACT'].str.contains(r'\bRye\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bRye\b')| temp['PROJECT_TITLE'].str.contains(r'\bRye\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)


df_abs=pd.read_csv('abstract/PRJABS_2003.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2003.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\brye\b') | temp['PROJECT_TERMS'].str.contains(r'\brye\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\brye\b') |temp['ABSTRACT'].str.contains(r'\bRye\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bRye\b')| temp['PROJECT_TITLE'].str.contains(r'\bRye\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)


df_abs=pd.read_csv('abstract/PRJABS_2004.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2004.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\brye\b') | temp['PROJECT_TERMS'].str.contains(r'\brye\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\brye\b') |temp['ABSTRACT'].str.contains(r'\bRye\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bRye\b')| temp['PROJECT_TITLE'].str.contains(r'\bRye\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)


df_abs=pd.read_csv('abstract/PRJABS_2005.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2005.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\brye\b') | temp['PROJECT_TERMS'].str.contains(r'\brye\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\brye\b') |temp['ABSTRACT'].str.contains(r'\bRye\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bRye\b')| temp['PROJECT_TITLE'].str.contains(r'\bRye\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2006.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2006.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\brye\b') | temp['PROJECT_TERMS'].str.contains(r'\brye\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\brye\b') |temp['ABSTRACT'].str.contains(r'\bRye\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bRye\b')| temp['PROJECT_TITLE'].str.contains(r'\bRye\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2007.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2007.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\brye\b') | temp['PROJECT_TERMS'].str.contains(r'\brye\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\brye\b') |temp['ABSTRACT'].str.contains(r'\bRye\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bRye\b')| temp['PROJECT_TITLE'].str.contains(r'\bRye\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)


df_abs=pd.read_csv('abstract/PRJABS_2008.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2008.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\brye\b') | temp['PROJECT_TERMS'].str.contains(r'\brye\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\brye\b') |temp['ABSTRACT'].str.contains(r'\bRye\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bRye\b')| temp['PROJECT_TITLE'].str.contains(r'\bRye\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)


df_abs=pd.read_csv('abstract/PRJABS_2009.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2009.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\brye\b') | temp['PROJECT_TERMS'].str.contains(r'\brye\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\brye\b') |temp['ABSTRACT'].str.contains(r'\bRye\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bRye\b')| temp['PROJECT_TITLE'].str.contains(r'\bRye\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)


df_abs=pd.read_csv('abstract/PRJABS_2010.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2010.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\brye\b') | temp['PROJECT_TERMS'].str.contains(r'\brye\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\brye\b') |temp['ABSTRACT'].str.contains(r'\bRye\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bRye\b')| temp['PROJECT_TITLE'].str.contains(r'\bRye\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)


df_abs=pd.read_csv('abstract/PRJABS_2011.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2011.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\brye\b') | temp['PROJECT_TERMS'].str.contains(r'\brye\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\brye\b') |temp['ABSTRACT'].str.contains(r'\bRye\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bRye\b')| temp['PROJECT_TITLE'].str.contains(r'\bRye\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)


df_abs=pd.read_csv('abstract/PRJABS_2012.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2012.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\brye\b') | temp['PROJECT_TERMS'].str.contains(r'\brye\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\brye\b') |temp['ABSTRACT'].str.contains(r'\bRye\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bRye\b')| temp['PROJECT_TITLE'].str.contains(r'\bRye\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2013.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2013.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\brye\b') | temp['PROJECT_TERMS'].str.contains(r'\brye\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\brye\b') |temp['ABSTRACT'].str.contains(r'\bRye\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bRye\b')| temp['PROJECT_TITLE'].str.contains(r'\bRye\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)


df_abs=pd.read_csv('abstract/PRJABS_2014.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2014.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\brye\b') | temp['PROJECT_TERMS'].str.contains(r'\brye\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\brye\b') |temp['ABSTRACT'].str.contains(r'\bRye\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bRye\b')| temp['PROJECT_TITLE'].str.contains(r'\bRye\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)


df_abs=pd.read_csv('abstract/PRJABS_2015.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2015.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\brye\b') | temp['PROJECT_TERMS'].str.contains(r'\brye\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\brye\b') |temp['ABSTRACT'].str.contains(r'\bRye\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bRye\b')| temp['PROJECT_TITLE'].str.contains(r'\bRye\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2016.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2016.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\brye\b') | temp['PROJECT_TERMS'].str.contains(r'\brye\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\brye\b') |temp['ABSTRACT'].str.contains(r'\bRye\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bRye\b')| temp['PROJECT_TITLE'].str.contains(r'\bRye\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)

df_abs=pd.read_csv('abstract/PRJABS_2017.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2017.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\brye\b') | temp['PROJECT_TERMS'].str.contains(r'\brye\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\brye\b') |temp['ABSTRACT'].str.contains(r'\bRye\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bRye\b')| temp['PROJECT_TITLE'].str.contains(r'\bRye\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)


df_abs=pd.read_csv('abstract/PRJABS_2018.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2018.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\brye\b') | temp['PROJECT_TERMS'].str.contains(r'\brye\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\brye\b') |temp['ABSTRACT'].str.contains(r'\bRye\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bRye\b')| temp['PROJECT_TITLE'].str.contains(r'\bRye\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)


df_abs=pd.read_csv('abstract/PRJABS_2019.csv', error_bad_lines=False)
df_prj=pd.read_csv('projects/PRJ_2019.csv', error_bad_lines=False)
temp = pd.merge(df_prj, df_abs, how='left', left_on='PROJECT_ID', right_on='PROJECT_ID')
temp.fillna('', inplace=True)
temp.columns = temp.columns.str.replace(' ', '')
temp.drop(columns=['BUDGET_START_DATE', 'BUDGET_END_DATE','CFDA_CODE','FY_TOTAL_COST_SUB_PROJECTS'])
t=temp.loc[temp['ABSTRACT'].str.contains(r'\brye\b') | temp['PROJECT_TERMS'].str.contains(r'\brye\b')| 
           temp['PROJECT_TITLE'].str.contains(r'\brye\b') |temp['ABSTRACT'].str.contains(r'\bRye\b') | 
           temp['PROJECT_TERMS'].str.contains(r'\bRye\b')| temp['PROJECT_TITLE'].str.contains(r'\bRye\b')]
df=df.append(t,ignore_index=True)
#df_prj.drop(columns=['BUDGET_START_DATE','BUDGET_END_DATE','CFDA_CODE'],inplace=True)
print(df_prj.shape, df.shape)
# Out:
# (668, 24) (1, 25)
# (340, 24) (1, 25)
# (351, 24) (1, 25)
# (310, 24) (1, 25)
# (641, 24) (2, 25)
# (618, 24) (2, 25)
# (640, 24) (5, 25)
# (598, 24) (7, 25)
# (104076, 24) (22, 25)
# (118557, 24) (47, 25)
# (111400, 24) (65, 25)
# (98064, 24) (83, 25)
# (93367, 24) (92, 25)
# (91637, 24) (103, 25)
# (90944, 24) (118, 25)
# (92265, 24) (131, 25)
# (91126, 24) (145, 25)
# b'Skipping line 87965: expected 24 fields, saw 25\nSkipping line 87967: expected 24 fields, saw 25\n'
# (88420, 24) (153, 25)
# b'Skipping line 95568: expected 24 fields, saw 25\nSkipping line 95570: expected 24 fields, saw 25\n'
# (96209, 24) (164, 25)
# b'Skipping line 74736: expected 24 fields, saw 25\nSkipping line 79976: expected 24 fields, saw 25\n'
# (80066, 24) (175, 25)

# %%
df.AGENCY.unique()
# Out:
# array(['EPA', 'ARS', 'NIH', 'NIFA', 'NSF', 'CDMRP', 'FDA'], dtype=object)

# %%
df = df[df.AGENCY != 'NASA']
df = df[df.AGENCY != 'NIH']
df.shape
# Out:
# (99, 25)

# %%
df.to_csv('rye.csv')
